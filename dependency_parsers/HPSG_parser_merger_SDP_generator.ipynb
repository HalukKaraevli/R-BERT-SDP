# %%
hpsg_dependency_parsing_results = './results/HPSG_neural_parser/test/'
default_semeval_tsv_data_path = './R-BERT/data/train.tsv'

# %%
import os
import re
import pickle

def return_entities(text):
    e1 = re.match('.*\[E11\](.*)\[E12\]',text).groups()[0].strip()
    e2 = re.match('.*\[E21\](.*)\[E22\]',text).groups()[0].strip()
    return (e1,e2)


def generate_paths_to_root(entity_tokens,
                          term_ids_map,
                          id_dep_id_map):
    paths = []
    for term in entity_tokens:
        t_ids = term_ids_map[term]
        for t_id in t_ids:
            temp = t_id
            temp_path = []
            while temp != 0:
                temp_path.append(temp)
                temp = id_dep_id_map[temp]
            paths.append(temp_path)
    return paths


def find_shortest_path_between_entities(e1_paths,
                                        e2_paths):
    paths = []
    e1_path_sets = list(map(set,e1_paths))
    e2_path_sets = list(map(set,e2_paths))
    #print(e1_paths)
    #print(e2_paths)
    
    for i1, p1 in enumerate(e1_paths):
        for i2, p2 in enumerate(e2_paths):
            common_ids = e1_path_sets[i1] & e2_path_sets[i2]
            #print('common', common_ids)
            temp_path = []
            for t_id in p1:
                temp_path.append(t_id)
                if t_id in common_ids:
                    break
            #print('p1 end')
            #print(temp_path)
            r_p2 = list(reversed(p2))
            for index,t_id in enumerate(r_p2):
                if t_id not in common_ids:
                    temp_path.extend(r_p2[index:])
                    break
            paths.append(temp_path)
    
    return min(paths,key=len)


def calculate_sdp(sample_index,sample,exceptional_case_ids):
    res = ['Error']
    
    
    id_term_map = {int(x[0]):x[1] for x in sample}
    term_ids_map = {}
    for x in sample:
        term_ids_map[x[1]] = term_ids_map.get(x[1],[])
        term_ids_map[x[1]].append(int(x[0]))

    id_dep_id_map = {int(x[0]):x[2] for x in sample}
    temp_entities = entities_tokenized[sample_index]

    if sample_index in exceptional_case_ids:
        for i,k in enumerate(sample):
            for ent in temp_entities:
                for ind,e in enumerate(ent):
                    if e.startswith(k[1]) and \
                    (i+1 != len(sample)) and \
                     e.endswith(sample[i+1][1]):
                        ent[ind] = k[1]
                        
    e1 = entities_tokenized[sample_index][0]
    #print(e1)
    e2 = entities_tokenized[sample_index][1]
    #print(e2)
    try:
        e1_paths = generate_paths_to_root(e1,
                                      term_ids_map,
                                      id_dep_id_map)
    except:
        print(sample, e1, term_ids_map, id_dep_id_map)
        raise
    e2_paths = generate_paths_to_root(e2,
                                      term_ids_map,
                                      id_dep_id_map)

    shortest_path =find_shortest_path_between_entities(e1_paths,
                                                       e2_paths)
    res = list(id_term_map[x] for x in shortest_path)

    return res

# %%
dp_lines = []
for x in os.listdir(hpsg_dependency_parsing_results):
    if x.startswith('output_synconst'):
        dp_lines.extend(open(hpsg_dependency_parsing_results + x,'r').readlines())
        
tokens_with_pos = [re.findall('([^\s\(]+) ([\w.;"\':_-]+)\)',x) for x in dp_lines]

dp_token_parents = []
for x in os.listdir(hpsg_dependency_parsing_results):
    if x.startswith('output_syndephead'):
        dp_token_parents.extend(open(hpsg_dependency_parsing_results + x,'r').readlines())
dp_token_parents = [list(map(int, x[1:-2].split(', '))) for x in dp_token_parents]

dp_token_relations = []
for x in os.listdir(hpsg_dependency_parsing_results):
    if x.startswith('output_syndeplabel'):
        dp_token_relations.extend(open(hpsg_dependency_parsing_results + x,'r').readlines())
dp_token_relations = [list(map(lambda k: k[1:-1], x[1:-2].split(', '))) for x in dp_token_relations]

dep_parser_res = [list(zip(range(1,len(tokens)+1),
                           [t[1].replace('.','') for t in tokens],
                           dp_token_parents[k],
                           dp_token_relations[k])) 
                  for k,tokens in enumerate(tokens_with_pos)]

lines = open(default_semeval_tsv_data_path,'r')
lines = lines.readlines()
example_list = list(map(lambda x: x.split('\t'), lines))

entities = [return_entities(x) for x in map(lambda k: k[1], example_list)]
entities_tokenized = [[x.split(), y.split()] for x,y in entities]
entities_tokens_flat = [x.split() + y.split() for x,y in entities]

dep_parser_token_sets = [set(k[1] for k in x) for x in dep_parser_res]

exceptional_cases = list(filter(lambda x: any(map(lambda k: k not in dep_parser_token_sets[x[0]],
                                                  x[1])), 
                          enumerate(entities_tokens_flat)))
exceptional_case_ids = set(x[0] for x in exceptional_cases)

res = [calculate_sdp(index,sample,exceptional_case_ids) for index,sample in enumerate(dep_parser_res)]


### Additional Step

for i,r in enumerate(res):
    if r[0] in entities_tokenized[i][0]:
        r[0] = entities[i][0]
        r[-1] = entities[i][-1]
    else:
        print(i)
        
pickle.dump(res,open('./hpsg_parser_train_sdp_results.pkl','wb'))

# %%
res
# Out:
# [['configuration', 'in', 'has', 'elements'],
#  ['child', 'wrapped', 'bound', 'into', 'cradle'],
#  ['author', 'uses', 'disassembler'],
#  ['ridge', 'uprises', 'surge'],
#  ['student', 'association'],
#  ['complex', 'producer'],
#  ['inflammation', 'caused', 'by', 'infection'],
#  ['people', 'moving', 'downtown'],
#  ['lawsonite', 'contained', 'platinum crucible'],
#  ['solvent', 'of', 'ml', 'pipetted', 'into', 'flask'],
#  ['essays', 'collected', 'in', 'volume'],
#  ['composer', 'sunk', 'oblivion'],
#  ['citation', 'explaining', 'reasons'],
#  ['burst', 'caused', 'pressure'],
#  ['networks', 'moved', 'high - definition broadcast'],
#  ['call', 'remind', 'about', 'bill'],
#  ['virtuoso', 'finds', 'instrument'],
#  ['factory', 'products', 'included', 'pots', 'trays'],
#  ['tree', 'blossom'],
#  ['battalion', 'by', 'backed', 'columns', 'with', 'tried', 'grenadiers'],
#  ['knowledge', 'gained', 'from', 'recruits'],
#  ['stable', 'had', 'hounds'],
#  ['singer', 'caused', 'commotion'],
#  ['essays', 'books', 'pertinent', 'history'],
#  ['brace', 'of', 'grouse'],
#  ['dress', 'made', 'with', 'blend'],
#  ['suicide', 'one', 'of', 'causes', 'of', 'death'],
#  ['article', 'gives', 'details', 'on', '2004', 'in', 'music'],
#  ['meeting', 'dedicated', 'to', 'rural history'],
#  ['timer', 'of', 'device'],
#  ['offer', 'made', 'in', 'phone call'],
#  ['headaches', 'pains', 'from', 'mold'],
#  ['country',
#   'founding',
#   'of',
#   'family',
#   'in',
#   'rift',
#   'healing',
#   'laying',
#   'father'],
#  ['stack', 'loading', 'for', 'method', 'describes', 'carton'],
#  ['plumbing', 'in', 'manor house'],
#  ['electricity', 'produce', 'available', 'systems'],
#  ['plan', 'in', 'ran', 'resistance'],
#  ['provinces', 'divided', 'into', 'shahrestan', 'counties'],
#  ['stress', 'one', 'divorce'],
#  ['newspapers', 'swap', 'service'],
#  ['women', 'caused', 'accident'],
#  ['transmitter', 'discovered', 'inside', 'suite'],
#  ['chain', 'of', 'lagoons'],
#  ['student', 'released', 'from', 'jail'],
#  ['calluses', 'caused', 'skin abnormality'],
#  ['adults', 'use', 'drugs'],
#  ['councilor', 'proposed', 'elicitation'],
#  ['meteor shower', 'of', 'action', 'caused', 'by', 'comet'],
#  ['notes', 'to', 'statements'],
#  ['diamond', 'colliers'],
#  ['radiation', 'from', 'bomb explosion'],
#  ['boat', 'tiller'],
#  ['recurrence', 'arose', 'from', 'induced', 'radiation'],
#  ['scars', 'from', 'stitches'],
#  ['knob', 'of', 'toads'],
#  ['discourse', 'around', 'participation'],
#  ['silver', 'ring'],
#  ['debate', 'about', 'value'],
#  ['dress', 'was', 'in', 'trunk'],
#  ['disagreement', 'concerns', 'causal part'],
#  ['feet', 'moving', 'ball'],
#  ['box'],
#  ['wing', 'of', 'dragons'],
#  ['cowpea', 'sealed', 'in', 'double bags'],
#  ['brucellosis', 'disease', 'found', 'in', 'cow'],
#  ['rout', 'havoc', 'completed', 'showered', 'hosts'],
#  ['princess', 'left', 'island'],
#  ['story', 'makes', 'point'],
#  ['milk', 'poured', 'pumpkin mixture'],
#  ['lawsuits', 'ensued', 'worked', 'fans'],
#  ['outbreak', 'biggest', 'vaccine'],
#  ['cabal', 'of', 'killers'],
#  ['fire', 'caused', 'fuel'],
#  ['epithelium', 'migrating', 'matrix'],
#  ['staff', 'removed', 'position'],
#  ['suffering', 'caused', 'by', 'terrorists'],
#  ['love', 'reflected', 'in', 'artworks'],
#  ['court', 'decided', 'by', 'making', 'order'],
#  ['tsunami', 'triggered', 'by', 'band'],
#  ['leakage', 'caused', 'due', 'to', 'corrosion'],
#  ['drivers', 'take', 'allows', 'vehicle', 'created', 'wheel'],
#  ['horde', 'brings', 'features'],
#  ['ball', 'makes', 'noise'],
#  ['ensemble', 'of', 'ladies'],
#  ['products', 'in', 'surveillance', 'for', 'need', 'underscores', 'industry'],
#  ['sand', 'in', 'lay', 'come', 'beach'],
#  ['marble', 'dropped', 'bowl'],
#  ['damage', 'caused', 'by', 'earthquake'],
#  ['suffering',
#   'for',
#   'apologies',
#   'offer',
#   'prosecuted',
#   'requested',
#   'officers'],
#  ['findings', 'published', 'in', 'section'],
#  ['passenger', 'pulled', 'from', 'train'],
#  ['introduction', 'in', 'book'],
#  ['simulation', 'started', 'from', 'structure'],
#  ['user', 'plays', 'console'],
#  ['exhibition', 'arose', 'from', 'idea'],
#  ['driver', 'cleaned', 'with', 'hose'],
#  ['recession',
#   'end',
#   'used',
#   'format',
#   'for',
#   'acceptance',
#   'gaining',
#   'of',
#   'way',
#   'provided',
#   'crash'],
#  ['legion', 'captains', 'are', 'crossbowmen'],
#  ['swelling', 'caused', 'by', 'infection'],
#  ['tone', 'produced', 'by', 'vibration'],
#  ['score', 'improvised', 'by', 'orchestra'],
#  ['answers', 'posted', 'website'],
#  ['threat', 'caused', 'by', 'spell'],
#  ['programmer', 'uses', 'language'],
#  ['earthquakes', 'of', 'many', 'caused', 'by', 'movements'],
#  ['fruit', 'basket'],
#  ['heel', 'of', 'shoes'],
#  ['shoemaker', 'thread'],
#  ['tablet', 'dropped', 'into', 'canteen'],
#  ['image', 'hidden', 'in', 'carafe'],
#  ['plastic container', 'was', 'in', 'cabinet'],
#  ['acetone', 'distilled', 'from', 'solution'],
#  ['guide', 'in', 'described', 'roses'],
#  ['chestnut', 'flour'],
#  ['artists', 'book'],
#  ['silver', 'necklace'],
#  ['motion', 'caused', 'suction'],
#  ['babel', 'of', 'words'],
#  ['courtyard', 'of', 'chapel', 'shows', 'castle'],
#  ['flock', 'of', 'pigeons'],
#  ['decision', 'subject', 'legal challenge'],
#  ['stream', 'of', 'temperature', 'from', 'reactor'],
#  ['investors', 'moved', 'property'],
#  ['questions', 'of', 'one', 'relates', 'salary'],
#  ['tradition', 'narrated', 'biographies'],
#  ['thief', 'broke', 'screwdriver'],
#  ['unit', 'of', 'infantrymen'],
#  ['guns', 'carried', 'court room'],
#  ['malfunctions', 'caused', 'delays'],
#  ['chemical weapons', 'dropped', 'lake'],
#  ['dwarves', 'hailed', 'clan'],
#  ['nose', 'of', 'bloodhound'],
#  ['industry', 'develops', 'grow', 'models'],
#  ['devices', 'manufactured', 'at', 'factory'],
#  ['muster', 'of', 'leaders'],
#  ['train ride', 'from', 'station'],
#  ['relics', 'yields', 'culture'],
#  ['maze', 'of', 'jurisdictions'],
#  ['damage', 'lead', 'to', 'growth'],
#  ['scourge', 'comes', 'is', 'mosquitoes'],
#  ['formation', 'of', 'stones'],
#  ['enemy',
#   'making',
#   'armies',
#   'of',
#   'progress',
#   'assisting',
#   'engaged',
#   'efforts'],
#  ['riffraff', 'of', 'consisting', 'army', 'had', 'mercenaries'],
#  ['geometry', 'extracted', 'data'],
#  ['discomfort', 'from', 'injury'],
#  ['coven', 'of', 'sorcerers'],
#  ['convoy', 'of', 'lorries'],
#  ['readers', 'transported', 'ancient times'],
#  ['environment', 'for', 'programmers'],
#  ['scarab', 'found', 'put', 'inside', 'body'],
#  ['motorcycle', 'manufactured', 'in', 'building'],
#  ['water', 'resulted', 'tides'],
#  ['chapters', 'investigate', 'issues'],
#  ['party', 'rescheduled', 'next day'],
#  ['bacterial aerosol', 'generated', 'nebulizer'],
#  ['people', 'travelled', 'into', 'space'],
#  ['language', 'evolved', 'from', 'settlers'],
#  ['beaver', 'dams'],
#  ['play', 'of', 'theme', 'has', 'religion'],
#  ['debate', 'origins'],
#  ['ear', 'in', 'creases', 'developed', 'lobes'],
#  ['alcohol', 'ingredient', 'used', 'for', 'making', 'liquor'],
#  ['user', 'calibrates', 'with', 'standard'],
#  ['province', 'comprises', 'part'],
#  ['charge', 'source', 'of', 'field'],
#  ['tardiness', 'caused', 'by', 'arrival'],
#  ['key', 'was', 'chest'],
#  ['residue', 'distilled', 'flask'],
#  ['rain', 'of', 'arrows'],
#  ['manuscript', 'relating', 'history'],
#  ['flood', 'into', 'turned', 'after', 'deluge'],
#  ['steamer', 'stopped', 'engine'],
#  ['umbrella', 'peels', 'with', 'pencil'],
#  ['wheat', 'ale'],
#  ['car', 'left', 'plant'],
#  ['archipelago', 'of', 'promotion', 'to', 'extends', 'islands'],
#  ['clay', 'contained', 'membrane tubing'],
#  ['sand', 'blowing', 'molds'],
#  ['cultivation', 'consisted', 'plow'],
#  ['chapter', 'offers', 'theological survey'],
#  ['scandal', 'caused', 'by', 'documentary'],
#  ['shaft', 'of', 'ulna'],
#  ['candidates', 'placed', 'roles'],
#  ['life', 'throw', 'disarray'],
#  ['potter', 'ceramics'],
#  ['nasal cavity', 'of', 'birds'],
#  ['tendon', 'attaches', 'muscle'],
#  ['positions', 'denoted', 'by', 'black dots'],
#  ['radiation', 'release', 'from', 'accident'],
#  ['cellophane bag', 'ate', 'dog treats'],
#  ['owl', 'held', 'claw'],
#  ['hay', 'put', 'delivered', 'is', 'barn'],
#  ['artist', 'drew', 'cartoon'],
#  ['paper', 'stuffed', 'into', 'bag'],
#  ['treasure trove', 'of', 'libraries'],
#  ['bail', 'of', 'reel'],
#  ['works', 'from', 'kingdom'],
#  ['confusion', 'caused', 'by', 'coup'],
#  ['book', 'by', 'planter'],
#  ['society', 'built', 'individuals'],
#  ['scientist', 'approached', 'with', 'notepad'],
#  ['photo', 'is', 'library'],
#  ['accident', 'caused', 'snarl'],
#  ['surgeon', 'helped', 'team'],
#  ['dress', 'was', 'in', 'trunk'],
#  ['tension', 'to', 'subject', 'situation'],
#  ['leader', 'of', 'organization'],
#  ['director', 'venice', 'completed', 'book'],
#  ['data', 'fetched', 'arrays'],
#  ['things', 'arrive', 'theatres'],
#  ['electrode', 'corrosion'],
#  ['koala', 'inside', 'are', 'pouch'],
#  ['duel', 'of', 'moles'],
#  ['umbrella', 'frames'],
#  ['contractions', 'caused', 'by', 'by', 'irritation'],
#  ['plane', 'drive', 'from', 'runway'],
#  ['skeleton', 'derived', 'from', 'object'],
#  ['filmmakers', 'dug', 'hole'],
#  ['report', 'providing', 'opinion'],
#  ['governments', 'resolved', 'subsidization'],
#  ['diamond', 'bought', 'gave', 'necklace'],
#  ['wake', 'of', 'buzzards'],
#  ['warts', 'caused', 'by', 'virus'],
#  ['sensor', 'manufactured', 'process'],
#  ['compeers',
#   'for',
#   'surveillance',
#   'of',
#   'systems',
#   'animate',
#   'brand',
#   'right',
#   'as',
#   'eager',
#   'criminals'],
#  ['list', 'filled', 'images'],
#  ['rope', 'of', 'prayer - bell'],
#  ['man', 'stirs', 'with', 'paddle'],
#  ['alliance', 'of', 'classes'],
#  ['operations', 'migrating', 'nearby countries'],
#  ['cover', 'preserved', 'in', 'ewer'],
#  ['machine', 'of', 'front', 'contains', 'picks'],
#  ['immigrant flows', 'incorporated', 'microsimulation'],
#  ['boys', 'roy', 'left', 'relieved', 'felt', 'creek'],
#  ['report', 'analyses', 'strategies'],
#  ['colony', 'of', 'establishment', 'for', 'prepared', 'power'],
#  ['gene', 'passes', 'generation'],
#  ['telescope', 'assists', 'eye'],
#  ['boy', 'went', 'bathroom'],
#  ['document', 'stored', 'in', 'folder'],
#  ['pages', 'spent', 'had', 'scene'],
#  ['weather', 'conditions'],
#  ['passel', 'of', 'pigeons'],
#  ['resources', 'poured', 'wine'],
#  ['money', 'stored', 'called', 'treasury', 'baskets'],
#  ['chemicals', 'of', 'hundreds', 'released', 'atmosphere'],
#  ['part', 'completed', 'by', 'chapel'],
#  ['mobile', 'found', 'belly'],
#  ['flyer', 'advertised', 'workshop'],
#  ['hotel', 'arose', 'from', 'reconstruction'],
#  ['edition', 'incorporates', 'findings'],
#  ['fish', 'swim', 'in', 'shoal'],
#  ['bookmarks', 'exported', 'file'],
#  ['team', 'used', 'nanoparticle'],
#  ['revelation', 'made', 'in', 'phone call'],
#  ['siege', 'bale', 'to', 'home', 'herons'],
#  ['indenter', 'pushed', 'into', 'material'],
#  ['issue', 'sent', 'members'],
#  ['cruisers', 'have', 'fittings'],
#  ['accused', 'killed', 'with', 'kirpan'],
#  ['shiver', 'of', 'demands', 'serve', 'are', 'sharks'],
#  ['capsule', 'in', 'placing', 'by', 'send', 'tube'],
#  ['doll', 'made', 'with', 'stockings'],
#  ['documents', 'illustrating', 'history'],
#  ['choreographer', 'devised', 'moves'],
#  ['state', 'assembled', 'package'],
#  ['bottle', 'full', 'of', 'carbonated beverage'],
#  ['wire', 'coiled', 'in', 'pail'],
#  ['earthquake', 'caused', 'blackout'],
#  ['configurations', 'illustrated', 'drawings'],
#  ['head', 'of', 'chief', 'of', 'police'],
#  ['series', 'comprises', 'titles'],
#  ['students', 'put', 'barricade'],
#  ['solution', 'comprises', 'creation'],
#  ['tension', 'release', 'contains', 'stress'],
#  ['hill', 'of', 'beans', 'corn'],
#  ['chocolate', 'poured', 'into', 'jars'],
#  ['elephant', 'descended', 'animal'],
#  ['meeting', 'of', 'shareholders'],
#  ['needle', 'inserted', 'machine'],
#  ['quality', 'obtained', 'from', 'oocytes'],
#  ['letter', 'sent', 'from', 'group'],
#  ['cardiovascular disease', 'one', 'of', 'causes', 'of', 'morbidity'],
#  ['geoid',
#   'as',
#   'known',
#   'mss',
#   'to',
#   'closest',
#   'surface',
#   'departs',
#   'from',
#   'ellipsoid'],
#  ['beans', 'slipped', 'into', 'flask'],
#  ['dizziness', 'from', 'sinus pressure'],
#  ['study', 'from', 'benefit', 'approach'],
#  ['governor', 'won', 'with', 'appearances'],
#  ['bomb', 'hidden', 'in', 'handcart'],
#  ['fistful', 'of', 'coupons'],
#  ['book', 'imported', 'software'],
#  ['soldiers', 'moved', 'jungle'],
#  ['chair', 'of', 'corporation'],
#  ['hole', 'found', 'in', 'piece'],
#  ['mummy', 'was', 'inside', 'wooden coffin'],
#  ['meeting', 'establishes', 'laws'],
#  ['game', 'sealed', 'in', 'packing'],
#  ['nerve', 'rests', 'in', 'cistern'],
#  ['body', 'stuffed', 'in', 'sack'],
#  ['model', 'moving', 'into', 'territory'],
#  ['priests', 'broke', 'pointed', 'work'],
#  ['sagas', 'developed', 'from', 'oral culture'],
#  ['walls', 'of', 'hospital'],
#  ['solution', 'storing', 'in', 'refrigerator'],
#  ['money', 'poured', 'project'],
#  ['farmer', 'plowing', 'with', 'mule'],
#  ['flower', 'buds'],
#  ['clothes', 'were', 'in', 'box'],
#  ['venter', 'cell'],
#  ['feedback', 'defined', 'earlier', 'in', 'chapter'],
#  ['train', 'arrives', 'from', 'point'],
#  ['body', 'found', 'in', 'sack'],
#  ['draught', 'with', 'rewarded', 'fling', 'directed', 'salmons'],
#  ['website', 'soap operas'],
#  ['system', 'consists', 'of', 'lines'],
#  ['owner', 'lit', 'fire'],
#  ['writer', 'specialises', 'in', 'letters'],
#  ['name', 'derived', 'from', 'vote'],
#  ['poodle', 'fetched', 'into', 'acre'],
#  ['fear', 'from', 'crowd'],
#  ['avalanches', 'originated', 'in', 'mass'],
#  ['exhibition', 'describes', 'fight'],
#  ['wax', 'placed', 'can'],
#  ['nose', 'of', 'plane'],
#  ['executive board', 'of', 'company'],
#  ['toys', 'of', 'box', 'family', 'about', 'story', 'from', 'future'],
#  ['pocketwatch', 'unwinded', 'by', 'letting', 'mainspring'],
#  ['television network', 'devoted', 'to', 'arts'],
#  ['laws', 'of', 'portion', 'defining', 'crimes'],
#  ['raspberry', 'syrup'],
#  ['stars', 'lit', 'heavens'],
#  ['transmission',
#   'of',
#   'commencement',
#   'of',
#   'time',
#   'mark',
#   'employed',
#   'transmitter'],
#  ['peep', 'of', 'chickens'],
#  ['cover', 'analysed', 'in', 'article'],
#  ['confrontation', 'caused', 'commotion'],
#  ['workers', 'build', 'honeycomb'],
#  ['cutting board', 'was', 'in', 'lot', 'box'],
#  ['wolf', 'of', 'role', 'reflect', 'uses', 'pack'],
#  ['protein', 'product', 'gene'],
#  ['audit', 'of', 'purpose', 'was', 'financial statements'],
#  ['stomach', 'full', 'of', 'gravel'],
#  ['throng', 'through', 'bore', 'foes'],
#  ['coffin', 'in', 'placed', 'removed', 'case'],
#  ['reduction', 'originates', 'correspond', 'relaxation'],
#  ['devastation', 'with', 'associated', 'speed', 'estimate', 'tornado'],
#  ['robot', 'reached', 'using', 'number', 'of', 'states'],
#  ['indicator', 'of', 'condition'],
#  ['deficits', 'caused', 'by', 'saving', 'people'],
#  ['teacher', 'writes', 'blackboard'],
#  ['wedge', 'of', 'swans'],
#  ['friend', 'falls', 'in', 'love'],
#  ['wind', 'cause', 'delays'],
#  ['illnesses', 'of', 'fifths', 'caused', 'by', 'diseases'],
#  ['rectangles', 'from', 'different', 'richer', 'made', 'cook'],
#  ['billions', 'flow', 'products'],
#  ['corporation', 'constructed', 'railways'],
#  ['glamour', 'subject', 'of', 'exhibition'],
#  ['resetting', 'completing', 'through', 'signal'],
#  ['destruction', 'caused', 'by', 'bombing'],
#  ['kit', 'includes', 'toggle switch'],
#  ['blood', 'arrives', 'from', 'animal'],
#  ['mesencephalon', 'comprises', 'tectum'],
#  ['construction', 'rescheduled', 'next year'],
#  ['ship', 'scratched', 'in', 'jug'],
#  ['consciousness', 'travelling', 'future'],
#  ['alligator', 'breaks', 'with', 'pick'],
#  ['chapters', 'in', 'used', 'later', 'in', 'book'],
#  ['plane', 'was', 'in', 'crate'],
#  ['water', 'poured', 'into', 'hand'],
#  ['vapor', 'of', 'most', 'evaporated', 'oceans'],
#  ['sound', 'produced', 'by', 'drum'],
#  ['caravan', 'left', 'putting', 'of', 'result', 'as', 'imprisoned', 'depo'],
#  ['tea', 'was', 'in', 'glass'],
#  ['plant', 'made', 'was', 'steel'],
#  ['box', 'regulated', 'using', 'controller'],
#  ['landslide', 'triggered', 'by', 'earthquake'],
#  ['meinie', 'has', 'knights'],
#  ['mechanism', 'composed', 'of', 'patella'],
#  ['bag', 'with', 'condoms'],
#  ['debris', 'caused', 'crash'],
#  ['fire', 'triggered', 'by', 'blasts'],
#  ['standards', 'are', 'under', 'discussion'],
#  ['macaque', 'grows', 'coat'],
#  ['congressmen', 'to', 'anathema', 'record', 'has', 'regarded', 'party'],
#  ['sediments', 'transported', 'lake'],
#  ['review', 'published', 'commentary'],
#  ['announcement', 'of', 'review'],
#  ['handbag', 'locked', 'display case'],
#  ['poem', 'written', 'by', 'riverside'],
#  ['intestines', 'migrated', 'into', 'abdomen'],
#  ['faults', 'caused', 'delays', 'cancellations'],
#  ['critic', 'james', 'completed', 'novel'],
#  ['incidents', 'related', 'books'],
#  ['focus', 'going', 'button'],
#  ['asparagus', 'cure', 'cancer'],
#  ['mustering', 'of', 'stork'],
#  ['craniopharyngioma', 'originating', 'in', 'bone'],
#  ['book', 'in', 'early', 'used', 'pool'],
#  ['power', 'exported', 'grid'],
#  ['pressure', 'relieve', 'enlarging', 'by', 'relieve', 'disc'],
#  ['sinus rinse', 'went', 'ear canal'],
#  ['factory', 'producing', 'plates'],
#  ['cold air', 'moved', 'into', 'mountains'],
#  ['mission', 'of', 'monkeys'],
#  ['quiver', 'like', 'swaying', 'standing', 'seethe', 'cobras'],
#  ['roach', 'on', 'sail'],
#  ['limestone', 'composed', 'of', 'pieces'],
#  ['heartwood', 'source', 'hematoxylin'],
#  ['beer', 'acts', 'dog'],
#  ['company', 'run', 'into', 'problem'],
#  ['spans', 'of', 'bridge'],
#  ['girl', 'plays', 'stick'],
#  ['surgeon', 'applies', 'splints'],
#  ['body', 'was', 'inside', 'duffel bag'],
#  ['scientist', 'kidnaps', 'manages', 'niece'],
#  ['clothing', 'factory'],
#  ['peanut butter', 'cookies'],
#  ['seeds', 'stored', 'in', 'stratification unit'],
#  ['cranberry', 'sauce'],
#  ['barren', 'of', 'mules'],
#  ['cancellation', 'delay', 'of', 'event', 'in', 'have', 'airline'],
#  ['supreme court', 'applied', 'protections'],
#  ['body', 'contained', 'cypress coffin'],
#  ['guides', 'prepared', 'on', 'maps'],
#  ['tenant', 'excluded', 'from', 'home'],
#  ['orphan', 'temple', 'of', 'adoption', 'by', 'john', 'bachelor'],
#  ['essay', 'inquires', 'into', 'nature', 'origins'],
#  ['sorrow', 'in', 'was', 'after', 'loss'],
#  ['earthquake', 'triggered', 'by', 'eruption'],
#  ['advances', 'in', 'biology'],
#  ['paper', 'review', 'of', 'techniques'],
#  ['diabetes mellitus', 'one', 'of', 'causes', 'of', 'blindness'],
#  ['crew', 'assisted', 'with', 'investigation'],
#  ['data', 'concerning', 'operations'],
#  ['bid', 'was', 'from', 'company'],
#  ['hurdles', 'for', 'drilling'],
#  ['comma', 'to', 'changed', 'scribe'],
#  ['pellets', 'blown', 'into', 'cavities'],
#  ['winemaker', 'chose', 'grapes'],
#  ['pin', 'of', 'connector'],
#  ['insulation', 'of', 'form', 'in', 'carafe'],
#  ['book', 'in', 'early', 'review', 'authors'],
#  ['irritation', 'reverse', 'time', 'reduced', 'fungus'],
#  ['flower', 'blooms', 'pond'],
#  ['bed',
#   'over',
#   'bridge',
#   'on',
#   'standing',
#   'finding',
#   'lost',
#   'to',
#   'from',
#   'real',
#   'make',
#   'offers',
#   'snakes'],
#  ['hamper', 'of', 'goodies'],
#  ['impetus', 'of', 'much', 'came', 'veteran'],
#  ['satisfaction', 'from', 'purchase'],
#  ['camaraderie', 'of', 'runners'],
#  ['kinship systems', 'of', 'grandparents'],
#  ['restaurant', 'cleaned', 'with', 'agent'],
#  ['package', 'includes', 'receiver'],
#  ['accident', 'caused', 'ground', 'on', 'entered', 'judge', 'negligence'],
#  ['coffee', 'arrived', 'in', 'mug'],
#  ['glut', 'of', 'savings'],
#  ['nuts', 'powered', 'plane'],
#  ['case', 'centers', 'on', 'tree'],
#  ['arrays', 'consisting', 'of', 'holes'],
#  ['comment', 'by', 'students'],
#  ['flowers', 'carried', 'chapel'],
#  ['documents', 'define', 'procedures', 'policies'],
#  ['rage', 'with', 'filled', 'after', 'fight'],
#  ['alarm', 'fire'],
#  ['guys', 'catch', 'nets'],
#  ['section', 'toward', 'wander', 'tending', 'noticed', 'store'],
#  ['waistband', 'of', 'underwear'],
#  ['plot', 'centers', 'around', 'girl'],
#  ['catamaran', 'tiller'],
#  ['oil', 'imports', 'to', 'countries'],
#  ['blogging', 'going', 'places'],
#  ['nurses', 'of', 'some', 'drank', 'out', 'of', 'jars'],
#  ['topics', 'emerging', 'from', 'literature'],
#  ['representative', 'rso', 'accessed', 'key'],
#  ['platform', 'part', 'of', 'narada', 'ship'],
#  ['car', 'plant'],
#  ['entrance', 'of', 'palace'],
#  ['clarinet', 'developed', 'from', 'recorder family'],
#  ['author', 'reasons', 'differ', 'work'],
#  ['paddle', 'of', 'microaccelerometer'],
#  ['soldiers', 'put', 'wall'],
#  ['hookah', 'filters', 'through', 'water'],
#  ['negotiations', 'are', 'labour', 'is', 'apprentice training'],
#  ['trembling', 'of', 'finches'],
#  ['incident', 'caused', 'sensation'],
#  ['computer', 'screen'],
#  ['navy', 'searched', 'with', 'crew'],
#  ['poems', 'published', 'on', 'site'],
#  ['hairdresser', 'tunes', 'toners'],
#  ['students', 'locate', 'pushpins'],
#  ['banquet', 'round', 'included', 'basket'],
#  ['array', 'of', 'comprised', 'luminaries'],
#  ['sugar', 'was', 'in', 'cabinet'],
#  ['cut', 'sealed', 'blade'],
#  ['sugar', 'factory'],
#  ['managers', 'left', 'locked', 'shop'],
#  ['recipient', 'receives', 'through', 'receiver'],
#  ['basket', 'containing', 'biscuits'],
#  ['genetic material', 'inherited', 'generation'],
#  ['power cord', 'of', 'dryer'],
#  ['cholesterol', 'fats', 'cause', 'proof', 'as', 'cited', 'disease'],
#  ['fraternity', 'of', 'adults'],
#  ['flight', 'of', 'seamews', 'gulls'],
#  ['drawings', 'featuring', 'landmarks'],
#  ['program', 'sponsored', 'by', 'organizations', 'districts'],
#  ['troupe', 'of', 'performers'],
#  ['memory', 'wiping', 'in', 'succeeded', 'mouse'],
#  ['cigarettes', 'used', 'by', 'women'],
#  ['preservatives', 'cause', 'dryness', 'itchiness'],
#  ['x - rays', 'used', 'by', 'dentists'],
#  ['cricket', 'dragged', 'business'],
#  ['space'],
#  ['pack', 'of', 'hounds'],
#  ['request', 'sent', 'port'],
#  ['girl', 'creates', 'quilt'],
#  ['box'],
#  ['pyrotechnics', 'caused', 'fire'],
#  ['stress', 'causes', 'is', 'breakouts'],
#  ['crisis', 'caused', 'by', 'flood'],
#  ['manufacturer', 'drug'],
#  ['scissors', 'used', 'by', 'stylist'],
#  ['tooth', 'day', 'in', 'cup'],
#  ['floor', 'of', 'cottage'],
#  ['bike', 'call', 'nest', 'into', 'put', 'bees'],
#  ['hand', 'put', 'inside', 'box'],
#  ['plowing', 'their', 'did', 'began', 'plow'],
#  ['publication', 'before', 'submitted', 'mail'],
#  ['passport', 'was', 'in', 'trunk'],
#  ['infection', 'viruses'],
#  ['fish', 'of', 'amount', 'migrated', 'water'],
#  ['victim', 'dragged', 'water'],
#  ['cellar', 'of', 'dwelling'],
#  ['segment', 'comprised', 'of', 'membrane'],
#  ['litter', 'raises', 'follow', 'going', 'pups'],
#  ['shed', 'put', 'by', 'people'],
#  ['session', 'discussed', 'about', 'inter - loans'],
#  ['drinks', 'cause', 'diabetes'],
#  ['grief', 'after', 'loss'],
#  ['students', 'misplaced', 'schools'],
#  ['deceit', 'of', 'lapwings'],
#  ['mentality', 'war'],
#  ['authors', 'assessed', 'in', 'series'],
#  ['painting', 'represents', 'meal'],
#  ['pillars', 'of', 'bridge'],
#  ['blood', 'products'],
#  ['preeclampsia', 'one', 'mortality'],
#  ['device', 'using', 'simulated', 'matchboxes'],
#  ['running', 'shoes'],
#  ['packet', 'was', 'inside', 'box'],
#  ['call', 'made', 'by', 'robbers'],
#  ['sugar', 'company'],
#  ['demolition', 'cause', 'of', 'terror'],
#  ['prices', 'arrived', 'hotel'],
#  ['tiger', 'escaped', 'from', 'pen'],
#  ['comb', 'hidden', 'in', 'envelope'],
#  ['machine', 'has', 'units'],
#  ['bout', 'of', 'violin'],
#  ['people', 'moving', 'cities'],
#  ['lime', 'juice'],
#  ['outbreak', 'resulted', 'injuries'],
#  ['padlock', 'lock', 'on', 'pane'],
#  ['troops', 'piled', 'hill'],
#  ['fridge', 'was', 'mahogany case'],
#  ['reader', 'took', 'past'],
#  ['document', 'of', 'economic policy'],
#  ['comradeship', 'seek', 'encouraged', 'veterans'],
#  ['lobby', 'of', 'building'],
#  ['priest', 'mixes', 'with', 'spoon'],
#  ['money', 'donated', 'charity'],
#  ['bag', 'was', 'in', 'bin'],
#  ['ale', 'of', 'freshness', 'in', 'carton'],
#  ['statute', 'applied', 'to', 'dominions'],
#  ['spring', 'in', 'grows', 'creek'],
#  ['devices', 'running', 'issues'],
#  ['channel', 'showing', 'sports'],
#  ['stove', 'on', 'melting', 'method'],
#  ['pain', 'from', 'indigestion'],
#  ['teacher', 'covers', 'glass'],
#  ['alcohol', 'child abuse'],
#  ['malfunction', 'caused', 'rush'],
#  ['physiotherapy', 'focused', 'on', 'prevention', 'admission avoidance'],
#  ['comradeship', 'of', 'ideal', 'reflected', 'based', 'arms'],
#  ['data', 'produced', 'by', 'technician'],
#  ['confederacy', 'of', 'kingdoms'],
#  ['troubadour', 'to', 'taught', 'broadsides'],
#  ['goods', 'imported', 'into', 'states'],
#  ['population', 'of', 'settlers'],
#  ['oven', 'has', 'conveyor'],
#  ['psychiatrists', 'familiar', 'with', 'medications'],
#  ['sections', 'denoted', 'asterisk'],
#  ['cashier', 'code', 'serves', 'register'],
#  ['report', 'emphasised', 'need'],
#  ['corpse', 'dangling', 'from', 'noose'],
#  ['sodium', 'causes', 'retention'],
#  ['boards', 'of', 'directors'],
#  ['team', 'constructed', 'gardens'],
#  ['pouches', 'of', 'wallabies'],
#  ['shoemaker', 'invented', 'machine'],
#  ['gam', 'of', 'whales'],
#  ['words', 'takes', 'action'],
#  ['sample', 'contained', 'in', 'glass tube'],
#  ['guidelines', 'from', 'article'],
#  ['damages', 'for', 'claims', 'vehicle'],
#  ['mater', 'placed', 'into', 'saline'],
#  ['text messages', 'sent', 'outer space'],
#  ['researchers', 'coated', 'paper'],
#  ['stuffed dog', 'was', 'in', 'trunk'],
#  ['martyrs', 'conquered', 'fears', 'associated', 'with', 'persecution'],
#  ['artist', 'taking', 'photograph'],
#  ['therapist', 'treats', 'therapy'],
#  ['program', 'assists', 'families'],
#  ['document', 'part', 'of', 'series'],
#  ['deers', 'ran', 'cars'],
#  ['ball', 'with', 'catnip'],
#  ['fistful', 'with', 'came', 'dollars'],
#  ['design', 'filters', 'through', 'bag'],
#  ['law', 'established', 'redistribution'],
#  ['virus', 'to', 'due', 'mononucleosis', 'causes', 'tonsillitis'],
#  ['electricity', 'flew', 'into', 'water'],
#  ['summary', 'of', 'aspects'],
#  ['device', 'shown', 'in', 'figure'],
#  ['constellation', 'of', 'artists'],
#  ['explosion', 'of', 'images', 'pictures', 'presented', 'crash'],
#  ['fiction', 'writer'],
#  ['staff', 'comprises', 'scholars', 'scientists', 'philosophers'],
#  ['damage', 'caused', 'strikers'],
#  ['installation', 'studies', 'relationships'],
#  ['sail', 'had', 'roach'],
#  ['assistant', 'she', 'knit', 'rug'],
#  ['card', 'reps', 'manufacturer'],
#  ['name', 'derived', 'from', 'word'],
#  ['bottle', 'with', 'wine'],
#  ['document', 'issued', 'from', 'locations'],
#  ['machine', 'fitted', 'with', 'feeder'],
#  ['method', 'used', 'mathematicians'],
#  ['cash', 'stuffed', 'into', 'shirt'],
#  ['scroll wheel', 'of', 'mouse'],
#  ['site', 'inside', 'earth'],
#  ['terrorism', 'exported', 'society'],
#  ['compeers', 'of', 'ages'],
#  ['food', 'manufacturer'],
#  ['person', 'regains', 'snowshoes'],
#  ['design', 'by', 'brothers'],
#  ['headache', 'get', 'from', 'wine'],
#  ['bulbs', 'work', 'by', 'using', 'electricity'],
#  ['authority', 'given', 'mosaic', 'translation'],
#  ['poster', 'enclosed', 'packaging'],
#  ['theories', 'of', 'some', 'allege', 'a', 'birth certificate'],
#  ['draft', 'declared', 'borders'],
#  ['tree', 'grows', 'acorn'],
#  ['patients', 'entered', 'trials'],
#  ['girl', 'plays', 'violin'],
#  ['atlas', 'created', 'by', 'matthias', 'cartographer'],
#  ['interrogation', 'covers', 'activities'],
#  ['drove', 'of', 'oxen'],
#  ['mast', 'folded', 'inside', 'canister'],
#  ['website', 'use', 'inform', 'about', 'projects'],
#  ['harm', 'caused', 'by', 'hurricane'],
#  ['liquor amnii', 'put', 'phial'],
#  ['statement', 'comes', 'from', 'knowledge'],
#  ['flip - flop', 'element', 'of', 'circuit'],
#  ['suitcase', 'full', 'of', 'marihuana'],
#  ['fluid', 'was', 'in', 'cup'],
#  ['paper', 'of', 'aim', 'is', 'present', 'results'],
#  ['drama', 'centered', 'around', 'girl'],
#  ['disease', 'caused', 'by', 'organism'],
#  ['water', 'evaporated', 'kettle'],
#  ['crash', 'splashes', 'hippopotami'],
#  ['builders', 'use', 'paste', 'like', 'adhesive'],
#  ['star', 'landing', 'into', 'controversies'],
#  ['prisoner', 'falling', 'oblivion'],
#  ['infection', 'one', 'of', 'causes', 'of', 'death'],
#  ['monasteries', 'founded', 'assimilated', 'river'],
#  ['coffee', 'machine'],
#  ['breakdown', 'triggered', 'by', 'death'],
#  ['manufacturers', 'attached', 'with', 'number', 'of', 'capscrews'],
#  ['wake', 'of', 'buzzards'],
#  ['call', 'came', 'from', 'father'],
#  ['passel', 'of', 'brats'],
#  ['daughter', 'put', 'with', 'harssement'],
#  ['circus', 'ace', 'about', 'hears', 'working', 'fighters'],
#  ['spacecraft', 'goes', 'retirement'],
#  ['piece', 'placed', 'inside', 'bladder'],
#  ['factory', 'output', 'of', 'firearms'],
#  ['baby', 'falling', 'sleep'],
#  ['builders', 'approached', 'building committee'],
#  ['meltdown', 'caused', 'reaction'],
#  ['ginger', 'was', 'in', 'jar'],
#  ['seeds', 'sent', 'space'],
#  ['group', 'part', 'of', 'association'],
#  ['event', 'postponed', 'tomorrow'],
#  ['chips', 'stuffed', 'into', 'mouth'],
#  ['account', 'of', 'analysis'],
#  ['convulsions', 'caused', 'fever'],
#  ['plugs', 'in', 'plugboard'],
#  ['rules', 'governing', 'transfers'],
#  ['page', 'torn', 'from', 'book'],
#  ['book', 'relates', 'tales'],
#  ['mouse', 'button'],
#  ['man', 'fell', 'from', 'bridge'],
#  ['virus', 'exported', 'hard disk'],
#  ['sign', 'indicating', 'length'],
#  ['shoe', 'stuffed', 'beaten', 'mouth'],
#  ['text', 'by', 'potter'],
#  ['fire', 'caught', 'after', 'collision'],
#  ['inlet', 'at', 'controlled', 'dryer'],
#  ['fog', 'cause', 'irritation'],
#  ['dollars', 'flow', 'facilities'],
#  ['professor', 'portrays', 'paper'],
#  ['image', 'constructed', 'from', 'photos'],
#  ['team', 'devised', 'methodology'],
#  ['clip', 'describing', 'investment'],
#  ['emissions reductions', 'under', 'discussion'],
#  ['fable', 'illustrates', 'force'],
#  ['sinking', 'resulted', 'in', 'loss'],
#  ['researcher', 'started', 'with', 'paper'],
#  ['team', 'drafted', 'player'],
#  ['novels', 'of', 'all', 'concerned', 'agents'],
#  ['creep', 'of', 'descendants', 'tortoises'],
#  ['headaches', 'pain killers'],
#  ['students', 'moving', 'into', 'components'],
#  ['advocates', 'lit', 'flame'],
#  ['traffic', 'transferred', 'into', 'cache'],
#  ['clams', 'deposited', 'in', 'bucket'],
#  ['month', 'of', 'sundays'],
#  ['population', 'of', 'dwellers'],
#  ['items', 'donated', 'to', 'museum'],
#  ['defendant', 'made', 'statement'],
#  ['coil', 'of', 'galvanometer'],
#  ['voters', 'eluded', 'issues'],
#  ['coven', 'of', 'witches'],
#  ['plane', 'took', 'from', 'city'],
#  ['craftsmen', 'marked', 'marks'],
#  ['bottle', 'with', 'apple'],
#  ['infestation', 'of', 'lice'],
#  ['garbages', 'thrown', 'into', 'ocean'],
#  ['meningitis', 'caused', 'by', 'bacteria'],
#  ['gallery', 'promoting', 'work'],
#  ['field', 'of', 'racehorses'],
#  ['book', 'criticizes', 'family'],
#  ['regulations', 'differ', 'professional corporations'],
#  ['people', 'threw', 'panic'],
#  ['kinship', 'of', 'ideals'],
#  ['novel', 'depicts', 'life'],
#  ['syndicate', 'of', 'capitalists'],
#  ['helicopter', 'landing', 'into', 'grass'],
#  ['rainbow', 'caused', 'by', 'spray'],
#  ['fluther', 'of', 'jellyfish'],
#  ['implant', 'placed', 'jaw bone'],
#  ['papers', 'define', 'threat'],
#  ['music', 'added', 'slideshows'],
#  ['cops', 'moved', 'hotels'],
#  ['flood', 'arrives', 'from', 'reaches'],
#  ['box', 'contained', 'dollar bill'],
#  ['grain', 'imported', 'into', 'countries'],
#  ['statesman', 'threw', 'draft'],
#  ['changes', 'caused', 'by', 'hormone'],
#  ['water', 'gave', 'plants'],
#  ['waste', 'gave', 'fumes'],
#  ['debris', 'thrown', 'air'],
#  ['coconut', 'oil'],
#  ['plastic container', 'with', 'dehydrated food'],
#  ['parcel', 'of', 'deer'],
#  ['populations', 'started', 'gene pool'],
#  ['nape', 'on', 'male'],
#  ['articles', 'run', 'sociological research'],
#  ['ruins', 'identified', 'inhabitants'],
#  ['wort', 'draining', 'bucket'],
#  ['studies', 'made', 'medicine'],
#  ['books', 'of', 'list', 'is', 'bible'],
#  ['funds', 'placed', 'account'],
#  ['argument', 'is', 'from', 'source'],
#  ['weak ligaments', 'caused', 'by', 'problems'],
#  ['arguments', 'provokes', 'topic', 'practice'],
#  ['clips', 'in', 'talked', 'about', 'career'],
#  ['creativity', 'puts', 'use'],
#  ['advertisements', 'resulted', 'in', 'murders'],
#  ['book', 'authored', 'by', 'academic'],
#  ['throng', 'of', 'spectators'],
#  ['ads', 'tended', 'feature', 'beauty'],
#  ['press', 'reported', 'on', 'disorders'],
#  ['quotation', 'used', 'indicate', 'words'],
#  ['book', 'telling', 'of', 'explorations'],
#  ['interview', 'in', 'speaks', 'about', 'childhood'],
#  ['passion', 'threw', 'painting'],
#  ['gel', 'placed', 'opened', 'sheath'],
#  ['bar', 'on', 'corner'],
#  ['cd', 'misplaced', 'folder'],
#  ['questionnaires', 'sent', 'countries'],
#  ['cabin', 'has', 'bedrooms'],
#  ['board', 'comprised', 'of', 'judge'],
#  ['shipment', 'in', 'cask'],
#  ['mason', 'did', 'stonework'],
#  ['philosophy', 'kind', 'uses', 'language'],
#  ['cells', 'injected', 'cavity'],
#  ['sacrifices', 'the', 'thrown', 'volcano'],
#  ['country', 'moved', 'century'],
#  ['practices', 'pointed', 'interviews'],
#  ['shoes', 'were', 'box'],
#  ['mechanic', 'attaches', 'wrench'],
#  ['brigade', 'of', 'chefs'],
#  ['stores', 'draining', 'stalled', 'memory'],
#  ['battle', 'caused', 'panic'],
#  ['poet', 'moved', 'center'],
#  ['world', 'in', 'jug'],
#  ['chapters', 'later', 'in', 'book'],
#  ['power', 'come', 'from', 'dams'],
#  ['chimpanzees', 'make', 'tools'],
#  ['stapler', 'comprises', 'head', 'anvil'],
#  ['signal', 'generated', 'by', 'laser'],
#  ['byelection', 'caused', 'by', 'resignation'],
#  ['structure',
#   'of',
#   'result',
#   'as',
#   'plaguing',
#   'transfer',
#   'of',
#   'victim',
#   'speculation'],
#  ['wars', 'brought', 'into', 'living rooms'],
#  ['items', 'transport', 'home'],
#  ['dishwasher', 'has', 'tub'],
#  ['works', 'donated', 'church'],
#  ['pier', 'forms'],
#  ['evacuation', 'regarding', 'received', 'drill'],
#  ['message', 'enclosed', 'in', 'paper'],
#  ['piano', 'keys'],
#  ['gathering', 'part', 'event'],
#  ['indicator', 'of', 'land'],
#  ['bag', 'in', 'locked', 'tallied', 'safe'],
#  ['boiler', 'works', 'with', 'cylinder'],
#  ['article', 'of', 'point', 'is', 'forms', 'food'],
#  ['tsunamis', 'triggered', 'by', 'earthquakes'],
#  ['elements', 'originating', 'with', 'product', 'earth'],
#  ['novel', 'written', 'by', 'historian'],
#  ['damage', 'caused', 'by', 'deregulation'],
#  ['anthrax', 'was', 'in', 'suitcase'],
#  ['chair', 'was', 'in', 'crate'],
#  ['club', 'consists', 'of', 'hotels'],
#  ['catastrophe', 'narrated', 'metaphor'],
#  ['bread', 'placed', 'in', 'basket'],
#  ['clutch', 'producing', 'of', 'capable', 'eggs'],
#  ['missile', 'placed', 'inside', 'canister'],
#  ['drama', 'criticised', 'by', 'watchdog'],
#  ['estrogen dominance', 'one', 'of', 'causes', 'of', 'cancer', 'osteoporosis'],
#  ['supplies', 'regulate', 'using', 'regulator'],
#  ['fly', 'of', 'jeans'],
#  ['information', 'found', 'sentence'],
#  ['kettle', 'drums'],
#  ['pictures', 'memories', 'were', 'bare', 'way', 'in', 'symbolised', 'box'],
#  ['man', 'watched', 'through', 'window'],
#  ['tribe', 'of', 'natives'],
#  ['group', 'took', 'bus'],
#  ['king', 'left', 'apartment'],
#  ['guide', 'offers', 'resources'],
#  ['superfluity', 'of', 'goods'],
#  ['wife', 'participant', 'in', 'blogosphere'],
#  ['mental disorders', 'featured', 'in', 'art'],
#  ['scan', 'started', 'at', 'potential'],
#  ['questions', 'raised', 'about', 'rules'],
#  ['parameter', 'passed', 'constructor'],
#  ['tail', 'long', 'feather'],
#  ['boat', 'sails', 'beach'],
#  ['early years', 'topic', 'discussion'],
#  ['basket', 'delivered', 'from', 'manager', 'village'],
#  ['germs', 'causing', 'illnesses'],
#  ['machine', 'stitching', 'stitches'],
#  ['experts', 'inserted', 'defence'],
#  ['shop', 'machined', 'diameter'],
#  ['tops', 'store', 'in', 'drawer'],
#  ['billions', 'poured', 'reforms'],
#  ['manufacturer', 'accept', 'right', 'pledge'],
#  ['definition', 'rooted', 'error'],
#  ['rock', 'with', 'power'],
#  ['container', 'put', 'inside', 'vault'],
#  ['system', 'with', 'emissions', 'carbon'],
#  ['subsection', 'applies', 'measure'],
#  ['oven', 'has', 'probe'],
#  ['rum', 'distilled', 'from', 'juice'],
#  ['material', 'from', 'article'],
#  ['blades', 'of', 'scissors'],
#  ['regiment', 'of', 'marksmen'],
#  ['picture', 'frame'],
#  ['papers', 'in', 'chemistry'],
#  ['disruption', 'caused', 'substance'],
#  ['landslide', 'triggered', 'by', 'event', 'rainfall'],
#  ['dieters', 'familiar', 'with', 'formula'],
#  ['wood', 'threw', 'bonfire'],
#  ['student', 'participation', 'in', 'governance'],
#  ['speech', 'outlined', 'measures'],
#  ['plane', 'took', 'passed', 'earth'],
#  ['market', 'rooted', 'in', 'structure'],
#  ['ozone layer', 'part', 'of', 'atmosphere'],
#  ['guidelines', 'used', 'by', 'lenders'],
#  ['officer', 'swore', 'oath'],
#  ['wine', 'rack'],
#  ['list', 'locked', 'in', 'safe'],
#  ['restaurant', 'advertised', 'website'],
#  ['wolf', 'to', 'down', 'continues', 'pack'],
#  ['rhumba', 'of', 'rattlesnakes'],
#  ['point', 'coming', 'from', 'background'],
#  ['examination process', 'carried', 'directives'],
#  ['poet', 'uses', 'imagery'],
#  ['leaflet', 'gives', 'entitlements'],
#  ['gas', 'caused', 'pyrolysis'],
#  ['queue', 'used', 'for', 'reports'],
#  ['files', 'put', 'into', 'directory'],
#  ['couple', 'hailed', 'from', 'town'],
#  ['bottle', 'finds', 'teeth'],
#  ['guns', 'locked', 'room'],
#  ['student',
#   'enrolled',
#   'take',
#   'processes',
#   'about',
#   'information',
#   'provides',
#   'university'],
#  ['scream', 'coming', 'from', 'chambers'],
#  ['products', 'of', 'worth', 'received', 'hamper'],
#  ['program', 'written', 'by', 'bio - scientist'],
#  ['emissions', 'released', 'hazard', 'atmosphere'],
#  ['cover', 'retracts', 'canister'],
#  ['house', 'at', 'seats', 'in', 'caused', 'senators'],
#  ['entitlements', 'inherited', 'property'],
#  ['claimant', 'proved', 'was', 'statement'],
#  ['prices', 'caused', 'collapse'],
#  ['cashier', 'opened', 'till'],
#  ['cells', 'moving', 'bone'],
#  ['visitors', 'travelled', 'to', 'vineyard'],
#  ['geodiversity', 'added', 'objective'],
#  ['pain', 'caused', 'by', 'entering', 'parasite'],
#  ['bevy', 'observing', 'of', 'possibility', 'has', 'roebucks'],
#  ['washer', 'works', 'water'],
#  ['reaction', 'starts', 'at', 'temperature'],
#  ['accommodation', 'comprises', 'of', 'hall'],
#  ['harlot', 'made', 'by', 'hornpipe'],
#  ['committee', 'member'],
#  ['paw', 'of', 'cat'],
#  ['unit', 'by', 'screened', 'companions', 'deployed', 'archers'],
#  ['weapon', 'was', 'inside', 'wooden box'],
#  ['stable', 'of', 'horses'],
#  ['job listings', 'added', 'careers section'],
#  ['conference', 'part', 'of', 'kortdage'],
#  ['cars',
#   'of',
#   'group',
#   'of',
#   'arrival',
#   'to',
#   'correspond',
#   'sequenced',
#   'signal'],
#  ['cable', 'of', 'part', 'to', 'atached', 'machine'],
#  ['challenges', 'of', 'aware', 'complacent', 'recruitment'],
#  ['button', 'from', 'unscrewing', 'by', 'made', 'mouse'],
#  ['towns', 'founded', 'year'],
#  ['slice', 'placed', 'in', 'beaker'],
#  ['discovery', 'made', 'by', 'worker'],
#  ['psychiatrist', 'killed', 'with', 'drugs'],
#  ['handgrip', 'on', 'mounted', 'wheelchair'],
#  ['restaurant', 'creates', 'using', 'products'],
#  ['practices', 'on', 'seminar', 'for', 'engineers'],
#  ['poster', 'advertises', 'exhibition'],
#  ['alcohol', 'distilled', 'from', 'steam bath'],
#  ['survey', 'documents', 'opinions'],
#  ['suitcase', 'nothing', 'with', 'came', 'oranges'],
#  ['sample', 'enclosed', 'in', 'vial'],
#  ['brothers', 'wrote', 'movie'],
#  ['song', 'with', 'find', 'writers'],
#  ['tittering', 'of', 'magpies'],
#  ['police', 'report'],
#  ['flight', 'arrived', 'gate'],
#  ['barley', 'spirits'],
#  ['bank', 'one', 'bubble'],
#  ['detachment', 'of', 'volunteers'],
#  ['helix', 'runs', 'nucleotide'],
#  ['joy', 'of', 'amount', 'derive', 'from', 'teaching'],
#  ['galaxy', 'of', 'footballers'],
#  ['combination', 'of', 'razadyne', 'inhibitors'],
#  ['horns', 'grows', 'from', 'mountains'],
#  ['problem', 'ensued', 'from', 'events'],
#  ['book', 'contained', 'recipes', 'things', 'as', 'coloring'],
#  ['revellers', 'sent', 'party mode'],
#  ['jam', 'put', 'into', 'canteen'],
#  ['revolution', 'triggered', 'writing'],
#  ['passage', 'describes', 'flag'],
#  ['statement', 'contains', 'account'],
#  ['bristles', 'of', 'brush'],
#  ['molding', 'blew', 'paperboard'],
#  ['agency', 'investigating', 'allegations'],
#  ['biofilm', 'grows', 'from', 'inside'],
#  ['vibration', 'caused', 'by', 'train'],
#  ['offer', 'was', 'from', 'company'],
#  ['feature', 'added', 'software'],
#  ['formation', 'of', 'dragoons'],
#  ['hull', 'of', 'boat'],
#  ['metal cube', 'enclosed', 'jacket'],
#  ['surges', 'caused', 'by', 'circuits', 'lightning'],
#  ['design', 'drew', 'artist'],
#  ['damage', 'caused', 'by', 'crisis'],
#  ['mycoses', 'caused', 'by', 'group', 'of', 'fungi'],
#  ['crisis', 'triggered', 'by', 'collapse'],
#  ['microphone', 'converts', 'signal'],
#  ['mass', 'takes', 'in', 'movement'],
#  ['disk', 'produced', 'image'],
#  ['implants', 'inserted', 'into', 'bone'],
#  ['transmitters', 'implanted', 'orangutans'],
#  ['hygrometer', 'manufactured', 'in', 'spring'],
#  ['menage', 'of', 'shadows'],
#  ['goatfish', 'use', 'pair', 'of', 'barbels'],
#  ['billion', 'poured', 'economy'],
#  ['items', 'removed', 'plastic bag'],
#  ['wall', 'on', 'painting', 'singing', 'shop'],
#  ['friends', 'moved', 'into', 'apartment'],
#  ['closet', 'writer'],
#  ['report', 'on', 'application'],
#  ['swelling', 'caused', 'by', 'expansion'],
#  ['setbacks', 'ensued', 'from', 'flooding', 'design'],
#  ['mattress', 'with', 'money'],
#  ['bisexuality', 'explores', 'book'],
#  ['researchers', 'studied', 'through', 'exams'],
#  ['toxic materials', 'leak', 'water'],
#  ...]
