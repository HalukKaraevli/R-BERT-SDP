# %%
import os
import re

# %%
os.listdir('./results/LAL_parser/train')
# Out:
# ['example_sentences.txt',
#  'output_synconst_0.txt',
#  'output_synconst_1.txt',
#  'output_synconst_2.txt',
#  'output_synconst_3.txt',
#  'output_synconst_4.txt',
#  'output_synconst_5.txt',
#  'output_synconst_6.txt',
#  'output_synconst_7.txt',
#  'output_syndephead_0.txt',
#  'output_syndephead_1.txt',
#  'output_syndephead_2.txt',
#  'output_syndephead_3.txt',
#  'output_syndephead_4.txt',
#  'output_syndephead_5.txt',
#  'output_syndephead_6.txt',
#  'output_syndephead_7.txt',
#  'output_syndeplabel_0.txt',
#  'output_syndeplabel_1.txt',
#  'output_syndeplabel_2.txt',
#  'output_syndeplabel_3.txt',
#  'output_syndeplabel_4.txt',
#  'output_syndeplabel_5.txt',
#  'output_syndeplabel_6.txt',
#  'output_syndeplabel_7.txt']

# %%
dp_lines = []
for x in os.listdir('./results/LAL_parser/test'):
    if x.startswith('output_synconst'):
        dp_lines.extend(open('./results/LAL_parser/test/' + x,'r').readlines())

# %%
dp_lines[0]
# Out:
# '(S (NP (DT the) (ADJP (RBS most) (JJ common)) (NNS audits)) (VP (VBD were) (PP (IN about) (NP (NN waste) (CC and) (NN recycling)))) (. .))\n'

# %%
tokens_with_pos = [re.findall('([^\s\(]+) ([\w.;"\':_-]+)\)',x) for x in dp_lines]

# %%
tokens_with_pos
# Out:
# [[('DT', 'the'),
#   ('RBS', 'most'),
#   ('JJ', 'common'),
#   ('NNS', 'audits'),
#   ('VBD', 'were'),
#   ('IN', 'about'),
#   ('NN', 'waste'),
#   ('CC', 'and'),
#   ('NN', 'recycling'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'company'),
#   ('VBZ', 'fabricates'),
#   ('JJ', 'plastic'),
#   ('NNS', 'chairs'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'school'),
#   ('NN', 'master'),
#   ('VBZ', 'teaches'),
#   ('DT', 'the'),
#   ('NN', 'lesson'),
#   ('IN', 'with'),
#   ('DT', 'a'),
#   ('NN', 'stick'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'suspect'),
#   ('VBD', 'dumped'),
#   ('DT', 'the'),
#   ('JJ', 'dead'),
#   ('NN', 'body'),
#   ('IN', 'into'),
#   ('DT', 'a'),
#   ('JJ', 'local'),
#   ('NN', 'reservoir'),
#   ('.', '.')],
#  [('JJ', 'avian'),
#   ('NN', 'influenza'),
#   ('VBZ', 'is'),
#   ('DT', 'an'),
#   ('JJ', 'infectious'),
#   ('NN', 'disease'),
#   ('IN', 'of'),
#   ('NNS', 'birds'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('NN', 'type'),
#   ('DT', 'a'),
#   ('NNS', 'strains'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'influenza'),
#   ('NN', 'virus'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'ear'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'african'),
#   ('NN', 'elephant'),
#   ('VBZ', 'is'),
#   ('RB', 'significantly'),
#   ('JJR', 'larger'),
#   (':', '-'),
#   (':', '-'),
#   ('VBG', 'measuring'),
#   ('CD', '183'),
#   ('NN', 'cm'),
#   ('IN', 'by'),
#   ('CD', '114'),
#   ('NN', 'cm'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'bush'),
#   ('NN', 'elephant'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'child'),
#   ('VBZ', 'is'),
#   ('VBN', 'told'),
#   ('DT', 'a'),
#   ('NN', 'lie'),
#   ('IN', 'for'),
#   ('JJ', 'several'),
#   ('NNS', 'years'),
#   ('IN', 'by'),
#   ('PRP$', 'their'),
#   ('NNS', 'parents'),
#   ('IN', 'before'),
#   ('PRP', 'he'),
#   ('PRP', 'she'),
#   ('VBZ', 'realizes'),
#   ('IN', 'that'),
#   ('DT', 'a'),
#   ('JJ', 'santa'),
#   ('NN', 'claus'),
#   ('VBZ', 'does'),
#   ('RB', 'not'),
#   ('VB', 'exist'),
#   ('.', '.')],
#  [('VB', 'skype'),
#   ('DT', 'a'),
#   ('JJ', 'free'),
#   ('NN', 'software'),
#   ('VBZ', 'allows'),
#   ('DT', 'a'),
#   ('NN', 'hookup'),
#   ('IN', 'of'),
#   ('JJ', 'multiple'),
#   ('NN', 'computer'),
#   ('NNS', 'users'),
#   ('TO', 'to'),
#   ('VB', 'join'),
#   ('IN', 'in'),
#   ('DT', 'an'),
#   ('JJ', 'online'),
#   ('NN', 'conference'),
#   ('NN', 'call'),
#   ('IN', 'without'),
#   ('VBG', 'incurring'),
#   ('DT', 'any'),
#   ('NN', 'telephone'),
#   ('NNS', 'costs'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('VBG', 'disgusting'),
#   ('NN', 'scene'),
#   ('VBD', 'was'),
#   ('NN', 'retaliation'),
#   ('IN', 'against'),
#   ('PRP$', 'her'),
#   ('NN', 'brother'),
#   ('NN', 'philip'),
#   ('WP', 'who'),
#   ('VBZ', 'rents'),
#   ('DT', 'the'),
#   ('NN', 'room'),
#   ('IN', 'inside'),
#   ('DT', 'this'),
#   ('NN', 'apartment'),
#   ('NN', 'house'),
#   ('IN', 'on'),
#   ('JJ', 'lombard'),
#   ('NN', 'street'),
#   ('.', '.')],
#  [('DT', 'this'),
#   ('NN', 'thesis'),
#   ('VBZ', 'defines'),
#   ('DT', 'the'),
#   ('JJ', 'clinical'),
#   ('NNS', 'characteristics'),
#   ('IN', 'of'),
#   ('JJ', 'amyloid'),
#   ('NN', 'disease'),
#   ('.', '.')],
#  [('CD', 'ten'),
#   ('CD', 'million'),
#   ('NN', 'quake'),
#   ('NNS', 'survivors'),
#   ('VBD', 'moved'),
#   ('IN', 'into'),
#   ('NN', 'makeshift'),
#   ('NNS', 'houses'),
#   ('.', '.')],
#  [('IN', 'on'),
#   ('DT', 'a'),
#   ('NN', 'friend'),
#   ('NN', 'advice'),
#   ('NN', 'i'),
#   ('VBD', 'purchased'),
#   ('DT', 'a'),
#   ('NN', 'sauerkraut'),
#   ('CC', 'and'),
#   ('NN', 'kimchi'),
#   ('NN', 'maker'),
#   ('RB', 'here'),
#   ('CC', 'and'),
#   ('PRP', 'it'),
#   ('VBZ', 'is'),
#   ('RB', 'just'),
#   ('JJ', 'fabulous'),
#   ('CC', 'and'),
#   ('JJ', 'cheap'),
#   ('RB', 'too'),
#   ('.', '.')],
#  [('JJ', 'nasa'),
#   ('NN', 'kepler'),
#   ('NN', 'mission'),
#   ('VBZ', 'sends'),
#   ('RB', 'names'),
#   ('IN', 'into'),
#   ('NN', 'space'),
#   ('.', '.')],
#  [('IN', 'as'),
#   ('DT', 'a'),
#   ('NN', 'landscape'),
#   ('NN', 'company'),
#   ('IN', 'in'),
#   ('NN', 'atlanta'),
#   ('PRP', 'we'),
#   ('VBP', 'know'),
#   ('WDT', 'which'),
#   ('NNS', 'plants'),
#   ('VBP', 'thrive'),
#   ('IN', 'in'),
#   ('DT', 'this'),
#   ('VBG', 'planting'),
#   ('NN', 'zone'),
#   ('CC', 'and'),
#   ('VB', 'know'),
#   ('DT', 'the'),
#   ('JJ', 'optimum'),
#   ('NN', 'landscaping'),
#   ('NNS', 'designs'),
#   ('IN', 'for'),
#   ('JJ', 'local'),
#   ('NNS', 'yards'),
#   ('CC', 'and'),
#   ('NN', 'business'),
#   ('.', '.')],
#  [('IN', 'as'),
#   ('NN', 'i'),
#   ('VBD', 'was'),
#   ('VBG', 'contemplating'),
#   ('IN', 'if'),
#   ('VBN', 'i'),
#   ('VBD', 'had'),
#   ('DT', 'a'),
#   ('NN', 'favorite'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'pink'),
#   ('NN', 'category'),
#   ('DT', 'a'),
#   ('NN', 'gift'),
#   ('VBN', 'arrived'),
#   ('IN', 'from'),
#   ('DT', 'a'),
#   ('JJ', 'sweet'),
#   ('NN', 'friend'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'male'),
#   ('VBD', 'took'),
#   ('RP', 'over'),
#   ('DT', 'the'),
#   ('JJ', 'entire'),
#   ('NN', 'care'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'young'),
#   ('WDT', 'that'),
#   ('VBD', 'had'),
#   ('VBN', 'left'),
#   ('DT', 'the'),
#   ('JJS', 'nest'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'famous'),
#   ('NN', 'actress'),
#   ('VBN', 'arrived'),
#   ('IN', 'at'),
#   ('DT', 'the'),
#   ('NN', 'airport'),
#   ('.', '.')],
#  [('DT', 'an'),
#   ('NN', 'ftp'),
#   ('NN', 'server'),
#   ('VBZ', 'is'),
#   ('DT', 'an'),
#   ('JJ', 'inexpensive'),
#   ('CC', 'and'),
#   ('RB', 'relatively'),
#   ('JJ', 'simple'),
#   ('TO', 'to'),
#   ('VB', 'operate'),
#   ('NN', 'tool'),
#   ('WDT', 'that'),
#   ('VBZ', 'works'),
#   ('JJ', 'great'),
#   ('IN', 'for'),
#   ('VBG', 'filesharing'),
#   ('IN', 'over'),
#   ('DT', 'the'),
#   ('NN', 'internet'),
#   ('.', '.')],
#  [('NN', 'beneath'),
#   ('DT', 'this'),
#   ('NN', 'invocation'),
#   ('EX', 'there'),
#   ('VBZ', 'is'),
#   ('DT', 'a'),
#   ('NN', 'zoo'),
#   ('IN', 'of'),
#   ('JJ', 'fearsome'),
#   ('NNS', 'beasts'),
#   ('VBG', 'including'),
#   ('JJ', 'several'),
#   ('NN', 'man'),
#   (':', '-'),
#   ('NNS', 'eaters'),
#   ('RB', 'as'),
#   ('RB', 'well'),
#   ('IN', 'as'),
#   ('NNS', 'sphinxes'),
#   ('IN', 'with'),
#   ('NNS', 'lions'),
#   ('NNS', 'bodies'),
#   ('CC', 'and'),
#   ('JJ', 'human'),
#   ('NNS', 'heads'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'song'),
#   ('VBD', 'was'),
#   ('VBN', 'composed'),
#   ('IN', 'for'),
#   ('DT', 'a'),
#   ('JJ', 'famous'),
#   ('JJ', 'brazilian'),
#   ('NN', 'musician'),
#   ('.', '.')],
#  [('DT', 'this'),
#   ('JJ', 'outline'),
#   ('VBZ', 'focuses'),
#   ('IN', 'on'),
#   ('NN', 'spirituality'),
#   ('NN', 'esotericism'),
#   ('NN', 'mysticism'),
#   ('NN', 'religion'),
#   ('CC', 'and'),
#   ('CC', 'or'),
#   ('NN', 'parapsychology'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'bomb'),
#   ('VBD', 'was'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'suitcase'),
#   ('VBN', 'loaded'),
#   ('IN', 'in'),
#   ('NN', 'frankfurt'),
#   ('CC', 'and'),
#   ('VBD', 'transferred'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('VBN', 'doomed'),
#   ('NN', 'boeing'),
#   ('CD', '747'),
#   ('IN', 'in'),
#   ('NN', 'london'),
#   ('.', '.')],
#  [('JJ', 'i'),
#   ('VBD', 'spent'),
#   ('DT', 'a'),
#   ('NN', 'year'),
#   ('VBG', 'working'),
#   ('IN', 'for'),
#   ('DT', 'a'),
#   ('NN', 'software'),
#   ('NN', 'company'),
#   ('TO', 'to'),
#   ('VB', 'pay'),
#   ('RP', 'off'),
#   ('PRP$', 'my'),
#   ('NN', 'college'),
#   ('NNS', 'loans'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'captain'),
#   ('CC', 'and'),
#   ('DT', 'the'),
#   ('NN', 'crew'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'steve'),
#   ('NN', 'irwin'),
#   ('VBP', 'are'),
#   ('JJ', 'grateful'),
#   ('IN', 'for'),
#   ('DT', 'the'),
#   ('NN', 'support'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'city'),
#   ('IN', 'of'),
#   ('NN', 'fremantle'),
#   ('CC', 'and'),
#   ('NN', 'mayor'),
#   ('NN', 'brad'),
#   ('NN', 'pettitt'),
#   ('IN', 'for'),
#   ('VBG', 'hosting'),
#   ('DT', 'the'),
#   ('NN', 'event'),
#   ('.', '.')],
#  [('JJ', 'organic'),
#   ('NN', 'sesame'),
#   ('NN', 'oil'),
#   ('VBZ', 'has'),
#   ('DT', 'an'),
#   ('JJ', 'anti'),
#   (':', '-'),
#   ('NN', 'bacterial'),
#   ('CC', 'and'),
#   ('JJ', 'anti'),
#   ('NN', 'imflammatory'),
#   ('NN', 'effect'),
#   ('.', '.')],
#  [('NN', 'mileson'),
#   ('VBZ', 'has'),
#   ('VBN', 'sold'),
#   ('PRP$', 'his'),
#   ('JJ', 'humble'),
#   ('NN', 'abode'),
#   ('TO', 'to'),
#   ('DT', 'a'),
#   ('NN', 'housing'),
#   ('NN', 'developer'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'same'),
#   ('NN', 'effect'),
#   ('VBZ', 'is'),
#   ('VBN', 'achieved'),
#   ('DT', 'the'),
#   ('JJ', 'traditional'),
#   ('NN', 'way'),
#   ('IN', 'with'),
#   ('DT', 'a'),
#   ('NN', 'team'),
#   ('IN', 'of'),
#   ('NNS', 'workers'),
#   ('IN', 'like'),
#   ('NN', 'keebler'),
#   ('NNS', 'elves'),
#   ('.', '.')],
#  [('PRP', 'he'),
#   ('VBZ', 'has'),
#   ('VBN', 'built'),
#   ('DT', 'a'),
#   ('JJ', 'formidable'),
#   ('NN', 'reputation'),
#   ('VBG', 'writing'),
#   ('JJ', 'powerful'),
#   ('NN', 'dramas'),
#   ('IN', 'for'),
#   ('DT', 'the'),
#   ('NN', 'stage'),
#   ('CC', 'and'),
#   ('NN', 'screen'),
#   ('VBN', 'based'),
#   ('IN', 'on'),
#   ('JJ', 'real'),
#   ('NNS', 'events'),
#   ('CC', 'or'),
#   ('RB', 'socially'),
#   ('JJ', 'vital'),
#   ('NNS', 'issues'),
#   ('.', '.')],
#  [('PRP', 'he'),
#   ('VBZ', 'produces'),
#   ('NNS', 'drawings'),
#   ('CC', 'and'),
#   ('NNS', 'videos'),
#   ('WDT', 'that'),
#   ('VBP', 'have'),
#   ('VBN', 'been'),
#   ('VBN', 'shown'),
#   ('IN', 'in'),
#   ('NNS', 'museums'),
#   ('IN', 'in'),
#   ('NN', 'europe'),
#   ('CC', 'and'),
#   ('NN', 'america'),
#   ('.', '.')],
#  [('RB', 'therefore'),
#   ('JJ', 'nowadays'),
#   ('NN', 'china'),
#   ('VBZ', 'is'),
#   ('DT', 'the'),
#   ('JJ', 'complex'),
#   ('NN', 'mixture'),
#   ('IN', 'of'),
#   ('JJ', 'different'),
#   ('NNS', 'cultures'),
#   ('IN', 'from'),
#   ('JJ', 'various'),
#   ('NNS', 'epochs'),
#   ('.', '.')],
#  [('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'hundreds'),
#   ('IN', 'of'),
#   ('NNS', 'strains'),
#   ('IN', 'of'),
#   ('JJ', 'avian'),
#   ('NN', 'influenza'),
#   ('DT', 'a'),
#   ('VBZ', 'viruses'),
#   ('RB', 'only'),
#   ('CD', 'four'),
#   ('VBP', 'have'),
#   ('VBN', 'caused'),
#   ('JJ', 'human'),
#   ('NNS', 'infections'),
#   (':', ':'),
#   ('NN', 'h5n1'),
#   ('NN', 'h7n3'),
#   ('NN', 'h7n7'),
#   ('CC', 'and'),
#   ('NN', 'h9n2'),
#   ('.', '.')],
#  [('JJ', 'many'),
#   ('IN', 'of'),
#   ('PRP$', 'his'),
#   ('JJ', 'literary'),
#   ('NNS', 'pieces'),
#   ('NN', 'narrate'),
#   ('CC', 'and'),
#   ('NN', 'mention'),
#   ('NNS', 'stories'),
#   ('WDT', 'that'),
#   ('VBD', 'took'),
#   ('NN', 'place'),
#   ('IN', 'in'),
#   ('NN', 'lipa'),
#   ('.', '.')],
#  [('WRB', 'when'),
#   ('NN', 'i'),
#   ('VBP', 'am'),
#   ('VBG', 'walking'),
#   ('RB', 'alone'),
#   ('JJ', 'i'),
#   ('VBP', 'count'),
#   ('DT', 'the'),
#   ('NNS', 'steps'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'stairs'),
#   ('CC', 'and'),
#   ('NN', 'i'),
#   ('RB', 'also'),
#   ('RB', 'guess'),
#   ('RB', 'approximately'),
#   ('WRB', 'how'),
#   ('JJ', 'many'),
#   ('NNS', 'steps'),
#   ('VBP', 'are'),
#   ('VBN', 'left'),
#   ('IN', 'till'),
#   ('JJ', 'i'),
#   ('VBP', 'reach'),
#   ('DT', 'the'),
#   ('JJ', 'next'),
#   ('NN', 'street'),
#   ('.', '.')],
#  [('RB', 'essentially'),
#   ('DT', 'the'),
#   ('NNS', 'blisters'),
#   ('WDT', 'that'),
#   ('VBP', 'appear'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'mouth'),
#   ('VBP', 'are'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('NNS', 'herpes'),
#   ('JJ', 'simplex'),
#   ('NN', 'virus'),
#   ('NN', 'type'),
#   ('CD', '1'),
#   ('NN', 'hsv'),
#   (':', '-'),
#   ('CD', '1'),
#   ('IN', 'for'),
#   ('JJ', 'short'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'man'),
#   ('IN', 'at'),
#   ('DT', 'the'),
#   ('NN', 'helm'),
#   ('VBD', 'was'),
#   ('VBG', 'watching'),
#   ('DT', 'the'),
#   ('NN', 'luff'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'sail'),
#   ('CC', 'and'),
#   ('VBG', 'whistling'),
#   ('RB', 'away'),
#   ('RB', 'gently'),
#   ('TO', 'to'),
#   ('PRP', 'himself'),
#   ('CC', 'and'),
#   ('DT', 'that'),
#   ('VBD', 'was'),
#   ('DT', 'the'),
#   ('JJ', 'only'),
#   ('NN', 'sound'),
#   ('VBG', 'excepting'),
#   ('DT', 'the'),
#   ('NN', 'swish'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'sea'),
#   ('.', '.')],
#  [('RB', 'still'),
#   ('VBZ', 'further'),
#   ('DT', 'the'),
#   ('NN', 'circuit'),
#   ('VBZ', 'comprises'),
#   ('DT', 'a'),
#   ('JJ', 'digital'),
#   ('NN', 'adder'),
#   ('CC', 'and'),
#   ('DT', 'an'),
#   ('NN', 'analog'),
#   (':', '-'),
#   ('TO', 'to'),
#   (':', '-'),
#   ('JJ', 'digital'),
#   ('NN', 'converter'),
#   ('IN', 'with'),
#   ('DT', 'an'),
#   ('NN', 'analog'),
#   ('NN', 'input'),
#   ('VBN', 'connected'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('NN', 'output'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'operational'),
#   ('NN', 'amplifier'),
#   ('CC', 'and'),
#   ('DT', 'a'),
#   ('JJ', 'digital'),
#   ('NN', 'output'),
#   ('VBN', 'connected'),
#   ('TO', 'to'),
#   ('DT', 'a'),
#   ('JJ', 'first'),
#   ('NN', 'input'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'digital'),
#   ('NN', 'adder'),
#   ('.', '.')],
#  [('NN', 'dolf'),
#   ('VBZ', 'oehler'),
#   ('DT', 'a'),
#   ('NN', 'leader'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('JJ', 'leftist'),
#   ('NN', 'camp'),
#   ('IN', 'of'),
#   ('NN', 'heine'),
#   ('NNS', 'champions'),
#   ('IN', 'since'),
#   ('DT', 'the'),
#   ('CD', '1970s'),
#   ('VBD', 'gathered'),
#   ('DT', 'a'),
#   ('NN', 'group'),
#   ('IN', 'of'),
#   ('JJ', 'likeminded'),
#   ('NNS', 'critics'),
#   ('IN', 'for'),
#   ('DT', 'this'),
#   ('NN', 'symposium'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'cartridge'),
#   ('VBD', 'was'),
#   ('VBN', 'marked'),
#   ('IN', 'as'),
#   ('JJ', 'empty'),
#   ('RB', 'even'),
#   ('IN', 'with'),
#   ('NN', 'ink'),
#   ('IN', 'in'),
#   ('DT', 'both'),
#   ('NNS', 'chambers'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'pod'),
#   ('IN', 'of'),
#   ('JJ', 'sperm'),
#   ('NNS', 'whales'),
#   ('VBD', 'was'),
#   ('VBN', 'beached'),
#   ('IN', 'on'),
#   ('JJ', 'italy'),
#   ('JJ', 'southern'),
#   ('NN', 'coast'),
#   ('CC', 'and'),
#   ('IN', 'at'),
#   ('JJS', 'least'),
#   ('CD', 'five'),
#   ('VBN', 'died'),
#   ('IN', 'in'),
#   ('WP', 'what'),
#   ('NNS', 'experts'),
#   ('VBD', 'said'),
#   ('VBD', 'was'),
#   ('DT', 'a'),
#   ('JJ', 'rare'),
#   ('CC', 'and'),
#   ('VBG', 'puzzling'),
#   ('NN', 'mass'),
#   ('VBG', 'beaching'),
#   ('IN', 'for'),
#   ('PDT', 'such'),
#   ('DT', 'a'),
#   ('JJ', 'large'),
#   ('NNS', 'species'),
#   ('.', '.')],
#  [('NNS', 'roundworms'),
#   ('CC', 'or'),
#   ('NNS', 'ascarids'),
#   ('VBP', 'are'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('DT', 'an'),
#   ('JJ', 'intestinal'),
#   ('NN', 'parasite'),
#   ('VBN', 'called'),
#   ('NN', 'toxocara'),
#   ('NN', 'canis'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'subject'),
#   ('IN', 'of'),
#   ('NN', 'imply'),
#   ('VBZ', 'is'),
#   ('DT', 'the'),
#   ('NN', 'source'),
#   ('IN', 'of'),
#   ('DT', 'an'),
#   ('NN', 'implication'),
#   ('IN', 'while'),
#   ('DT', 'the'),
#   ('NN', 'subject'),
#   ('IN', 'of'),
#   ('NN', 'infer'),
#   ('VBZ', 'is'),
#   ('DT', 'the'),
#   ('NN', 'recipient'),
#   ('IN', 'of'),
#   ('DT', 'an'),
#   ('NN', 'implication'),
#   ('.', '.')],
#  [('PRP$', 'my'),
#   ('NN', 'cat'),
#   ('VBZ', 'has'),
#   ('DT', 'a'),
#   ('NN', 'problem'),
#   ('IN', 'with'),
#   ('PRP$', 'his'),
#   ('NN', 'paw'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'treaty'),
#   ('VBZ', 'establishes'),
#   ('DT', 'a'),
#   ('JJ', 'double'),
#   ('NN', 'majority'),
#   ('NN', 'rule'),
#   ('IN', 'for'),
#   ('NN', 'council'),
#   ('NNS', 'decisions'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'accident'),
#   ('VBZ', 'has'),
#   ('VBN', 'spread'),
#   ('NN', 'oil'),
#   ('IN', 'into'),
#   ('DT', 'the'),
#   ('NN', 'ocean'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('JJ', 'tidal'),
#   ('NN', 'wave'),
#   ('IN', 'of'),
#   ('NN', 'talent'),
#   ('VBZ', 'has'),
#   ('VBN', 'emanated'),
#   ('IN', 'from'),
#   ('DT', 'this'),
#   ('JJ', 'lush'),
#   ('NN', 'village'),
#   ('.', '.')],
#  [('DT', 'these'),
#   ('NNS', 'coins'),
#   ('VBP', 'are'),
#   ('VBN', 'enclosed'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('JJ', 'clear'),
#   ('JJ', 'hard'),
#   ('NN', 'plastic'),
#   ('NN', 'case'),
#   ('IN', 'with'),
#   ('DT', 'a'),
#   ('NN', 'blue'),
#   ('NN', 'background'),
#   ('WDT', 'that'),
#   ('VBZ', 'is'),
#   ('VBN', 'packaged'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('JJ', 'blue'),
#   ('NN', 'box'),
#   ('.', '.')],
#  [('IN', 'by'),
#   ('VBG', 'dividing'),
#   ('DT', 'the'),
#   ('NN', 'space'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'kitchen'),
#   ('NN', 'drawer'),
#   ('WRB', 'where'),
#   ('PRP', 'you'),
#   ('VB', 'keep'),
#   ('DT', 'all'),
#   ('PRP$', 'your'),
#   ('NN', 'cooking'),
#   ('IN', 'utensils'),
#   ('PRP', 'you'),
#   ('VBD', 'grouped'),
#   ('NNS', 'items'),
#   ('IN', 'by'),
#   ('NN', 'size'),
#   ('CC', 'or'),
#   ('NN', 'purpose'),
#   ('.', '.')],
#  [('RB', 'then'),
#   ('DT', 'the'),
#   ('NN', 'target'),
#   ('JJ', 'pet'),
#   ('NN', 'bottle'),
#   ('VBD', 'was'),
#   ('VBN', 'put'),
#   ('IN', 'inside'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('NN', 'metal'),
#   ('NN', 'container'),
#   ('WDT', 'which'),
#   ('VBD', 'was'),
#   ('VBN', 'grounded'),
#   ('.', '.')],
#  [('NN', 'news'),
#   ('NNS', 'programs'),
#   ('VBD', 'commented'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('NN', 'violence'),
#   ('IN', 'from'),
#   ('DT', 'the'),
#   ('NN', 'game'),
#   ('CC', 'and'),
#   ('JJ', 'expressed'),
#   ('NNS', 'worries'),
#   ('IN', 'on'),
#   ('WRB', 'how'),
#   ('PRP', 'it'),
#   ('MD', 'would'),
#   ('VB', 'affect'),
#   ('DT', 'the'),
#   ('NNS', 'players'),
#   ('NNS', 'personalities'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'narrative'),
#   ('VBZ', 'comprises'),
#   ('DT', 'the'),
#   ('NN', 'interplay'),
#   ('IN', 'of'),
#   ('CD', 'two'),
#   ('NNS', 'themes'),
#   ('WDT', 'that'),
#   ('VBP', 'are'),
#   ('RB', 'woven'),
#   ('RB', 'together'),
#   ('IN', 'as'),
#   ('PRP', 'it'),
#   ('VBZ', 'criss'),
#   (':', '-'),
#   ('NNS', 'crosses'),
#   ('RB', 'back'),
#   ('CC', 'and'),
#   ('NN', 'forth'),
#   ('IN', 'between'),
#   ('DT', 'the'),
#   ('NN', 'life'),
#   ('IN', 'of'),
#   ('JJ', 'nineteen'),
#   ('NN', 'year'),
#   ('JJ', 'old'),
#   ('NN', 'greg'),
#   ('NN', 'kowalski'),
#   ('NN', 'desire'),
#   ('TO', 'to'),
#   ('VB', 'become'),
#   ('DT', 'a'),
#   ('NN', 'firefighter'),
#   ('CC', 'and'),
#   ('PRP$', 'his'),
#   ('NN', 'heart'),
#   (':', '-'),
#   ('VBG', 'rending'),
#   ('NN', 'life'),
#   ('VBG', 'growing'),
#   ('RP', 'up'),
#   ('IN', 'in'),
#   ('NN', 'saginaw'),
#   ('NN', 'michigan'),
#   ('WRB', 'where'),
#   ('PRP', 'he'),
#   ('VBD', 'had'),
#   ('TO', 'to'),
#   ('VB', 'endure'),
#   ('DT', 'the'),
#   ('JJ', 'physical'),
#   ('CC', 'and'),
#   ('JJ', 'verbal'),
#   ('NN', 'abuse'),
#   ('VBN', 'handed'),
#   ('RP', 'out'),
#   ('IN', 'by'),
#   ('PRP$', 'his'),
#   ('VBG', 'appalling'),
#   ('NN', 'father'),
#   ('.', '.')],
#  [('IN', 'as'),
#   ('NN', 'vinay'),
#   ('VBN', 'collapsed'),
#   ('IN', 'in'),
#   ('NN', 'pain'),
#   ('DT', 'the'),
#   ('NNS', 'villagers'),
#   ('VBD', 'poured'),
#   ('RP', 'acid'),
#   ('IN', 'into'),
#   ('PRP$', 'his'),
#   ('NNS', 'eyes'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'room'),
#   ('VBD', 'was'),
#   ('VBN', 'filled'),
#   ('IN', 'with'),
#   ('JJ', 'huge'),
#   ('NN', 'jack'),
#   (':', '-'),
#   ('DT', 'the'),
#   (':', '-'),
#   ('NN', 'dripper'),
#   ('NNS', 'canvases'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'gulp'),
#   ('IN', 'of'),
#   ('NNS', 'magpies'),
#   ('RB', 'just'),
#   ('VBD', 'left'),
#   ('IN', 'after'),
#   ('DT', 'a'),
#   ('JJ', 'quick'),
#   ('NN', 'breakfast'),
#   ('IN', 'of'),
#   ('NNS', 'peanuts'),
#   ('CC', 'and'),
#   ('NN', 'cookie'),
#   ('NNS', 'crumbs'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'proposal'),
#   ('VBD', 'was'),
#   ('VBN', 'debated'),
#   ('CC', 'and'),
#   ('RB', 'enthusiastically'),
#   ('VBN', 'endorsed'),
#   ('IN', 'in'),
#   ('CD', '2002'),
#   ('IN', 'by'),
#   ('DT', 'a'),
#   ('NN', 'convocation'),
#   ('IN', 'of'),
#   ('JJ', 'international'),
#   ('NNS', 'scholars'),
#   ('WDT', 'that'),
#   ('VBD', 'included'),
#   ('JJ', 'many'),
#   ('JJ', 'prominent'),
#   ('NNS', 'academics'),
#   ('IN', 'among'),
#   ('PRP', 'them'),
#   ('NNS', 'scientists'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'stature'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'late'),
#   ('NN', 'h'),
#   ('NN', 'curien'),
#   ('NN', 'h'),
#   ('NN', 'varmus'),
#   ('NN', 'p'),
#   ('NN', 'crutzen'),
#   ('CC', 'and'),
#   ('NN', 'j'),
#   ('NN', 'sachs'),
#   ('.', '.')],
#  [('IN', 'in'),
#   ('NN', 'south'),
#   ('NN', 'africa'),
#   ('WDT', 'which'),
#   ('VBZ', 'has'),
#   ('CD', 'one'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJS', 'best'),
#   ('NN', 'police'),
#   ('TO', 'to'),
#   ('JJ', 'public'),
#   ('NNS', 'ratios'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('NN', 'continent'),
#   ('DT', 'the'),
#   ('NN', 'share'),
#   ('IN', 'of'),
#   ('NNS', 'murders'),
#   ('WDT', 'that'),
#   ('VBP', 'result'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'conviction'),
#   ('VBZ', 'is'),
#   ('IN', 'about'),
#   ('CD', '18'),
#   ('VBN', 'compared'),
#   ('TO', 'to'),
#   ('CD', '56'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('PRP', 'us'),
#   ('CC', 'and'),
#   ('CD', '61'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'uk'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'group'),
#   ('IN', 'of'),
#   ('NNS', 'monkeys'),
#   ('WP', 'who'),
#   ('VBD', 'escaped'),
#   ('IN', 'from'),
#   ('DT', 'an'),
#   ('NN', 'enclosure'),
#   ('IN', 'at'),
#   ('JJ', 'edinburgh'),
#   ('NN', 'zoo'),
#   ('VBP', 'are'),
#   ('CD', 'one'),
#   ('NN', 'step'),
#   ('IN', 'from'),
#   ('VBG', 'being'),
#   ('VBN', 'caught'),
#   ('.', '.')],
#  [('NNS', 'people'),
#   ('RB', 'now'),
#   ('VBP', 'post'),
#   ('PRP$', 'their'),
#   ('NNS', 'opinions'),
#   ('TO', 'to'),
#   ('DT', 'this'),
#   ('NN', 'blog'),
#   ('.', '.')],
#  [('NN', 'traffic'),
#   ('NNS', 'vibrations'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('NN', 'street'),
#   ('IN', 'outside'),
#   ('VBD', 'had'),
#   ('VBN', 'caused'),
#   ('DT', 'the'),
#   ('NN', 'movement'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'light'),
#   ('.', '.')],
#  [('NNS', 'poodles'),
#   ('IN', 'of'),
#   ('DT', 'all'),
#   ('NNS', 'types'),
#   ('VBD', 'were'),
#   ('DT', 'the'),
#   ('JJ', 'ideal'),
#   ('NN', 'circus'),
#   ('NNS', 'dogs'),
#   ('WRB', 'when'),
#   ('RB', 'not'),
#   ('VBN', 'dyed'),
#   ('NN', 'pink'),
#   ('CC', 'and'),
#   ('VBG', 'wearing'),
#   ('NN', 'diamond'),
#   ('NNS', 'colliers'),
#   ('IN', 'in'),
#   ('IN', 'via'),
#   ('NN', 'veneto'),
#   ('CC', 'or'),
#   ('NN', 'maxim'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('JJ', 'digital'),
#   ('NN', 'door'),
#   ('NN', 'lock'),
#   ('VBZ', 'is'),
#   ('DT', 'an'),
#   ('JJ', 'electronic'),
#   ('NN', 'lock'),
#   ('IN', 'for'),
#   ('JJ', 'residential'),
#   ('NNS', 'applications'),
#   ('JJ', 'such'),
#   ('IN', 'as'),
#   ('JJ', 'front'),
#   ('NNS', 'doors'),
#   ('IN', 'on'),
#   ('NNS', 'apartments'),
#   ('CC', 'and'),
#   ('JJ', 'single'),
#   (':', '-'),
#   ('NN', 'family'),
#   ('NNS', 'houses'),
#   ('.', '.')],
#  [('JJ', 'red'),
#   ('NN', 'grape'),
#   ('NN', 'wine'),
#   ('VBZ', 'is'),
#   ('DT', 'an'),
#   ('JJ', 'alcoholic'),
#   ('NN', 'fruit'),
#   ('NN', 'drink'),
#   ('IN', 'of'),
#   ('IN', 'between'),
#   ('CD', '10'),
#   ('CC', 'and'),
#   ('CD', '14'),
#   ('JJ', 'alcoholic'),
#   ('NN', 'strength'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'text'),
#   ('RB', 'also'),
#   ('VBZ', 'exists'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'transcript'),
#   ('IN', 'by'),
#   ('DT', 'a'),
#   ('JJ', 'professional'),
#   ('NN', 'scribe'),
#   ('WDT', 'which'),
#   ('VBD', 'was'),
#   ('VBN', 'prepared'),
#   ('IN', 'for'),
#   ('JJ', 'sir'),
#   ('NN', 'dudley'),
#   ('NN', 'carleton'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'witch'),
#   ('VBZ', 'is'),
#   ('JJ', 'able'),
#   ('TO', 'to'),
#   ('VB', 'change'),
#   ('NNS', 'events'),
#   ('IN', 'by'),
#   ('VBG', 'using'),
#   ('NN', 'magic'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'committee'),
#   ('VBZ', 'is'),
#   ('DT', 'an'),
#   ('JJ', 'integral'),
#   ('NN', 'part'),
#   ('IN', 'of'),
#   ('PRP$', 'our'),
#   ('NN', 'organisation'),
#   ('.', '.')],
#  [('NNS', 'i'),
#   ('VBP', 'have'),
#   ('VBN', 'inserted'),
#   ('DT', 'a'),
#   ('NN', 'clock'),
#   ('IN', 'into'),
#   ('DT', 'the'),
#   ('NNS', 'presentations'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'family'),
#   ('VBD', 'constructed'),
#   ('DT', 'some'),
#   ('NN', 'tcu'),
#   ('VBD', 'horned'),
#   ('JJ', 'frog'),
#   ('VBG', 'supporting'),
#   ('JJ', 'snow'),
#   ('NNS', 'features'),
#   ('RB', 'as'),
#   ('RB', 'well'),
#   ('IN', 'as'),
#   ('RB', 'just'),
#   ('DT', 'a'),
#   ('RB', 'really'),
#   ('JJ', 'nice'),
#   ('NN', 'picture'),
#   ('IN', 'of'),
#   ('DT', 'an'),
#   ('JJ', 'old'),
#   ('JJ', 'fashioned'),
#   ('NN', 'light'),
#   ('NN', 'post'),
#   ('.', '.')],
#  [('CD', 'one'),
#   ('NN', 'simple'),
#   ('NN', 'method'),
#   ('IN', 'for'),
#   ('VBG', 'clearing'),
#   ('JJ', 'small'),
#   ('NNS', 'clogs'),
#   ('VBZ', 'is'),
#   ('TO', 'to'),
#   ('VB', 'use'),
#   ('DT', 'a'),
#   ('JJ', 'tried'),
#   (':', '-'),
#   ('CC', 'and'),
#   (':', '-'),
#   ('JJ', 'true'),
#   ('NN', 'combination'),
#   ('IN', 'of'),
#   ('VBG', 'baking'),
#   ('NN', 'soda'),
#   ('CC', 'and'),
#   ('NN', 'vinegar'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'complete'),
#   ('NN', 'statue'),
#   ('VBN', 'topped'),
#   ('IN', 'by'),
#   ('DT', 'an'),
#   ('VBG', 'imposing'),
#   ('NN', 'head'),
#   ('VBD', 'was'),
#   ('RB', 'originally'),
#   ('RB', 'nearly'),
#   ('CD', 'five'),
#   ('NNS', 'metres'),
#   ('JJ', 'high'),
#   ('.', '.')],
#  [('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'article'),
#   ('DT', 'the'),
#   ('NNS', 'authors'),
#   ('VBP', 'explore'),
#   ('DT', 'the'),
#   ('NN', 'use'),
#   ('IN', 'of'),
#   ('NN', 'technology'),
#   ('IN', 'in'),
#   ('JJ', 'small'),
#   ('NN', 'pharmacy'),
#   ('NNS', 'chains'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'following'),
#   ('NNS', 'comments'),
#   ('VBP', 'are'),
#   ('VBN', 'provided'),
#   ('IN', 'by'),
#   ('NNS', 'readers'),
#   ('CC', 'and'),
#   ('VBP', 'are'),
#   ('DT', 'the'),
#   ('JJ', 'sole'),
#   ('NN', 'responsiblity'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'authors'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'organic'),
#   ('NN', 'act'),
#   ('IN', 'of'),
#   ('CD', '1868'),
#   ('VBD', 'made'),
#   ('JJ', 'several'),
#   ('JJ', 'specific'),
#   ('NNS', 'references'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('NNS', 'powers'),
#   ('CC', 'and'),
#   ('NNS', 'duties'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'president'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'university'),
#   ('IN', 'after'),
#   ('VBG', 'stating'),
#   ('IN', 'that'),
#   ('PRP', 'he'),
#   ('VB', 'be'),
#   ('VBN', 'elected'),
#   ('TO', 'to'),
#   ('NN', 'office'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('NN', 'board'),
#   ('IN', 'of'),
#   ('NNS', 'regents'),
#   ('.', '.')],
#  [('DT', 'this'),
#   ('JJ', 'grand'),
#   ('NN', 'cru'),
#   ('NN', 'wine'),
#   ('VBZ', 'is'),
#   ('VBN', 'made'),
#   ('IN', 'from'),
#   ('JJ', 'pinot'),
#   ('JJ', 'noir'),
#   ('NNS', 'grapes'),
#   ('CC', 'and'),
#   ('VBZ', 'is'),
#   ('NN', 'medium'),
#   ('TO', 'to'),
#   ('JJ', 'full'),
#   (':', '-'),
#   ('VBN', 'bodied'),
#   ('IN', 'in'),
#   ('NN', 'style'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'slide'),
#   ('WDT', 'which'),
#   ('VBD', 'was'),
#   ('VBN', 'triggered'),
#   ('IN', 'by'),
#   ('DT', 'an'),
#   ('NN', 'avalanche'),
#   (':', '-'),
#   ('NN', 'control'),
#   ('VBD', 'crew'),
#   ('VBN', 'damaged'),
#   ('CD', 'one'),
#   ('NN', 'home'),
#   ('CC', 'and'),
#   ('VBD', 'blocked'),
#   ('DT', 'the'),
#   ('NN', 'road'),
#   ('IN', 'for'),
#   ('JJS', 'most'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'day'),
#   ('.', '.')],
#  [('IN', 'since'),
#   ('DT', 'the'),
#   ('NN', 'inspector'),
#   ('VBD', 'had'),
#   ('VBN', 'left'),
#   ('DT', 'the'),
#   ('RB', 'yard'),
#   ('JJ', 'early'),
#   ('IN', 'that'),
#   ('NN', 'morning'),
#   ('PRP', 'he'),
#   ('VBD', 'had'),
#   ('VBN', 'disappeared'),
#   ('.', '.')],
#  [('JJ', 'international'),
#   ('NN', 'ship'),
#   ('NN', 'sewage'),
#   ('NNS', 'regulations'),
#   ('VBP', 'have'),
#   ('VBN', 'entered'),
#   ('IN', 'into'),
#   ('NN', 'force'),
#   ('.', '.')],
#  [('NN', 'ambassador'),
#   ('NN', 'sun'),
#   ('RB', 'shuzhong'),
#   ('VBD', 'answered'),
#   ('DT', 'the'),
#   ('NNS', 'questions'),
#   ('IN', 'from'),
#   ('DT', 'the'),
#   ('JJ', 'local'),
#   ('NN', 'press'),
#   ('IN', 'after'),
#   ('PRP$', 'his'),
#   ('NN', 'visit'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('JJ', 'memorial'),
#   ('NN', 'center'),
#   ('IN', 'in'),
#   ('NN', 'kigali'),
#   ('IN', 'on'),
#   ('NN', 'dec'),
#   ('CD', '28'),
#   ('CD', '2007'),
#   ('.', '.')],
#  [('PRP$', 'her'),
#   ('NNS', 'children'),
#   ('VBP', 'have'),
#   ('VBN', 'gone'),
#   ('IN', 'into'),
#   ('NN', 'exile'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'bedouin'),
#   ('NN', 'mediator'),
#   ('RB', 'again'),
#   ('VBD', 'returned'),
#   ('PRP', 'her'),
#   ('WRB', 'when'),
#   ('PRP$', 'her'),
#   ('NN', 'father'),
#   ('VBD', 'promised'),
#   ('RB', 'not'),
#   ('TO', 'to'),
#   ('VB', 'hurt'),
#   ('PRP$', 'her'),
#   ('CC', 'and'),
#   ('RB', 'then'),
#   ('PRP$', 'her'),
#   ('NN', 'father'),
#   ('VBD', 'killed'),
#   ('PRP', 'her'),
#   ('IN', 'with'),
#   ('DT', 'an'),
#   ('NN', 'iron'),
#   ('NN', 'bar'),
#   ('.', '.')],
#  [('PRP', 'he'),
#   ('VBD', 'put'),
#   ('DT', 'a'),
#   ('NN', 'rebound'),
#   ('IN', 'into'),
#   ('DT', 'an'),
#   ('JJ', 'open'),
#   ('NN', 'net'),
#   ('IN', 'for'),
#   ('PRP$', 'his'),
#   ('JJ', 'eighth'),
#   ('NN', 'goal'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'ubc'),
#   ('JJ', 'graduate'),
#   ('NN', 'student'),
#   ('VBD', 'spent'),
#   ('PRP$', 'his'),
#   ('JJ', 'free'),
#   ('NN', 'time'),
#   ('VBG', 'creating'),
#   ('DT', 'an'),
#   ('NN', 'application'),
#   ('VBN', 'called'),
#   ('NN', 'colorsplash'),
#   ('WDT', 'that'),
#   ('VBZ', 'lets'),
#   ('NNS', 'people'),
#   ('VBP', 'play'),
#   ('IN', 'with'),
#   ('DT', 'the'),
#   ('NN', 'colour'),
#   ('IN', 'in'),
#   ('PRP$', 'their'),
#   ('JJ', 'digital'),
#   ('NNS', 'photos'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'safety'),
#   ('NN', 'bar'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'seats'),
#   ('VBZ', 'has'),
#   ('TO', 'to'),
#   ('VB', 'be'),
#   ('VBN', 'folded'),
#   ('RP', 'down'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('NN', 'passenger'),
#   ('CC', 'and'),
#   ('PRP', 'it'),
#   ('VBZ', 'has'),
#   ('TO', 'to'),
#   ('VB', 'be'),
#   ('VBN', 'kept'),
#   ('JJ', 'closed'),
#   ('IN', 'during'),
#   ('DT', 'the'),
#   ('NN', 'journey'),
#   ('.', '.')],
#  [('IN', 'by'),
#   ('CD', '1715'),
#   ('DT', 'the'),
#   ('NN', 'cabriole'),
#   ('NN', 'leg'),
#   ('VBD', 'was'),
#   ('IN', 'in'),
#   ('JJ', 'general'),
#   ('NN', 'use'),
#   ('CC', 'and'),
#   ('DT', 'the'),
#   ('NN', 'back'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'chair'),
#   ('VBD', 'had'),
#   ('VBN', 'started'),
#   ('TO', 'to'),
#   ('VB', 'become'),
#   ('JJ', 'square'),
#   ('IN', 'in'),
#   ('NN', 'shape'),
#   (':', ':'),
#   ('DT', 'no'),
#   ('NN', 'longer'),
#   ('VBD', 'was'),
#   ('PRP', 'it'),
#   ('DT', 'the'),
#   ('JJ', 'characteristic'),
#   ('NN', 'tall'),
#   ('CC', 'and'),
#   ('JJ', 'narrow'),
#   ('NN', 'feature'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'previous'),
#   ('NN', 'century'),
#   ('.', '.')],
#  [('NN', 'muscle'),
#   ('NN', 'fatigue'),
#   ('VBZ', 'is'),
#   ('DT', 'the'),
#   ('NN', 'number'),
#   ('CD', 'one'),
#   ('NN', 'cause'),
#   ('IN', 'of'),
#   ('JJ', 'arm'),
#   ('NN', 'muscle'),
#   ('NN', 'pain'),
#   ('.', '.')],
#  [('JJ', 'lawhammer'),
#   ('NN', 'coat'),
#   (':', ':'),
#   ('DT', 'a'),
#   ('JJ', 'slang'),
#   ('NN', 'term'),
#   ('IN', 'for'),
#   ('DT', 'a'),
#   ('NN', 'man'),
#   ('JJ', 'formal'),
#   ('NN', 'evening'),
#   ('NN', 'coat'),
#   ('IN', 'because'),
#   ('NN', 'split'),
#   ('NNS', 'tails'),
#   ('VBP', 'resemble'),
#   ('DT', 'the'),
#   ('NN', 'claw'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('NN', 'hammer'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'magazine'),
#   ('VBD', 'was'),
#   ('VBN', 'founded'),
#   ('IN', 'in'),
#   ('NN', 'order'),
#   ('TO', 'to'),
#   ('VB', 'keep'),
#   ('NNS', 'athletes'),
#   ('VBG', 'serving'),
#   ('IN', 'as'),
#   ('NNS', 'soldiers'),
#   ('VBP', 'informed'),
#   ('IN', 'about'),
#   ('PRP$', 'their'),
#   ('NN', 'sport'),
#   ('RB', 'back'),
#   ('NN', 'home'),
#   ('.', '.')],
#  [('JJ', 'many'),
#   ('JJ', 'professional'),
#   ('NNS', 'cartomancers'),
#   ('VBP', 'use'),
#   ('DT', 'a'),
#   ('JJ', 'regular'),
#   ('NN', 'deck'),
#   ('IN', 'of'),
#   ('VBG', 'playing'),
#   ('NNS', 'cards'),
#   ('IN', 'for'),
#   ('NN', 'divination'),
#   ('.', '.')],
#  [('JJ', 'many'),
#   ('NNS', 'films'),
#   ('VBP', 'have'),
#   ('VBN', 'portrayed'),
#   ('JJ', 'mental'),
#   ('NN', 'illness'),
#   ('CC', 'or'),
#   ('VBD', 'used'),
#   ('PRP', 'it'),
#   ('IN', 'as'),
#   ('DT', 'a'),
#   ('NN', 'backdrop'),
#   ('IN', 'for'),
#   ('JJ', 'other'),
#   ('NNS', 'themes'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'software'),
#   ('NN', 'company'),
#   ('VBD', 'addressed'),
#   ('DT', 'the'),
#   ('NN', 'problem'),
#   ('IN', 'with'),
#   ('DT', 'the'),
#   ('NN', 'publication'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('NN', 'fix'),
#   ('IN', 'on'),
#   ('NN', 'saturday'),
#   ('.', '.')],
#  [('VBG', 'drinking'),
#   ('RP', 'down'),
#   ('DT', 'the'),
#   ('NN', 'rest'),
#   ('IN', 'of'),
#   ('PRP$', 'his'),
#   ('NN', 'papaya'),
#   ('NN', 'nectar'),
#   ('CC', 'and'),
#   ('VBG', 'wiping'),
#   ('PRP$', 'his'),
#   ('NN', 'mouth'),
#   ('PRP', 'he'),
#   ('VBD', 'turned'),
#   ('CC', 'and'),
#   ('VBD', 'hurried'),
#   ('RB', 'away'),
#   ('VBG', 'throwing'),
#   ('DT', 'a'),
#   ('NN', 'goodbye'),
#   ('CC', 'and'),
#   ('NN', 'wave'),
#   ('IN', 'over'),
#   ('PRP$', 'his'),
#   ('NN', 'shoulder'),
#   ('RB', 'madly'),
#   ('VBG', 'dashing'),
#   ('IN', 'thorough'),
#   ('DT', 'the'),
#   ('NN', 'crowds'),
#   ('.', '.')],
#  [('DT', 'this'),
#   ('NN', 'volume'),
#   ('VBZ', 'analyzes'),
#   ('JJ', 'central'),
#   ('NNS', 'concepts'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'contemporary'),
#   ('JJ', 'political'),
#   ('NN', 'debate'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'defendant'),
#   ('VBD', 'was'),
#   ('VBN', 'released'),
#   ('IN', 'from'),
#   ('NN', 'custody'),
#   ('IN', 'on'),
#   ('NN', 'march'),
#   ('CD', '2'),
#   ('CD', '2001'),
#   ('.', '.')],
#  [('IN', 'in'),
#   ('NN', 'addition'),
#   ('DT', 'the'),
#   ('NN', 'plant'),
#   ('VBZ', 'builds'),
#   ('CD', 'four'),
#   (':', '-'),
#   ('NN', 'cylinder'),
#   ('NN', 'ecotec'),
#   ('WDT', 'that'),
#   ('VBP', 'are'),
#   ('VBN', 'used'),
#   ('IN', 'in'),
#   ('NNS', 'vehicles'),
#   ('IN', 'like'),
#   ('DT', 'the'),
#   ('NN', 'chevy'),
#   ('NN', 'malibu'),
#   ('CC', 'and'),
#   ('NN', 'cobalt'),
#   ('.', '.')],
#  [('PRP', 'we'),
#   ('VBD', 'used'),
#   ('VBN', 'fried'),
#   ('JJ', 'cheese'),
#   ('IN', 'as'),
#   ('DT', 'an'),
#   ('NN', 'element'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'dish'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'castle'),
#   ('VBD', 'was'),
#   ('IN', 'inside'),
#   ('DT', 'a'),
#   ('NN', 'museum'),
#   ('.', '.')],
#  [('RBR', 'more'),
#   ('CC', 'and'),
#   ('RBR', 'more'),
#   ('JJ', 'english'),
#   ('NN', 'premier'),
#   ('NN', 'league'),
#   ('NNS', 'clubs'),
#   ('VBP', 'are'),
#   ('VBG', 'falling'),
#   ('IN', 'into'),
#   ('JJ', 'foreign'),
#   ('NN', 'ownership'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'man'),
#   ('VBD', 'was'),
#   ('VBN', 'carried'),
#   ('IN', 'into'),
#   ('DT', 'a'),
#   ('VBG', 'waiting'),
#   ('NN', 'police'),
#   ('NN', 'car'),
#   ('IN', 'from'),
#   ('NN', 'coleraine'),
#   ('NNS', 'times'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'aim'),
#   ('IN', 'of'),
#   ('DT', 'this'),
#   ('NN', 'section'),
#   ('VBZ', 'is'),
#   ('DT', 'the'),
#   ('NN', 'interpretation'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'results'),
#   ('CC', 'and'),
#   ('PRP$', 'their'),
#   ('NN', 'relation'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('VBG', 'existing'),
#   ('NN', 'knowledge'),
#   ('.', '.')],
#  [('NN', 'bunn'),
#   ('VBZ', 'has'),
#   ('VBN', 'recalled'),
#   ('CD', '35'),
#   ('CD', '600'),
#   ('JJ', 'single'),
#   (':', '-'),
#   ('NN', 'cup'),
#   ('NN', 'pod'),
#   ('NNS', 'brewers'),
#   ('IN', 'because'),
#   ('DT', 'the'),
#   ('NN', 'drawer'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'coffeemaker'),
#   ('VBZ', 'opens'),
#   ('RB', 'unexpectedly'),
#   ('IN', 'during'),
#   ('DT', 'a'),
#   ('JJ', 'brew'),
#   ('NN', 'cycle'),
#   ('VBG', 'posing'),
#   ('DT', 'a'),
#   ('NN', 'burn'),
#   ('NN', 'hazard'),
#   ('TO', 'to'),
#   ('NNS', 'consumers'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'probe'),
#   ('NN', 'tube'),
#   ('VBZ', 'is'),
#   ('VBN', 'introduced'),
#   ('IN', 'into'),
#   ('DT', 'a'),
#   ('NN', 'reaction'),
#   ('NN', 'container'),
#   ('IN', 'for'),
#   ('VBG', 'measuring'),
#   ('DT', 'the'),
#   ('NN', 'operating'),
#   ('NN', 'condition'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('NN', 'medium'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'interior'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'container'),
#   ('.', '.')],
#  [('NN', 'david'),
#   ('VBD', 'mamet'),
#   ('VBD', 'took'),
#   ('NNS', 'questions'),
#   ('IN', 'from'),
#   ('DT', 'the'),
#   ('NN', 'audience'),
#   ('CC', 'and'),
#   ('VBD', 'shared'),
#   ('PRP$', 'his'),
#   ('NNS', 'views'),
#   ('IN', 'on'),
#   ('NNS', 'topics'),
#   ('JJ', 'such'),
#   ('IN', 'as'),
#   ('NN', 'television'),
#   ('DT', 'the'),
#   ('NN', 'democracy'),
#   ('IN', 'of'),
#   ('NN', 'culture'),
#   ('CC', 'and'),
#   ('DT', 'the'),
#   ('JJ', 'english'),
#   ('NN', 'accent'),
#   ('.', '.')],
#  [('RB', 'additionally'),
#   ('DT', 'the'),
#   ('NN', 'chapter'),
#   ('VBZ', 'points'),
#   ('RP', 'out'),
#   ('DT', 'the'),
#   ('NN', 'importance'),
#   ('IN', 'of'),
#   ('JJ', 'new'),
#   ('NN', 'employee'),
#   ('NN', 'orientation'),
#   ('CC', 'and'),
#   ('VBZ', 'lists'),
#   ('DT', 'some'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'important'),
#   ('NNS', 'things'),
#   ('TO', 'to'),
#   ('VB', 'cover'),
#   ('IN', 'during'),
#   ('DT', 'that'),
#   ('NN', 'process'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'monitoring'),
#   ('NN', 'station'),
#   ('VBZ', 'receives'),
#   ('DT', 'the'),
#   ('NN', 'signal'),
#   ('IN', 'through'),
#   ('DT', 'a'),
#   ('NN', 'communication'),
#   ('NN', 'device'),
#   ('CC', 'and'),
#   ('DT', 'the'),
#   ('JJ', 'combined'),
#   ('NN', 'signal'),
#   ('VBZ', 'is'),
#   ('VBN', 'processed'),
#   ('TO', 'to'),
#   ('VB', 'retrieve'),
#   ('NN', 'gps'),
#   ('NNS', 'data'),
#   ('.', '.')],
#  [('IN', 'in'),
#   ('DT', 'this'),
#   ('NN', 'approach'),
#   ('NN', 'correction'),
#   ('CC', 'and'),
#   ('NN', 'police'),
#   ('NNS', 'personnel'),
#   ('RB', 'jointly'),
#   ('VBD', 'sought'),
#   ('TO', 'to'),
#   ('VB', 'locate'),
#   ('CC', 'and'),
#   ('VB', 'apprehend'),
#   ('NNS', 'offenders'),
#   ('WP', 'who'),
#   ('VBD', 'had'),
#   ('VBN', 'absconded'),
#   ('IN', 'from'),
#   ('NN', 'parole'),
#   ('CC', 'and'),
#   ('NN', 'probation'),
#   ('NNS', 'officers'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'major'),
#   ('NN', 'theme'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'book'),
#   ('VBZ', 'is'),
#   ('DT', 'the'),
#   ('NN', 'beauty'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('NN', 'dream'),
#   ('.', '.')],
#  [('PRP', 'it'),
#   ('VBD', 'spilled'),
#   ('JJR', 'more'),
#   ('IN', 'than'),
#   ('CD', '53000'),
#   ('NNS', 'gallons'),
#   ('IN', 'of'),
#   ('JJ', 'crude'),
#   ('NN', 'oil'),
#   ('IN', 'into'),
#   ('DT', 'the'),
#   ('VBG', 'surrounding'),
#   ('NNS', 'marshes'),
#   ('CD', 'one'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJR', 'bigger'),
#   ('NNS', 'spills'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('NN', 'hurricane'),
#   ('.', '.')],
#  [('JJ', 'eighteen'),
#   ('NNS', 'studies'),
#   ('VBD', 'were'),
#   ('VBN', 'focused'),
#   ('IN', 'on'),
#   ('JJR', 'older'),
#   ('NNS', 'adults'),
#   ('VBG', 'living'),
#   ('IN', 'at'),
#   ('NN', 'home'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NNS', 'diseases'),
#   ('VBP', 'are'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('NN', 'gene'),
#   ('NNS', 'mutations'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('JJ', 'x'),
#   ('NN', 'chromosome'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'pretexts'),
#   ('VBN', 'offered'),
#   ('VBD', 'were'),
#   ('JJ', 'laughable'),
#   ('CC', 'and'),
#   ('DT', 'the'),
#   ('NN', 'response'),
#   ('VBD', 'caused'),
#   ('RB', 'scarcely'),
#   ('DT', 'a'),
#   ('NN', 'ripple'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('NN', 'flood'),
#   ('IN', 'of'),
#   ('NN', 'commentary'),
#   ('IN', 'on'),
#   ('NN', 'washington'),
#   ('JJ', 'noble'),
#   ('NNS', 'efforts'),
#   ('TO', 'to'),
#   ('VB', 'spread'),
#   ('NN', 'democracy'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'size'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('JJ', 'tree'),
#   ('NN', 'crown'),
#   ('VBZ', 'is'),
#   ('RB', 'strongly'),
#   ('VBN', 'correlated'),
#   ('IN', 'with'),
#   ('DT', 'the'),
#   ('NN', 'growth'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'tree'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'state'),
#   ('NN', 'capital'),
#   ('VBZ', 'is'),
#   ('DT', 'a'),
#   ('VBG', 'disgusting'),
#   ('NN', 'sewer'),
#   ('CC', 'and'),
#   ('NN', 'bruno'),
#   ('VBZ', 'is'),
#   ('RB', 'just'),
#   ('CD', 'one'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'mischief'),
#   ('IN', 'of'),
#   ('JJ', 'filthy'),
#   ('NNS', 'rats'),
#   ('WDT', 'that'),
#   ('VBP', 'proliferate'),
#   ('RB', 'there'),
#   ('.', '.')],
#  [('SYM', 'sci'),
#   (':', '-'),
#   ('JJ', 'fi'),
#   ('NN', 'channel'),
#   ('VBZ', 'is'),
#   ('DT', 'the'),
#   ('NN', 'cable'),
#   ('NN', 'network'),
#   ('RB', 'exclusively'),
#   ('VBN', 'dedicated'),
#   ('TO', 'to'),
#   ('VBG', 'offering'),
#   ('JJ', 'classic'),
#   ('NN', 'science'),
#   ('NN', 'fiction'),
#   ('NN', 'tv'),
#   ('NNS', 'shows'),
#   ('CC', 'and'),
#   ('NNS', 'movies'),
#   ('RB', 'as'),
#   ('RB', 'well'),
#   ('IN', 'as'),
#   ('JJ', 'bold'),
#   ('JJ', 'original'),
#   ('NN', 'programming'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'mummified'),
#   ('NN', 'cat'),
#   ('VBD', 'was'),
#   ('VBN', 'found'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('JJ', 'live'),
#   ('NN', 'trap'),
#   ('IN', 'with'),
#   ('DT', 'an'),
#   ('JJ', 'empty'),
#   ('NN', 'dish'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NNS', 'stories'),
#   ('VBP', 'are'),
#   ('VBN', 'narrated'),
#   ('IN', 'through'),
#   ('NN', 'dance'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'foundry'),
#   ('JJ', 'major'),
#   ('NN', 'product'),
#   ('NNS', 'lines'),
#   ('VBP', 'include'),
#   ('JJ', 'manhole'),
#   ('NNS', 'frames'),
#   ('CC', 'and'),
#   ('NN', 'utility'),
#   ('VBZ', 'covers'),
#   ('JJ', 'airport'),
#   ('NNS', 'castings'),
#   ('NN', 'drainage'),
#   ('NNS', 'products'),
#   ('JJ', 'trench'),
#   ('NNS', 'grates'),
#   ('JJ', 'hydrant'),
#   ('CC', 'and'),
#   ('JJ', 'valve'),
#   ('NNS', 'components'),
#   ('CC', 'and'),
#   ('JJ', 'industrial'),
#   ('NNS', 'castings'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'air'),
#   ('VBD', 'was'),
#   ('VBN', 'filled'),
#   ('IN', 'with'),
#   ('DT', 'the'),
#   ('NN', 'smell'),
#   ('IN', 'of'),
#   ('VBG', 'burning'),
#   ('NN', 'plastic'),
#   ('.', '.')],
#  [('JJ', 'lisa'),
#   ('VBD', 'took'),
#   ('JJ', 'great'),
#   ('NN', 'joy'),
#   ('IN', 'from'),
#   ('VBG', 'laughing'),
#   ('VBG', 'volunteering'),
#   ('IN', 'at'),
#   ('NN', 'school'),
#   ('VBG', 'taking'),
#   ('NNS', 'pictures'),
#   ('VBG', 'chatting'),
#   ('DT', 'the'),
#   ('NNS', 'twins'),
#   ('CC', 'and'),
#   ('NNS', 'vikings'),
#   ('VBG', 'playing'),
#   ('NN', 'softball'),
#   ('CC', 'and'),
#   ('NN', 'volleyball'),
#   ('CC', 'and'),
#   ('NN', 'time'),
#   ('IN', 'at'),
#   ('JJ', 'lake'),
#   ('NN', 'vermilion'),
#   ('.', '.')],
#  [('JJ', 'such'),
#   ('NNS', 'lines'),
#   ('IN', 'from'),
#   ('DT', 'the'),
#   ('NN', 'pen'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('JJ', 'young'),
#   ('NN', 'author'),
#   ('RB', 'widely'),
#   ('VBN', 'read'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('JJR', 'younger'),
#   ('NN', 'part'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'population'),
#   ('RB', 'only'),
#   ('VBZ', 'confirm'),
#   ('DT', 'the'),
#   ('NN', 'profound'),
#   ('NN', 'change'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('NN', 'mood'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'freuch'),
#   ('NN', 'proletariat'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'receiver'),
#   ('VBD', 'was'),
#   ('VBG', 'outputting'),
#   ('DT', 'the'),
#   ('JJ', 'same'),
#   ('NN', 'tone'),
#   ('TO', 'to'),
#   ('PRP$', 'my'),
#   ('NN', 'deva'),
#   ('CD', '5'),
#   ('.', '.')],
#  [('IN', 'at'),
#   ('JJS', 'least'),
#   ('CD', '12'),
#   ('NNS', 'people'),
#   ('VBD', 'were'),
#   ('VBN', 'killed'),
#   ('NN', 'yesterday'),
#   ('WRB', 'when'),
#   ('DT', 'a'),
#   ('NN', 'squad'),
#   ('IN', 'of'),
#   ('RB', 'heavily'),
#   ('VBN', 'armed'),
#   ('NNS', 'militants'),
#   ('VBD', 'stormed'),
#   ('DT', 'the'),
#   ('NN', 'police'),
#   ('VBG', 'training'),
#   ('NN', 'school'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('NNS', 'outskirts'),
#   ('IN', 'of'),
#   ('NN', 'lahore'),
#   ('VBG', 'spraying'),
#   ('PRP', 'it'),
#   ('IN', 'with'),
#   ('NN', 'gunfire'),
#   ('CC', 'and'),
#   ('NNS', 'grenades'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'telescope'),
#   ('VBZ', 'comprises'),
#   ('NNS', 'lenses'),
#   ('CC', 'and'),
#   ('NNS', 'tubes'),
#   (':', ':'),
#   ('DT', 'both'),
#   ('VBP', 'are'),
#   ('RB', 'extremely'),
#   ('JJ', 'important'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('NN', 'performance'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'telescope'),
#   ('.', '.')],
#  [('PRP', 'we'),
#   ('VBD', 'poured'),
#   ('DT', 'the'),
#   ('NN', 'pulp'),
#   ('IN', 'into'),
#   ('DT', 'the'),
#   ('NN', 'tupperware'),
#   ('NN', 'tub'),
#   ('VBN', 'filled'),
#   ('IN', 'with'),
#   ('NN', 'water'),
#   ('.', '.')],
#  [('NNS', 'carpenters'),
#   ('VBP', 'build'),
#   ('JJ', 'many'),
#   ('NNS', 'things'),
#   ('IN', 'from'),
#   ('NN', 'wood'),
#   ('CC', 'and'),
#   ('JJ', 'other'),
#   ('NNS', 'materials'),
#   ('IN', 'like'),
#   ('NNS', 'buildings'),
#   ('CC', 'and'),
#   ('NNS', 'boats'),
#   ('.', '.')],
#  [('NN', 'milk'),
#   ('NNS', 'samples'),
#   ('VBD', 'were'),
#   ('VBN', 'obtained'),
#   ('IN', 'from'),
#   ('CD', 'one'),
#   ('NN', 'milking'),
#   ('IN', 'of'),
#   ('DT', 'each'),
#   ('NN', 'cow'),
#   ('.', '.')],
#  [('EX', 'there'),
#   ('VBZ', 'is'),
#   ('DT', 'a'),
#   ('NN', 'comparison'),
#   ('IN', 'between'),
#   ('DT', 'the'),
#   ('NN', 'intimacy'),
#   ('CC', 'and'),
#   ('NN', 'accountability'),
#   ('VBN', 'offered'),
#   ('IN', 'by'),
#   ('DT', 'a'),
#   ('NN', 'novel'),
#   ('CC', 'and'),
#   ('IN', 'that'),
#   ('VBN', 'offered'),
#   ('IN', 'by'),
#   ('DT', 'a'),
#   ('NN', 'blog'),
#   ('IN', 'in'),
#   ('WDT', 'which'),
#   ('DT', 'the'),
#   ('NN', 'blogger'),
#   ('VBZ', 'is'),
#   ('JJ', 'participant'),
#   ('IN', 'in'),
#   ('DT', 'an'),
#   ('IN', 'on'),
#   ('VBG', 'going'),
#   ('NN', 'conversation'),
#   ('IN', 'in'),
#   ('WDT', 'which'),
#   ('DT', 'the'),
#   ('NN', 'line'),
#   ('IN', 'between'),
#   ('NN', 'reader'),
#   ('CC', 'and'),
#   ('JJ', 'original'),
#   ('NN', 'poster'),
#   ('VBZ', 'is'),
#   ('VBN', 'blurred'),
#   ('IN', 'beyond'),
#   ('NN', 'recognition'),
#   ('IN', 'in'),
#   ('WDT', 'which'),
#   ('JJ', 'collective'),
#   ('NN', 'comment'),
#   ('NNS', 'replaces'),
#   ('JJ', 'old'),
#   (':', '-'),
#   ('VBD', 'fashioned'),
#   ('JJ', 'ivory'),
#   ('NN', 'tower'),
#   ('VBG', 'editing'),
#   ('IN', 'with'),
#   ('DT', 'a'),
#   ('NN', 'kind'),
#   ('IN', 'of'),
#   ('JJ', 'universal'),
#   ('NN', 'peer'),
#   ('NN', 'review'),
#   ('.', '.')],
#  [('PRP$', 'his'),
#   ('NN', 'speech'),
#   ('VBD', 'criticised'),
#   ('DT', 'the'),
#   ('NN', 'idea'),
#   ('IN', 'of'),
#   ('JJ', 'religious'),
#   ('NN', 'education'),
#   ('IN', 'as'),
#   ('DT', 'a'),
#   ('NN', 'journey'),
#   ('IN', 'around'),
#   ('DT', 'the'),
#   ('JJ', 'various'),
#   ('NNS', 'religions'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'bread'),
#   ('VBD', 'prepared'),
#   ('IN', 'with'),
#   ('NN', 'rice'),
#   ('NN', 'flour'),
#   ('VBD', 'was'),
#   ('VBN', 'considered'),
#   ('JJ', 'good'),
#   ('IN', 'by'),
#   ('CD', '25'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'assessors'),
#   ('JJ', 'regular'),
#   ('IN', 'by'),
#   ('CD', '33'),
#   ('RB', 'very'),
#   ('JJ', 'bad'),
#   ('IN', 'by'),
#   ('CD', '17'),
#   ('CC', 'and'),
#   ('RB', 'very'),
#   ('JJ', 'good'),
#   ('IN', 'by'),
#   ('RB', 'only'),
#   ('CD', '8'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'body'),
#   ('VBZ', 'unleashes'),
#   ('PRP$', 'its'),
#   ('JJ', 'extraterrestrial'),
#   ('NN', 'passenger'),
#   ('WDT', 'which'),
#   ('VBZ', 'proceeds'),
#   ('TO', 'to'),
#   ('VB', 'infect'),
#   ('DT', 'the'),
#   ('NN', 'student'),
#   ('NN', 'population'),
#   ('IN', 'at'),
#   ('DT', 'a'),
#   ('NN', 'breakneck'),
#   ('NN', 'pace'),
#   ('.', '.')],
#  [('NN', 'asteroid'),
#   ('VBD', 'threatened'),
#   ('NN', 'earth'),
#   ('IN', 'with'),
#   ('NN', 'disaster'),
#   ('.', '.')],
#  [('IN', 'in'),
#   ('PRP$', 'its'),
#   ('JJ', 'early'),
#   ('NNS', 'years'),
#   ('DT', 'the'),
#   ('NN', 'farm'),
#   ('VBD', 'had'),
#   ('VBN', 'forty'),
#   ('NNS', 'acres'),
#   ('CC', 'and'),
#   ('VBD', 'was'),
#   ('DT', 'a'),
#   ('JJ', 'productive'),
#   ('NN', 'subsistence'),
#   ('NN', 'farm'),
#   ('IN', 'with'),
#   ('JJ', 'sheep'),
#   ('VBG', 'being'),
#   ('DT', 'the'),
#   ('JJ', 'primary'),
#   ('NN', 'source'),
#   ('IN', 'of'),
#   ('NN', 'income'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'laptop'),
#   ('VBD', 'was'),
#   ('IN', 'inside'),
#   ('DT', 'a'),
#   ('JJ', 'protective'),
#   ('NN', 'plastic'),
#   ('NN', 'bag'),
#   ('VBN', 'made'),
#   ('IN', 'from'),
#   ('JJ', 'ldpe'),
#   ('NN', 'number'),
#   ('CD', '4'),
#   ('WDT', 'which'),
#   ('MD', 'can'),
#   ('VB', 'be'),
#   ('RB', 'easily'),
#   ('VBN', 'recycled'),
#   ('.', '.')],
#  [('JJ', 'gary'),
#   ('NN', 'wheelan'),
#   ('DT', 'a'),
#   ('VBG', 'womanizing'),
#   ('JJ', 'adulterous'),
#   ('NN', 'thirty'),
#   (':', '-'),
#   ('NN', 'something'),
#   ('JJ', 'dallas'),
#   ('NN', 'attorney'),
#   ('RB', 'finally'),
#   ('VBZ', 'gets'),
#   ('WP', 'what'),
#   ('PRP', 'he'),
#   ('VBZ', 'deserves'),
#   ('WRB', 'when'),
#   ('PRP$', 'his'),
#   ('NN', 'verbal'),
#   ('NNS', 'assaults'),
#   ('VBD', 'provoke'),
#   ('DT', 'a'),
#   ('NN', 'telephone'),
#   ('NN', 'operator'),
#   ('.', '.')],
#  [('PRP', 'he'),
#   ('VBZ', 'weaves'),
#   ('JJ', 'complex'),
#   ('NNS', 'tales'),
#   ('VBG', 'concerning'),
#   ('DT', 'the'),
#   ('JJ', 'romantic'),
#   ('NNS', 'concerns'),
#   ('IN', 'of'),
#   ('NN', 'happiness'),
#   ('NN', 'love'),
#   ('CC', 'and'),
#   ('NN', 'sufferance'),
#   ('.', '.')],
#  [('IN', 'unlike'),
#   ('DT', 'the'),
#   ('NN', 'forebrain'),
#   ('NN', 'telencephalon'),
#   ('CC', 'or'),
#   ('NN', 'cerebrum'),
#   ('IN', 'of'),
#   ('NNS', 'mammals'),
#   ('NNS', 'birds'),
#   ('CC', 'and'),
#   ('VB', 'fish'),
#   ('DT', 'the'),
#   ('NN', 'forebrain'),
#   ('IN', 'of'),
#   ('NNS', 'amphibians'),
#   ('VBZ', 'is'),
#   ('JJ', 'similar'),
#   ('IN', 'across'),
#   ('DT', 'all'),
#   ('CD', 'three'),
#   ('NNS', 'orders'),
#   ('IN', 'of'),
#   ('NNS', 'amphibians'),
#   (':', ':'),
#   ('DT', 'the'),
#   ('NNS', 'anurons'),
#   ('NNS', 'frogs'),
#   ('CC', 'and'),
#   ('VBZ', 'toads'),
#   ('DT', 'the'),
#   ('JJ', 'urodiles'),
# ...
#   ('VBD', 'resulted'),
#   ('IN', 'in'),
#   ('JJ', 'massive'),
#   ('NN', 'population'),
#   ('NNS', 'movements'),
#   ('IN', 'from'),
#   ('DT', 'the'),
#   ('JJ', 'old'),
#   ('NN', 'world'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('JJ', 'new'),
#   ('NN', 'world'),
#   ('.', '.')],
#  [('NNS', 'workers'),
#   ('VBP', 'take'),
#   ('NN', 'wax'),
#   ('IN', 'from'),
#   ('JJ', 'wax'),
#   ('VBG', 'producing'),
#   ('NNS', 'workers'),
#   ('CC', 'and'),
#   ('VB', 'build'),
#   ('DT', 'the'),
#   ('NN', 'comb'),
#   ('IN', 'with'),
#   ('PRP', 'it'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'author'),
#   ('VBZ', 'identifies'),
#   ('DT', 'the'),
#   ('NN', 'piper'),
#   ('IN', 'with'),
#   ('DT', 'the'),
#   ('NN', 'devil'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'faction'),
#   ('IN', 'of'),
#   ('NN', 'sikh'),
#   ('NNS', 'leaders'),
#   ('VBD', 'took'),
#   ('RP', 'over'),
#   ('DT', 'a'),
#   ('NN', 'gurdwara'),
#   ('IN', 'in'),
#   ('DT', 'this'),
#   ('NN', 'haryana'),
#   ('NN', 'town'),
#   ('WDT', 'which'),
#   ('VBD', 'was'),
#   ('VBN', 'controlled'),
#   ('IN', 'by'),
#   ('NN', 'amritsar'),
#   (':', '-'),
#   ('VBN', 'based'),
#   ('NN', 'shiromani'),
#   ('NN', 'gurdwara'),
#   ('NN', 'parbandhak'),
#   ('NN', 'committee'),
#   ('NN', 'sgpc'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'law'),
#   (':', '-'),
#   ('NN', 'maker'),
#   ('RB', 'narrowly'),
#   ('VBN', 'escaped'),
#   ('IN', 'by'),
#   ('VBG', 'fleeing'),
#   ('IN', 'from'),
#   ('PRP$', 'his'),
#   ('NN', 'house'),
#   ('IN', 'on'),
#   ('DT', 'a'),
#   ('NN', 'horse'),
#   ('.', '.')],
#  [('WRB', 'when'),
#   ('DT', 'the'),
#   ('NN', 'loading'),
#   ('NN', 'time'),
#   ('VBD', 'was'),
#   ('VBN', 'completed'),
#   ('DT', 'the'),
#   ('VBG', 'sliding'),
#   ('NN', 'bar'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'injector'),
#   ('VBD', 'was'),
#   ('VBN', 'displaced'),
#   ('RB', 'manually'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('JJ', 'other'),
#   ('VBG', 'resting'),
#   ('NN', 'position'),
#   ('VBD', 'dashed'),
#   ('NN', 'area'),
#   ('.', '.')],
#  [('JJ', 'cambodian'),
#   ('NNS', 'troops'),
#   ('VBD', 'arrived'),
#   ('TO', 'to'),
#   ('NNS', 'areas'),
#   ('IN', 'in'),
#   ('JJ', 'chad'),
#   ('JJ', 'central'),
#   ('JJ', 'african'),
#   ('NN', 'republic'),
#   ('WRB', 'where'),
#   ('PRP', 'us'),
#   ('NNS', 'forces'),
#   ('VBD', 'had'),
#   ('VBN', 'settled'),
#   ('RB', 'already'),
#   ('.', '.')],
#  [('NNS', 'highways'),
#   ('VBP', 'are'),
#   ('VBG', 'falling'),
#   ('IN', 'into'),
#   ('NN', 'disrepair'),
#   ('.', '.')],
#  [('NN', 'witness'),
#   ('NN', 'ryan'),
#   ('NNS', 'jones'),
#   ('VBD', 'tried'),
#   ('TO', 'to'),
#   ('VB', 'stop'),
#   ('DT', 'the'),
#   ('NN', 'fleeing'),
#   ('NN', 'diaz'),
#   ('NNS', 'jones'),
#   ('VBD', 'became'),
#   ('VBN', 'caught'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('NN', 'door'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'truck'),
#   ('CC', 'and'),
#   ('VBD', 'was'),
#   ('VBN', 'dragged'),
#   ('IN', 'for'),
#   ('DT', 'a'),
#   ('NN', 'distance'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'tea'),
#   ('VBD', 'was'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'mug'),
#   ('PRP$', 'my'),
#   ('NN', 'husband'),
#   ('NN', 'larry'),
#   ('VBD', 'had'),
#   ('VBN', 'ordered'),
#   ('IN', 'from'),
#   ('DT', 'some'),
#   ('NN', 'company'),
#   ('NN', 'online'),
#   ('.', '.')],
#  [('IN', 'while'),
#   ('VBG', 'making'),
#   ('NNS', 'observations'),
#   ('DT', 'the'),
#   ('NN', 'microfossil'),
#   ('IN', 'through'),
#   ('DT', 'the'),
#   ('JJ', 'binocular'),
#   ('NN', 'microscope'),
#   ('CC', 'or'),
#   ('IN', 'on'),
#   ('DT', 'a'),
#   ('NN', 'computer'),
#   ('NN', 'monitor'),
#   ('DT', 'the'),
#   ('NN', 'investigator'),
#   ('VBD', 'needed'),
#   ('TO', 'to'),
#   ('RB', 'manually'),
#   ('VB', 'move'),
#   ('DT', 'the'),
#   ('NNS', 'specimen'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'while'),
#   ('IN', 'ago'),
#   ('NN', 'i'),
#   ('VBD', 'was'),
#   ('VBG', 'walking'),
#   ('IN', 'along'),
#   ('DT', 'the'),
#   ('NN', 'nibenay'),
#   ('NN', 'basin'),
#   ('WRB', 'when'),
#   ('NN', 'i'),
#   ('VBD', 'stumbled'),
#   ('IN', 'upon'),
#   ('DT', 'a'),
#   ('NN', 'harras'),
#   ('IN', 'of'),
#   ('JJ', 'wild'),
#   ('NNS', 'horses'),
#   ('.', '.')],
#  [('IN', 'on'),
#   ('DT', 'the'),
#   ('NN', 'way'),
#   ('IN', 'in'),
#   ('PRP', 'we'),
#   ('VBD', 'saw'),
#   ('DT', 'a'),
#   ('JJ', 'big'),
#   ('NN', 'raft'),
#   ('IN', 'of'),
#   ('NN', 'eider'),
#   ('NNS', 'ducks'),
#   ('CC', 'and'),
#   ('EX', 'there'),
#   ('VBD', 'were'),
#   ('DT', 'some'),
#   ('JJ', 'tiny'),
#   ('NNS', 'babies'),
#   ('IN', 'with'),
#   ('PRP', 'them'),
#   ('.', '.')],
#  [('DT', 'another'),
#   ('CD', '40'),
#   ('CD', 'million'),
#   ('NNS', 'people'),
#   ('VBP', 'have'),
#   ('VBN', 'been'),
#   ('VBN', 'pushed'),
#   ('IN', 'into'),
#   ('NN', 'hunger'),
#   ('DT', 'this'),
#   ('NN', 'year'),
#   ('.', '.')],
#  [('PRP', 'he'),
#   ('VBD', 'grabbed'),
#   ('CC', 'and'),
#   ('VBD', 'put'),
#   ('DT', 'all'),
#   ('NN', 'dirty'),
#   ('NN', 'clothing'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'hamper'),
#   ('.', '.')],
#  [('DT', 'each'),
#   ('NN', 'recipe'),
#   ('VBZ', 'features'),
#   ('DT', 'an'),
#   ('NN', 'anecdote'),
#   ('IN', 'by'),
#   ('DT', 'a'),
#   ('NN', 'band'),
#   ('WDT', 'that'),
#   ('VBD', 'performed'),
#   ('IN', 'via'),
#   ('DT', 'the'),
#   ('NN', 'hope'),
#   ('VBP', 'collective'),
#   ('DT', 'a'),
#   ('JJ', 'popular'),
#   ('NN', 'punk'),
#   ('VBG', 'booking'),
#   ('JJ', 'collective'),
#   ('IN', 'in'),
#   ('NN', 'dublin'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'writer'),
#   ('VBZ', 'has'),
#   ('DT', 'a'),
#   ('NN', 'bottle'),
#   ('IN', 'of'),
#   ('NN', 'ink'),
#   ('DT', 'a'),
#   ('NN', 'pen'),
#   ('CC', 'and'),
#   ('DT', 'a'),
#   ('NN', 'blotter'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'city'),
#   ('VBZ', 'has'),
#   ('VBN', 'constructed'),
#   ('DT', 'some'),
#   ('NN', 'tourism'),
#   ('NNS', 'facilities'),
#   ('CC', 'and'),
#   ('DT', 'a'),
#   ('JJ', 'new'),
#   ('NN', 'police'),
#   ('NN', 'station'),
#   ('IN', 'in'),
#   ('DT', 'the'),
#   ('JJ', 'showcase'),
#   ('NN', 'area'),
#   ('CC', 'but'),
#   ('DT', 'no'),
#   ('JJ', 'new'),
#   ('NNS', 'houses'),
#   ('VBP', 'are'),
#   ('TO', 'to'),
#   ('VB', 'be'),
#   ('VBN', 'built'),
#   ('RB', 'here'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'straight'),
#   ('JJ', 'blue'),
#   ('NN', 'ion'),
#   ('NN', 'tail'),
#   ('VBZ', 'is'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('JJ', 'solar'),
#   ('NN', 'wind'),
#   ('CC', 'and'),
#   ('DT', 'the'),
#   ('JJ', 'curved'),
#   ('NN', 'dust'),
#   ('NN', 'tail'),
#   ('VBZ', 'is'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('JJ', 'solar'),
#   ('NN', 'radiation'),
#   ('NN', 'pressure'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'ocean'),
#   ('NN', 'exploration'),
#   ('VBZ', 'is'),
#   ('RB', 'now'),
#   ('VBG', 'moving'),
#   ('IN', 'into'),
#   ('JJ', 'deeper'),
#   ('NNS', 'waters'),
#   ('.', '.')],
#  [('JJ', 'infectious'),
#   ('NNS', 'diseases'),
#   ('CC', 'or'),
#   ('JJ', 'communicable'),
#   ('NNS', 'diseases'),
#   ('VBP', 'are'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('NN', 'bacteria'),
#   ('NNS', 'viruses'),
#   ('CC', 'and'),
#   ('NNS', 'parasites'),
#   ('.', '.')],
#  [('NNS', 'proposals'),
#   ('TO', 'to'),
#   ('VB', 'simplify'),
#   ('DT', 'the'),
#   ('NN', 'university'),
#   ('NNS', 'admissions'),
#   ('NN', 'process'),
#   ('VBP', 'have'),
#   ('VBN', 'been'),
#   ('VBN', 'outlined'),
#   ('IN', 'at'),
#   ('DT', 'a'),
#   ('NN', 'conference'),
#   ('IN', 'of'),
#   ('JJ', 'secondary'),
#   ('NN', 'school'),
#   ('NN', 'head'),
#   ('NNS', 'teachers'),
#   ('.', '.')],
#  [('IN', 'during'),
#   ('DT', 'the'),
#   ('NN', 'reign'),
#   ('IN', 'of'),
#   ('VBG', 'king'),
#   ('NN', 'richard'),
#   ('NN', 'ii'),
#   ('DT', 'this'),
#   ('VBD', 'was'),
#   ('VBN', 'replaced'),
#   ('IN', 'by'),
#   ('DT', 'a'),
#   ('NN', 'hammerbeam'),
#   ('NN', 'roof'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('NN', 'royal'),
#   ('NN', 'carpenter'),
#   ('NN', 'hugh'),
#   ('VBP', 'herland'),
#   ('DT', 'the'),
#   ('JJS', 'greatest'),
#   ('NN', 'creation'),
#   ('IN', 'of'),
#   ('JJ', 'medieval'),
#   ('NN', 'timber'),
#   ('NN', 'architecture'),
#   ('.', '.')],
#  [('TO', 'to'),
#   ('VB', 'prepare'),
#   ('IN', 'for'),
#   ('PRP$', 'his'),
#   ('NN', 'exam'),
#   ('DT', 'the'),
#   ('NN', 'student'),
#   ('VBD', 'visited'),
#   ('DT', 'the'),
#   ('JJ', 'isa'),
#   ('NN', 'website'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'football'),
#   ('NN', 'club'),
#   ('VBZ', 'has'),
#   ('VBN', 'rescheduled'),
#   ('DT', 'the'),
#   ('NNS', 'trials'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('JJ', 'next'),
#   ('NN', 'day'),
#   ('JJ', 'due'),
#   ('TO', 'to'),
#   ('JJ', 'recent'),
#   ('NN', 'wet'),
#   ('NN', 'weather'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('JJ', 'second'),
#   ('NN', 'lesson'),
#   ('NNS', 'points'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('JJ', 'predominant'),
#   ('NN', 'role'),
#   ('IN', 'of'),
#   ('NN', 'quality'),
#   ('IN', 'over'),
#   ('NN', 'quantity'),
#   ('.', '.')],
#  [('JJ', 'many'),
#   ('NNS', 'times'),
#   ('VBZ', 'journalists'),
#   ('VBP', 'become'),
#   ('DT', 'the'),
#   ('NN', 'topic'),
#   ('IN', 'for'),
#   ('NN', 'discussion'),
#   ('IN', 'among'),
#   ('JJ', 'political'),
#   ('NN', 'party'),
#   ('NNS', 'supporters'),
#   ('IN', 'at'),
#   ('NN', 'press'),
#   ('NNS', 'conferences'),
#   ('.', '.')],
#  [('NNS', 'women'),
#   ('VBP', 'improve'),
#   ('NNS', 'lives'),
#   ('IN', 'of'),
#   ('PRP$', 'their'),
#   ('NNS', 'families'),
#   ('IN', 'with'),
#   ('DT', 'the'),
#   ('NN', 'help'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('JJ', 'few'),
#   ('NN', 'sheep'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'definition'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'vcard'),
#   ('NN', 'specification'),
#   ('VBN', 'made'),
#   ('NN', 'use'),
#   ('IN', 'of'),
#   ('DT', 'a'),
#   ('NN', 'number'),
#   ('IN', 'of'),
#   ('VBG', 'existing'),
#   ('NNS', 'standards'),
#   ('.', '.')],
#  [('DT', 'all'),
#   ('PRP$', 'your'),
#   ('NNS', 'posts'),
#   ('VBP', 'are'),
#   ('VBN', 'imported'),
#   ('IN', 'into'),
#   ('DT', 'the'),
#   ('JJ', 'standard'),
#   ('NN', 'wordpress'),
#   ('NN', 'installation'),
#   ('.', '.')],
#  [('IN', 'without'),
#   ('VBG', 'wasting'),
#   ('NN', 'time'),
#   ('DT', 'a'),
#   ('JJ', 'medical'),
#   ('NN', 'team'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'army'),
#   ('VBD', 'rushed'),
#   ('TO', 'to'),
#   ('DT', 'the'),
#   ('NN', 'house'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'militant'),
#   ('CC', 'and'),
#   ('VBD', 'provided'),
#   ('JJ', 'emergent'),
#   ('JJ', 'medical'),
#   ('NN', 'treatment'),
#   ('TO', 'to'),
#   ('PRP$', 'her'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'report'),
#   ('VBZ', 'provides'),
#   ('DT', 'a'),
#   ('JJ', 'full'),
#   ('NN', 'account'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'societal'),
#   ('NNS', 'impacts'),
#   ('IN', 'of'),
#   ('NN', 'car'),
#   ('NN', 'production'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'siege'),
#   ('VBD', 'started'),
#   ('RB', 'rather'),
#   ('JJ', 'slow'),
#   ('IN', 'with'),
#   ('DT', 'a'),
#   ('NN', 'regiment'),
#   ('IN', 'of'),
#   ('RB', 'lightly'),
#   ('VBN', 'armored'),
#   ('NNS', 'swordsmen'),
#   ('VBG', 'ramming'),
#   ('RP', 'down'),
#   ('DT', 'the'),
#   ('NN', 'gate'),
#   ('.', '.')],
#  [('IN', 'on'),
#   ('DT', 'this'),
#   ('NN', 'basis'),
#   ('DT', 'the'),
#   ('RB', 'vibronically'),
#   ('JJ', 'coupled'),
#   ('NN', 'cd'),
#   ('NNS', 'bands'),
#   ('IN', 'of'),
#   ('JJ', 'lutein'),
#   ('NN', 'diacetate'),
#   ('VBP', 'are'),
#   ('VBN', 'attributed'),
#   ('TO', 'to'),
#   ('DT', 'an'),
#   ('JJ', 'excitonic'),
#   ('NN', 'interaction'),
#   ('VBD', 'arose'),
#   ('IN', 'from'),
#   ('DT', 'the'),
#   ('JJ', 'twisted'),
#   ('JJ', 'nematic'),
#   ('NNS', 'layers'),
#   ('.', '.')],
#  [('NN', 'psa'),
#   ('VBZ', 'is'),
#   ('DT', 'a'),
#   ('NN', 'chemical'),
#   ('VBN', 'produced'),
#   ('RB', 'exclusively'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('NN', 'prostate'),
#   ('NN', 'gland'),
#   ('TO', 'to'),
#   ('VB', 'liquefy'),
#   ('NNS', 'semen'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'pension'),
#   ('NN', 'crisis'),
#   ('VBZ', 'has'),
#   ('VBN', 'been'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('DT', 'the'),
#   ('VBG', 'escalating'),
#   ('NN', 'cost'),
#   ('IN', 'of'),
#   ('VBG', 'funding'),
#   ('NN', 'copper'),
#   ('VBD', 'bottomed'),
#   ('JJ', 'final'),
#   ('JJ', 'salary'),
#   ('NN', 'pension'),
#   ('NNS', 'schemes'),
#   ('RB', 'still'),
#   ('VBN', 'provided'),
#   ('IN', 'unlike'),
#   ('JJS', 'most'),
#   ('NNS', 'companies'),
#   ('IN', 'by'),
#   ('NNS', 'councils'),
#   ('CC', 'and'),
#   ('JJ', 'other'),
#   ('JJ', 'public'),
#   ('NN', 'sector'),
#   ('NNS', 'employers'),
#   ('JJ', 'such'),
#   ('IN', 'as'),
#   ('NN', 'transport'),
#   ('IN', 'for'),
#   ('NN', 'london'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NNS', 'editors'),
#   ('VBP', 'have'),
#   ('VBN', 'inserted'),
#   ('NN', 'narration'),
#   ('IN', 'into'),
#   ('DT', 'the'),
#   ('NN', 'description'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('NN', 'blood'),
#   ('NN', 'clot'),
#   ('VBZ', 'is'),
#   ('DT', 'a'),
#   ('JJ', 'normal'),
#   ('NN', 'reaction'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NN', 'body'),
#   ('WDT', 'that'),
#   ('VBZ', 'occurs'),
#   ('IN', 'if'),
#   ('DT', 'a'),
#   ('NN', 'blood'),
#   ('NN', 'vessel'),
#   ('VBZ', 'is'),
#   ('VBN', 'injured'),
#   ('.', '.')],
#  [('DT', 'a'),
#   ('JJ', 'third'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'injuries'),
#   ('VBP', 'are'),
#   ('VBN', 'caused'),
#   ('IN', 'by'),
#   ('RB', 'illegally'),
#   ('VBN', 'obtained'),
#   ('NNS', 'fireworks'),
#   ('CC', 'and'),
#   ('NNS', 'burns'),
#   ('VBP', 'account'),
#   ('IN', 'for'),
#   ('PDT', 'half'),
#   ('DT', 'the'),
#   ('NNS', 'injuries'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'icon'),
#   ('VBZ', 'is'),
#   ('RB', 'generally'),
#   ('DT', 'a'),
#   ('JJ', 'flat'),
#   ('NN', 'panel'),
#   ('VBG', 'painting'),
#   ('VBG', 'depicting'),
#   ('DT', 'a'),
#   ('JJ', 'holy'),
#   ('VBG', 'being'),
#   ('CC', 'or'),
#   ('NN', 'object'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'weather'),
#   ('VBZ', 'is'),
#   ('RB', 'still'),
#   ('DT', 'the'),
#   ('JJ', 'main'),
#   ('VBG', 'talking'),
#   ('NN', 'point'),
#   ('IN', 'on'),
#   ('DT', 'the'),
#   ('NN', 'front'),
#   ('NNS', 'pages'),
#   ('.', '.')],
#  [('PRP$', 'their'),
#   ('NN', 'relationship'),
#   ('VBZ', 'is'),
#   ('VBN', 'thrown'),
#   ('IN', 'into'),
#   ('NN', 'chaos'),
#   ('.', '.')],
#  [('RB', 'i'),
#   ('VBD', 'wanted'),
#   ('TO', 'to'),
#   ('VB', 'breastfeed'),
#   ('PRP', 'him'),
#   ('WRB', 'when'),
#   ('PRP', 'he'),
#   ('VBD', 'was'),
#   ('JJ', 'hungry'),
#   ('CC', 'and'),
#   ('JJ', 'i'),
#   ('VBD', 'noticed'),
#   ('IN', 'that'),
#   ('PRP', 'he'),
#   ('VBD', 'was'),
#   ('RB', 'not'),
#   ('VBG', 'approving'),
#   ('IN', 'of'),
#   ('PRP$', 'my'),
#   ('NN', 'breast'),
#   ('IN', 'so'),
#   ('JJ', 'i'),
#   ('VBD', 'gave'),
#   ('PRP', 'him'),
#   ('DT', 'a'),
#   ('NN', 'bottle'),
#   ('IN', 'with'),
#   ('NN', 'formula'),
#   ('IN', 'in'),
#   ('PRP', 'it'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'mess'),
#   ('VBD', 'was'),
#   ('RB', 'rapidly'),
#   ('VBN', 'cleaned'),
#   ('IN', 'by'),
#   ('CD', 'one'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('NNS', 'waiters'),
#   ('IN', 'with'),
#   ('DT', 'a'),
#   ('NN', 'mop'),
#   ('CC', 'and'),
#   ('NN', 'disinfectant'),
#   ('CC', 'and'),
#   ('DT', 'the'),
#   ('NN', 'meal'),
#   ('VBD', 'continued'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NNS', 'skies'),
#   ('VBD', 'were'),
#   ('RB', 'also'),
#   ('VBN', 'filled'),
#   ('IN', 'with'),
#   ('DT', 'a'),
#   ('NN', 'desert'),
#   ('IN', 'of'),
#   ('NNS', 'lapwings'),
#   ('CC', 'and'),
#   ('DT', 'a'),
#   ('NN', 'congregation'),
#   ('IN', 'of'),
#   ('JJ', 'golden'),
#   ('NN', 'plover'),
#   ('JJ', 'mixed'),
#   ('RB', 'together'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'cloud'),
#   ('IN', 'of'),
#   ('NNS', 'birds'),
#   ('WDT', 'which'),
#   ('VBD', 'filled'),
#   ('DT', 'the'),
#   ('NN', 'sky'),
#   ('IN', 'as'),
#   ('PRP', 'they'),
#   ('VBD', 'escaped'),
#   ('DT', 'a'),
#   ('NN', 'passing'),
#   ('CC', 'but'),
#   ('JJ', 'unseen'),
#   ('IN', 'by'),
#   ('PRP', 'me'),
#   ('NN', 'predator'),
#   ('.', '.')],
#  [('CD', 'one'),
#   ('IN', 'of'),
#   ('DT', 'the'),
#   ('JJ', 'few'),
#   ('JJ', 'clear'),
#   ('CC', 'and'),
#   ('JJ', 'non'),
#   (':', '-'),
#   ('JJ', 'controversial'),
#   ('NNS', 'norms'),
#   ('VBG', 'governing'),
#   ('NNS', 'issues'),
#   ('IN', 'of'),
#   ('NN', 'state'),
#   ('NN', 'succession'),
#   ('VBP', 'are'),
#   ('DT', 'the'),
#   ('JJ', 'customary'),
#   ('NNS', 'rules'),
#   ('VBN', 'enshrined'),
#   ('IN', 'in'),
#   ('NN', 'article'),
#   ('CD', '11'),
#   ('.', '.')],
#  [('DT', 'the'),
#   ('NN', 'bomb'),
#   ('VBD', 'was'),
#   ('VBN', 'hidden'),
#   ('IN', 'in'),
#   ('DT', 'a'),
#   ('NN', 'toshiba'),
#   ('NN', 'radio'),
#   (':', '-'),
#   ('NN', 'cassette'),
#   ('NN', 'player'),
#   ('WDT', 'which'),
#   ('IN', 'in'),
#   ('NN', 'turn'),
#   ('VBD', 'was'),
#   ('IN', 'inside'),
#   ('DT', 'a'),
#   ('JJ', 'brown'),
#   ('JJ', 'samsonite'),
#   ('NN', 'suitcase'),
#   ('.', '.')],
#  ...]

# %%
dp_token_parents = []
for x in os.listdir('./results/LAL_parser/test'):
    if x.startswith('output_syndephead'):
        dp_token_parents.extend(open('./results/LAL_parser/test/' + x,'r').readlines())

# %%
dp_token_parents = [list(map(int, x[1:-2].split(', '))) for x in dp_token_parents]

# %%
dp_token_relations = []
for x in os.listdir('./results/LAL_parser/test'):
    if x.startswith('output_syndeplabel'):
        dp_token_relations.extend(open('./results/LAL_parser/test/' + x,'r').readlines())

# %%
dp_token_relations = [list(map(lambda k: k[1:-1], x[1:-2].split(', '))) for x in dp_token_relations]

# %%
dep_parser_res = [list(zip(range(1,len(tokens)+1),
                           [t[1] for t in tokens],
                           dp_token_parents[k],
                           dp_token_relations[k])) 
                  for k,tokens in enumerate(tokens_with_pos)]

# %%
dep_parser_res[:3]
# Out:
# [[(1, 'the', 4, 'det'),
#   (2, 'most', 3, 'advmod'),
#   (3, 'common', 4, 'amod'),
#   (4, 'audits', 5, 'nsubj'),
#   (5, 'were', 0, 'root'),
#   (6, 'about', 5, 'prep'),
#   (7, 'waste', 6, 'pobj'),
#   (8, 'and', 7, 'cc'),
#   (9, 'recycling', 7, 'conj'),
#   (10, '.', 5, 'punct')],
#  [(1, 'the', 2, 'det'),
#   (2, 'company', 3, 'nsubj'),
#   (3, 'fabricates', 0, 'root'),
#   (4, 'plastic', 5, 'amod'),
#   (5, 'chairs', 3, 'dobj'),
#   (6, '.', 3, 'punct')],
#  [(1, 'the', 3, 'det'),
#   (2, 'school', 3, 'nn'),
#   (3, 'master', 4, 'nsubj'),
#   (4, 'teaches', 0, 'root'),
#   (5, 'the', 6, 'det'),
#   (6, 'lesson', 4, 'dobj'),
#   (7, 'with', 4, 'prep'),
#   (8, 'a', 9, 'det'),
#   (9, 'stick', 7, 'pobj'),
#   (10, '.', 4, 'punct')]]

# %%
lines = open('./R-BERT/data/test.tsv','r')
lines = lines.readlines()
example_list = list(map(lambda x: x.split('\t'), lines))

# %%
def return_entities(text):
    e1 = re.match('.*\[E11\](.*)\[E12\]',text).groups()[0].strip()
    e2 = re.match('.*\[E21\](.*)\[E22\]',text).groups()[0].strip()
    return (e1,e2)

# %%
entities = [return_entities(x) for x in map(lambda k: k[1], example_list)]
entities_tokenized = [[x.split(), y.split()] for x,y in entities]
entities_tokens_flat = [x.split() + y.split() for x,y in entities]

# %%
dep_parser_token_sets = [set(k[1] for k in x) for x in dep_parser_res]

# %%
exceptional_cases = list(filter(lambda x: any(map(lambda k: k not in dep_parser_token_sets[x[0]],
                              x[1])), 
                          enumerate(entities_tokens_flat)))

# %%
exceptional_case_ids = set(x[0] for x in exceptional_cases)

# %%
def generate_paths_to_root(entity_tokens,
                          term_ids_map,
                          id_dep_id_map):
    paths = []
    for term in entity_tokens:
        t_ids = term_ids_map[term]
        for t_id in t_ids:
            temp = t_id
            temp_path = []
            while temp != 0:
                temp_path.append(temp)
                temp = id_dep_id_map[temp]
            paths.append(temp_path)
    return paths

# %%
def find_shortest_path_between_entities(e1_paths,
                                        e2_paths):
    paths = []
    e1_path_sets = list(map(set,e1_paths))
    e2_path_sets = list(map(set,e2_paths))
    #print(e1_paths)
    #print(e2_paths)
    
    for i1, p1 in enumerate(e1_paths):
        for i2, p2 in enumerate(e2_paths):
            common_ids = e1_path_sets[i1] & e2_path_sets[i2]
            #print('common', common_ids)
            temp_path = []
            for t_id in p1:
                temp_path.append(t_id)
                if t_id in common_ids:
                    break
            #print('p1 end')
            #print(temp_path)
            r_p2 = list(reversed(p2))
            for index,t_id in enumerate(r_p2):
                if t_id not in common_ids:
                    temp_path.extend(r_p2[index:])
                    break
            paths.append(temp_path)
    
    return min(paths,key=len)

# %%
def calculate_sdp(sample_index,sample,exceptional_case_ids):
    res = ['Error']
    
    
    id_term_map = {int(x[0]):x[1] for x in sample}
    term_ids_map = {}
    for x in sample:
        term_ids_map[x[1]] = term_ids_map.get(x[1],[])
        term_ids_map[x[1]].append(int(x[0]))

    id_dep_id_map = {int(x[0]):x[2] for x in sample}
    temp_entities = entities_tokenized[sample_index]

    if sample_index in exceptional_case_ids:
        for i,k in enumerate(sample):
            for ent in temp_entities:
                for ind,e in enumerate(ent):
                    if e.startswith(k[1]) and \
                    (i+1 != len(sample)) and \
                     e.endswith(sample[i+1][1]):
                        ent[ind] = k[1]
                        
    e1 = entities_tokenized[sample_index][0]
    #print(e1)
    e2 = entities_tokenized[sample_index][1]
    #print(e2)
    try:
        e1_paths = generate_paths_to_root(e1,
                                      term_ids_map,
                                      id_dep_id_map)
    except:
        print(sample, e1, term_ids_map, id_dep_id_map)
        raise
    e2_paths = generate_paths_to_root(e2,
                                      term_ids_map,
                                      id_dep_id_map)

    shortest_path =find_shortest_path_between_entities(e1_paths,
                                                       e2_paths)
    res = list(id_term_map[x] for x in shortest_path)

    return res

# %%
res = [calculate_sdp(index,sample,exceptional_case_ids) for index,sample in enumerate(dep_parser_res)]

# %% [markdown]
# ### Additional Step

# %%
for i,r in enumerate(res):
    if r[0] in entities_tokenized[i][0]:
        r[0] = entities[i][0]
        r[-1] = entities[i][-1]
    else:
        print(i)

# %%
res

# %%
import pickle

# %%
pickle.dump(res,open('./lal_parser_test_sdp_results.pkl','wb'))
