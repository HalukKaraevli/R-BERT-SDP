# %%
import json

# %%
train = json.load(open('./tacred/data/json/train.json','r',encoding='utf-8'))
dev = json.load(open('./tacred/data/json/dev.json','r',encoding='utf-8'))
test = json.load(open('./tacred/data/json/test.json','r',encoding='utf-8'))

# %%
train
# Out:
# <_io.TextIOWrapper name='./tacred/data/tsv_cased/train.tsv' mode='r' encoding='utf-8'>

# %%
dataset = test

# %%
def get_entities(sample):
    if sample['obj_start'] < sample['subj_start']:
        e1 = ' '.join(sample['token'][sample['obj_start']:sample['obj_end']+1])
        e2 = ' '.join(sample['token'][sample['subj_start']:sample['subj_end']+1])
    else:
        e2 = ' '.join(sample['token'][sample['obj_start']:sample['obj_end']+1])
        e1 = ' '.join(sample['token'][sample['subj_start']:sample['subj_end']+1])
    return (e1,e2)

def get_entity_tokens(sample):
    if sample['obj_start'] < sample['subj_start']:
        e1 = sample['token'][sample['obj_start']:sample['obj_end']+1]
        e2 =sample['token'][sample['subj_start']:sample['subj_end']+1]
    else:
        e2 = sample['token'][sample['obj_start']:sample['obj_end']+1]
        e1 = sample['token'][sample['subj_start']:sample['subj_end']+1]
    return (e1,e2)

# %%
entities = [get_entities(x) for x in dataset]
entities_tokenized = [get_entity_tokens(x) for x in dataset]
entities_tokens_flat = [x+y for x,y in entities_tokenized]

# %%
dep_parser_res = [list(zip(range(1,len(sample['token'])+1),
                          sample['token'],
                          sample['stanford_head'],
                          sample['stanford_deprel'])) for sample in dataset]

# %%
dep_parser_token_sets = [set(k[1] for k in x) for x in dep_parser_res]

# %%
exceptional_cases = list(filter(lambda x: any(map(lambda k: k not in dep_parser_token_sets[x[0]],
                              x[1])), 
                          enumerate(entities_tokens_flat)))

# %%
exceptional_case_ids = set(x[0] for x in exceptional_cases)

# %%
def generate_paths_to_root(entity_tokens,
                          term_ids_map,
                          id_dep_id_map):
    paths = []
    for term in entity_tokens:
        t_ids = term_ids_map[term]
        for t_id in t_ids:
            temp = t_id
            temp_path = []
            while temp != 0:
                temp_path.append(temp)
                temp = id_dep_id_map[temp]
            paths.append(temp_path)
    return paths

def find_shortest_path_between_entities(e1_paths,
                                        e2_paths):
    paths = []
    e1_path_sets = list(map(set,e1_paths))
    e2_path_sets = list(map(set,e2_paths))
    #print(e1_paths)
    #print(e2_paths)
    
    for i1, p1 in enumerate(e1_paths):
        for i2, p2 in enumerate(e2_paths):
            common_ids = e1_path_sets[i1] & e2_path_sets[i2]
            #print('common', common_ids)
            temp_path = []
            for t_id in p1:
                temp_path.append(t_id)
                if t_id in common_ids:
                    break
            #print('p1 end')
            #print(temp_path)
            r_p2 = list(reversed(p2))
            for index,t_id in enumerate(r_p2):
                if t_id not in common_ids:
                    temp_path.extend(r_p2[index:])
                    break
            paths.append(temp_path)
    
    return min(paths,key=len)

# %%
def calculate_sdp(sample_index,sample,exceptional_case_ids):
    res = ['Error']
    
    
    id_term_map = {int(x[0]):x[1] for x in sample}
    term_ids_map = {}
    for x in sample:
        term_ids_map[x[1]] = term_ids_map.get(x[1],[])
        term_ids_map[x[1]].append(int(x[0]))

    id_dep_id_map = {int(x[0]):x[2] for x in sample}
    temp_entities = entities_tokenized[sample_index]

    if sample_index in exceptional_case_ids:
        for i,k in enumerate(sample):
            for ent in temp_entities:
                for ind,e in enumerate(ent):
                    if e.startswith(k[1]) and \
                    (i+1 != len(sample)) and \
                     e.endswith(sample[i+1][1]):
                        ent[ind] = k[1]
                        
    e1 = entities_tokenized[sample_index][0]
    #print(e1)
    e2 = entities_tokenized[sample_index][1]
    #print(e2)
    try:
        e1_paths = generate_paths_to_root(e1,
                                      term_ids_map,
                                      id_dep_id_map)
    except:
        print(sample, e1, term_ids_map, id_dep_id_map)
        raise
    e2_paths = generate_paths_to_root(e2,
                                      term_ids_map,
                                      id_dep_id_map)

    shortest_path =find_shortest_path_between_entities(e1_paths,
                                                       e2_paths)
    res = list(id_term_map[x] for x in shortest_path)

    return res

# %%
res = [calculate_sdp(index,sample,exceptional_case_ids) for index,sample in enumerate(dep_parser_res)]

# %%
res
# Out:
# [['of', 'department'],
#  ['his', 'power', 'impose', 'Palermo'],
#  ['Vagni', 'Notter', 'Switzerland'],
#  ['he', 'calls', 'repository', 'journalists', 'Western'],
#  ['Association', 'percent', 'named', 'destination', 'PATA', 'Bangkok-based'],
#  ['Helen', 'organization', 'won', 'foundation'],
#  ['ADF', 'said', 'responding', 'group', 'Timor'],
#  ['He', 'had', 'him'],
#  ['missionary', 'Silsby'],
#  ['Television', 'AIA', 'Richard'],
#  ['Lange', 'met', 'Berkeley', 'he'],
#  ['journalist',
#   'owner',
#   'Lomax',
#   'story',
#   'shares',
#   'taking',
#   'family',
#   'her'],
#  ['Katrina', 'name', 'Ramon'],
#  ['Ramon', 'promoted', 'lieutenant', 'captain'],
#  ['her', 'husband', 'maiming', 'friend', 'Nash'],
#  ['he', 'received', 'credentials', 'his'],
#  ['Cain', 'tenure', 'NRA'],
#  ['Miami',
#   'BC-FLA-SCIENTOLOGY-DENTIST',
#   'skilled',
#   'selling',
#   'services',
#   'his'],
#  ['http://www.adb.org/media/Articles/2007/12155-asian-poverties-reductions',
#   'becomes',
#   '*',
#   'http://www.adb.org/ADF',
#   '>',
#   'ADF'],
#  ['Cain', 'records', 'dug', 'Association'],
#  ['Campbell', 'Church'],
#  ['Financial', 'US'],
#  ['his',
#   'appeals',
#   'sentencing',
#   'represented',
#   'Salaam',
#   'got',
#   'term',
#   'seven-year'],
#  ['Hodgson', 'associate', 'Library'],
#  ['ALICO', 'Co', 'shares', 'sell', 'intends', 'said', 'Sato'],
#  ['Heloise'],
#  ['Marshall', 'pleaded', 'aiding', 'murder', 'Aquash'],
#  ['his', 'trial', 'told', 'Wen'],
#  ['15-6-2007', 'edit', 'CIT', 'Craig'],
#  ['Hakka', 'people', 'descendants', 'Taiwan'],
#  ['Monday', 'said', 'responsibility', 'pay', 'workers', 'New'],
#  ['Chongqing', 'officers', 'Daiqiang', 'Tao'],
#  ['PSIA', 'Course', 'provides', 'modules', 'Module', '1'],
#  ['of', 'Whitehorse', 'lived', 'Graham'],
#  ['Helen', 'organization', 'won', 'said', 'Friday'],
#  ['ShopperTrak', 'said', 'indicator', 'Friday', 'Black'],
#  ['Association', 'agrees', 'has', 'stake', 'size', 'Americans'],
#  ['48-year-old', 'Sodini'],
#  ['him',
#   'treating',
#   'doctor',
#   'uncle',
#   'Accompanied',
#   'landed',
#   'ANP',
#   'Dutch'],
#  ['US', 'forced', 'Gross'],
#  ['Lomax', 'shares', 'taking', 'Tuskegee'],
#  ['PDA', 'board', 'includes', 'members', 'leaders', 'Hayden', 'Yearwood'],
#  ['Change', 'premiere', 'getting', 'working', 'planning', 'doing', 'Truth'],
#  ['She', 'moved', 'Paulo', 'born', 'February'],
#  ['Jordan', 'succeeded', 'head', 'League'],
#  ['Dworin', 'president'],
#  ['Mi', 'tribe', 'member', 'Aquash', '30', 'died', 'she'],
#  ['now',
#   'listed',
#   'Will',
#   'explains',
#   'BTW',
#   'learned',
#   'tabloid',
#   'predecessor',
#   'Press'],
#  ['Ladyzhenskiy', 'Kaukonen', 'Finnish'],
#  ['Tao',
#   'said',
#   'traveled',
#   'county',
#   'attend',
#   'ask',
#   'assistance',
#   'Ying-jeou'],
#  ['Pacific', 'meeting', 'attended', 'Tuesday'],
#  ['Morial', 'president', 'League'],
#  ['He', 'said', 'had', 'he'],
#  ['his',
#   'son',
#   'Piedra',
#   'names',
#   'showed',
#   'as',
#   'donors',
#   'building',
#   'Super'],
#  ['Sollecito', 'Knox', 'broke', 'bedroom', 'apartment', 'shared', 'Kercher'],
#  ['Ruben', 'visited', 'hospital', 'recovering', 'he'],
#  ['Silsby', 'know', 'lacked', 'remove', 'earthquake'],
#  ['Ramon', 'Church', 'Lost'],
#  ['his', 'wife', 'sons', 'Jeff'],
#  ['ALICO', 'AIA', 'future'],
#  ['Gross', 'release', 'appealed', 'talked', 'he'],
#  ['7', 'Engineers', 'Richard'],
#  ['she', 'got', 'Scientology'],
#  ['Cerniglia', 'owned', 'west', 'Manhattan'],
#  ['He', 'said', 'remember', 'he'],
#  ['Bryant', 'borrower', 'said', 'threatened', 'Countrywide'],
#  ['Tao', 'unleashed', 'picked', 'Shen'],
#  ['Richard', 'enjoyed', 'trip', 'his'],
#  ['Sunday', 'freed', 'abducted', 'he'],
#  ['National', 'Fassler', 'offered', 'defense', 'Cain', 'GOP'],
#  ['Gonzalez', 'stepped', 'general', 'state', 'Chihuahua'],
#  ['American', 'told', 'he'],
#  ['Sabastawi', 'Jawad', 'Pizza', 'Church', 'Ramon'],
#  ['Giago', 'talks', 'fails', 'mention', 'FBI', 'ordered', 'hands', 'Mae'],
#  ['Cerniglia', 'friend', 'director', 'Edwards', 'said', 'thought', 'he'],
#  ['Denaro', 'said', 'adding', 'confident', 'arrest', 'him'],
#  ['Goude', 'quoted', 'saying', 'have', 'Ouattara', 'minister', 'his'],
#  ['LIHOP', 'Hoaxer'],
#  ['Daniels', 'drop', 'service', 'Sunday'],
#  ['Looking', 'took', 'said', 'Jackley'],
#  ['Antara', 'of'],
#  ['China', 'mantra', 'embraced', 'vigorously', 'Qiang'],
#  ['Coast', 'ambassador', 'Bamba'],
#  ['Mack', 'hired', 'Boyd', 'working', 'League'],
#  ['Aquash', 'Indian', 'Canada'],
#  ['Press', 'discovery', 'have', 'half', 'soldiers', 'returned', 'recently'],
#  ['Press', 'October'],
#  ['PDA', 'board', 'includes', 'members', 'leaders', 'Hayden', 'Hartmann'],
#  ['Troof',
#   'days',
#   'remember',
#   'got',
#   'videos',
#   'ukeleles',
#   'singing',
#   'LIHOP'],
#  ['Silsby', 'freed', 'told', 'lawyer', 'her'],
#  ['She', '61'],
#  ['she', 'beaten', 'Santos', 'officer'],
#  ['Beginning', 'Journey', 'called', 'magazine', 'wrote', 'mother', 'his'],
#  ['he', 'modified', 'loan', '4-year-old'],
#  ['Barnes', 'member', 'Instructors'],
#  ['he', 'safari', 'Trudy', 'Patrick'],
#  ['Gross', 'working', 'arrested', 'December'],
#  ['Vagni', 'said', 'day', 'release', 'his'],
#  ['physicist', 'Lange'],
#  ['ShopperTrak', 'reported', 'rose', 'period', 'ago'],
#  ['Fisher', 'Think', 'newworldlibrary'],
#  ['He',
#   'regret',
#   'reported',
#   'telling',
#   'neighborhood',
#   'surrounded',
#   'mob',
#   'peacekeeper',
#   'one'],
#  ['ADF', 'Fund', 'provide', 'help', 'achieve', 'said', 'eradication', 'Times'],
#  ['Framework', 'ADF'],
#  ['his', 'legs', 'repair', 'underwent', 'say', 'recovering', 'he'],
#  ['he', 'working', 'communicate', 'another', 'one'],
#  ['Tripoli',
#   'arrived',
#   'am',
#   'taken',
#   'make',
#   'sure',
#   'see',
#   'faces',
#   'next',
#   'bed',
#   'his'],
#  ['Lu', 'Peng', 'Tao'],
#  ['the', 'jurors', 'convicted', 'acquitted', 'him'],
#  ['Vagni', '62'],
#  ['attorney', 'Filmmaker', 'Kunstler'],
#  ['eight', 'titles', 'selling', 'LLC', 'company', 'formed', 'Management'],
#  ['Sousa', 'suspected', 'friends', 'beaten', 'hidden', 'body', 'her'],
#  ['Rosen',
#   'Email',
#   'Help',
#   'Read',
#   'stream',
#   'Watch',
#   'Watch',
#   'Download',
#   'Listen',
#   'journalist',
#   'author'],
#  ['he', 'explain', 'money', 'amounts', 'owning', 'charged', 'charged', 'rape'],
#  ['she', 'hung', 'org', 'Honolulu'],
#  ['Countrywide', 'Mozilo'],
#  ['Graham', 'member', 'Canada'],
#  ['Daniels', 'found', 'Sunday'],
#  ['Cuba', 'butcher', 'is', 'knows', 'Dworin'],
#  ['Prachai', 'founder', 'Industry'],
#  ['he', 'posted', 'picture', 'nullifies', 'point', 'his'],
#  ['him',
#   'treating',
#   'doctor',
#   'uncle',
#   'accompanied',
#   'told',
#   'Prommersberger',
#   'ministry'],
#  ['Gonzalez', 'described', 'met', 'Baeza', 'Chihuahua'],
#  ['100', 'demonstrators', 'rallied', 'warning', 'pardon', 'Bibi'],
#  ['Pakistani', 'lawmaker'],
#  ['ALICO', 'active', 'assurance', 'States'],
#  ['Federation', 'donated', 'Province'],
#  ['Anadarko',
#   'Palczynsky',
#   'said',
#   'disconcerting',
#   'taken',
#   'steps',
#   'make',
#   'sure',
#   'secure',
#   'church',
#   'his'],
#  ['Lomax', 'president', 'Fund'],
#  ['Filmmaker', 'Kunstler'],
#  ['Force', 'chiefs', 'Beaumont', 'Gration'],
#  ['ambassador', 'Bamba'],
#  ['800', 'Jews', 'down', 'were', 'said', 'Dworin'],
#  ['ALICO', 'FAS', 'Life', '60'],
#  ['Graham', 'left', 'place', 'says', 'Herman', 'assistant'],
#  ['Oct.', 'kick', 'Festival', 'County', 'Taiwan'],
#  ['his', 'pistol', 'drew', 'emerged', 'Herold'],
#  ['one', 'creditors', 'Piedra'],
#  ['Dean', 'open', 'death', 'Jupp'],
#  ['Mexico', 'CHIHUAHUA', 'stormed', 'offices', 'Gonzalez'],
#  ['he', 'explain', 'money', 'amounts', 'owning', 'charged', 'charged', 'Wen'],
#  ['Kunstler', 'said', 'ironic', 'took', 'occurred', 'war'],
#  ['NTSO', 'organized', 'cooperation', 'Administration'],
#  ['13', 'age', 'moved', 'him'],
#  ['CEPN', 'Network', 'member', 'SAVE', 'VOTE', 'Democrats', 'America', 'PDA'],
#  ['Scrapblog', 'used', 'create', 'pictures', 'trip', 'took', 'England'],
#  ['Qiang', 'went', 'trial', 'rape'],
#  ['Xie', 'notorious', 'toughness', 'her'],
#  ['Jackley',
#   'prompting',
#   'acknowledged',
#   'remembered',
#   'asking',
#   'let',
#   'stay',
#   'Aquash'],
#  ['Orchestra', 'Festival', 'announced', 'Pi-twan', 'Council'],
#  ['Assouw', 'arrived', 'days', 'disaster'],
#  ['Association', 'published', 'Girls', 'Shortchanging'],
#  ['He', 'survived', 'parents', 'sister', 'Lange'],
#  ['ShopperTrak', 'expected', 'release', 'Monday'],
#  ['Now', 'sought', 'Rashid'],
#  ['Congress', 'faced', 'recently'],
#  ['she', 'high', 'drugs'],
#  ['Bibi', 'confessed', 'committing', 'quarrel', 'women', 'Muslim'],
#  ['League', 'president', 'chairman', 'Committee'],
#  ['his', 'organization', 'CIT'],
#  ['Cerniglia', 'friend', 'director', 'Edwards', 'said', 'thought', 'he'],
#  ['Mamane', 'said', 'translator'],
#  ['Bibi', 'freed', 'recommending', 'delivered', 'Thursday'],
#  ['Organisation', 'signed', 'Antara'],
#  ['he'],
#  ['he', 'put', 'ideas', 'his'],
#  ['Guild', 'worked', 'joining', 'League'],
#  ['Anna'],
#  ['Bamba', 'gave', 'Wednesday'],
#  ['she', 'suffered', 'final', 'championship', 'Heinola', 'city', 'Finland'],
#  ['Sollecito', 'said', 'apartment', 'he'],
#  ['year', 'day', 'ShopperTrak'],
#  ['Collection', 'museum', 'wrote', 'Richard'],
#  ['ADF', 'Forces', 'Democratic'],
#  ['Asia', 'Islam', 'Rise', 'Rashid'],
#  ['Church', 'Officials', 'knew', 'said', 'sister', 'Wright'],
#  ['GOPAC',
#   'chairman',
#   'Steele',
#   'said',
#   'demonstrated',
#   'ability',
#   'connect',
#   'groups',
#   'Association',
#   'League'],
#  ['Shelby', 'asked', 'helped', 'route', 'her'],
#  ['PDA', 'board', 'includes', 'members', 'leaders', 'Hayden', 'Sheehan'],
#  ['Samudio', 'kidnapped', 'killed', 'later'],
#  ['Congress', ','],
#  ['Gage',
#   'speaker',
#   'BOULDER',
#   'present',
#   'evidence',
#   'destruction',
#   '2pm',
#   'auditorium',
#   'Mathematics'],
#  ['Shellenberger', 'soloists', 'perform', 'invitation', 'NTSO'],
#  ['murder', 'Aquash'],
#  ['attack', 'recovery', 'bit', 'clawed', 'face', 'her'],
#  ['She', 'said', 'made', 'years', 'her'],
#  ['New', 'Rosen'],
#  ['she', 'filed', 'police', 'Rio'],
#  ['UNWTO', 'Organization', 'declined', 'reported', 'Association'],
#  ['his', 'wife', 'Mailer'],
#  ['Fort', 'attorney', 'drawn', 'ads', 'Piedra'],
#  ['Knox', '22'],
#  ['journalist', 'Rashid'],
#  ['of',
#   'reform',
#   'part',
#   'reauthorized',
#   'Act',
#   'success',
#   'signed',
#   'recently'],
#  ['Jupp',
#   'died',
#   'conducting',
#   'experiments',
#   'nature',
#   'explained',
#   'thought',
#   'collaboration',
#   'laboratory',
#   'U.S.'],
#  ['Alessi', 'Citgo'],
#  ['Heloise', 'recalls', 'time', 'applied', 'she'],
#  ['Countrywide'],
#  ['Heloise',
#   'Mulrenan',
#   'McBurney',
#   'called',
#   'occasion',
#   'looks',
#   'loved',
#   'she'],
#  ['Caiping', 'sister-in-law', 'sentenced', 'years'],
#  ['U.N.', 'ambassador', 'Bamba'],
#  ['his', 'brothers', 'him'],
#  ['co', 'editor', 'Minow', 'founder', 'Library'],
#  ['Barker', 'held', 'kept', 'her'],
#  ['governor', 'office', 'front', 'railed', 'calling', 'release', 'Bibi'],
#  ['Qiang', 'stood', 'Court', 'People', '5'],
#  ['Vagni', 'told', 'imagined', 'he'],
#  ['him', 'shows', 'became', 'Rashid'],
#  ['genocide', 'brink', 'said', 'he'],
#  ['Korea', 'gone', 'friends', 'told', 'said', 'Chen'],
#  ['International', 'http://wwwhkiorg/'],
#  ['Rosen', 'book', 'Belly'],
#  ['Federation', 'said', 'tents', '400'],
#  ['he', 'understand', 'attracted', 'him'],
#  ['ShopperTrak', 'Martin', 'said', 'laws', 'limit', 'hours', 'Sunday'],
#  ['Bollyn', 'August', 'headquarters', 'Blvd.', 'John'],
#  ['American', 'http://www.americanfreepress.net/'],
#  ['sekitar', 'Celancang', 'Jakarta/Indramayu', 'Ikan'],
#  ['he', 'unaware', 'fact', 'Maine'],
#  ['Denaro', 'helped', 'providing', 'documents', 'conducting', 'behalf', 'his'],
#  ['Coalition', 'Troops', 'Center', 'of'],
#  ['Canada', 'Yukon', 'along', 'Cloud'],
#  ['he', 'think', 'dead', 'she'],
#  ['Her', 'baby', 'located', 'Saturday'],
#  ['Ladyzhenskiy', 'wrestler'],
#  ['7', 'building', 'fall', 'picked', ',', 'worship', 'Gage'],
#  ['One', 'point', 'lenders', 'Countrywide'],
#  ['two-hour', 'lunch', 'said', 'worries', 'he'],
#  ['BestPartyEvercom', 'CEO', 'Strebel'],
#  ['Silsby', 'accused', 'Americans'],
#  ['Samudio', 'assaulting', 'her'],
#  ['Sea', 'canteen', 'door', 'night', 'opened', 'walked', 'she'],
#  ['Mozilo', 'officer', 'Countrywide'],
#  ['Piedra', 'entanglements', 'Scientologists'],
#  ['doctor', 'Dilla', 'said', 'getting', 'he'],
#  ['his', 'models', 'one', 'million', 'manufacturers', 'Alessi'],
#  ['Alessi',
#   'made',
#   'claims',
#   'lawyers',
#   'preparing',
#   'appeal',
#   'conviction',
#   'his'],
#  ['Kunstler', 'daughter', 'co-director', 'film', 'father', 'her'],
#  ['Ladyzhenskiy', 'Kaukonen'],
#  ['three', 'synagogues', 'none', 'authorized', 'said', 'Dworin'],
#  ['attorney', 'Gonzalez'],
#  ['Vagni', 'Notter', 'Lacaba', 'Filipina'],
#  ['and', 'development', 'playing', 'told', 'Xinhua'],
#  ['Congress', 'wrote', 'Cameron'],
#  ['Panthers', 'League'],
#  ['Force', 'Australia', 'Authority'],
#  ['Ly', 'Christmas', 'used', 'Scrapblog'],
#  ['Daniels', 'traveled', 'Sunday'],
#  ['League', 'International'],
#  ['Denaro', 'Sicily'],
#  ['Rios', 'said', 'relayed', 'reported', 'taken', 'Aquash'],
#  ['August',
#   'detained',
#   'accused',
#   'protecting',
#   'operations',
#   'masterminded',
#   'sister-in-law',
#   'Caiping'],
#  ['Chiafari', 'shock', 'sent', 'girl', '10-year-old'],
#  ['Tuesday', 'operation', 'made', 'circle', 'his'],
#  ['Leader', 'Boehner', 'Work', 'Week', 'orchestrate', 'Lomax'],
#  ['Commission', 'NDRC'],
#  ['Herold', 'attorney', 'called', 'said', 'treated', 'case', 'family', 'her'],
#  ['his', 'mother', 'nothing', 'mentioned', 'said', 'Morton', 'Superintendent'],
#  ['footballer', 'threatened', 'her'],
#  ['Goude', 'calling', 'gather', 'district', 'Yopougon'],
#  ['Looking'],
#  ['One', 'defenders', 'Bibi'],
#  ['his', 'role', 'organising', 'streets', 'Abidjan'],
#  ['He', 'defendants', 'his'],
#  ['Dossett', 'lawyer', 'Congress'],
#  ['10', 'countries', 'surveyed', 'Pacific', 'PATA'],
#  ['TPI', 'Utomo', 'umum', 'pihaknya'],
#  ['Association', 'PATA'],
#  ['NDRC',
#   'Commission',
#   'Development',
#   'minister',
#   'Kai',
#   'announced',
#   'lift',
#   '2010'],
#  ['Pravda', 'AFP'],
#  ['he'],
#  ['ERP', 'System', 'Oracle', 'SAP'],
#  ['Rashid', 'analyst', 'author'],
#  ['he', 'working', 'center', 'Jewish'],
#  ['his', 'chance', 'has', 'bores', 'Alessi'],
#  ['LIHOP', 'Progressive', 'Liberal', '5.0', 'Moderate', '5.7'],
#  ['She', 'prosecuted', 'Sainvil', 'pastor', 'Atlanta-based'],
#  ['MGE', 'training', 'sending', 'bus', 'plane', 'flew', 'he'],
#  ['Gross', 'charges', 'expects', 'separate', 'said', 'Alarcon'],
#  ['Gresik', 'is', 'seek', 'approval', 'build', 'plants', 'plants', 'five'],
#  ['Countrywide', 'Kurland'],
#  ['Rashid', 'called', 'discussed', 'became', 'seemed', 'he'],
#  ['MCA', 'Affairs', 'Ministry', 'received', 'received', 'Federation'],
#  ['2010', 'NTSO'],
#  ['his'],
#  ['CAEFI', 'Investment', 'Association', 'China'],
#  ['PATA',
#   'Association',
#   'ceremony',
#   'held',
#   'Hangzhou',
#   'capital',
#   'Province'],
#  ['Hagemo', 'put', 'doubts', 'her'],
#  ['Currently', 'featured', 'Collection'],
#  ['25-year-old', 'Samudio'],
#  ['Jupp', 'family', 'accused', 'previously'],
#  ['League', 'directs', 'mayor', 'Morial', 'told', 'PBS'],
#  ['Tamaihia', 'placed', 'home', 'Walker'],
#  ['he', 'taken', 'steps', 'make', 'sure', 'secure', 'church', 'his'],
#  ['Attorney',
#   'Jackley',
#   'recounted',
#   'believe',
#   'happened',
#   'days',
#   'leading',
#   'up',
#   'slaying',
#   'Aquash'],
#  ['Martin', 'founder', 'ShopperTrak'],
#  ['Chiafari', 'first', 'respond', 'call', '911'],
#  ['his', 'reporting', 'appeared', 'warned', 'decision', 'support', 'Taliban'],
#  ['Avery', 'shows', 'caught', 'he'],
#  ['Chertoff', 'Editor', 'Chief', 'magazine', 'Popular'],
#  ['Bamba', 'diplomat', '60-year-old'],
#  ['He', 'formed', 'sold', 'left', 'start', 'line', 'Motorola'],
#  ['Congress', 'wrote', 'Cameron'],
#  ['Graham', 'defendant', 'shot', 'thought', 'informant', 'she'],
#  ['Kercher', 'family', 'suing', 'Knox'],
#  ['Samudio', '25'],
#  ['Chiafari', 'said', 'returned', 'received', 'months'],
#  ['2008', 'said', 'seems', 'underway', 're-shape', 'image', 'Goude'],
#  ['Aquash', 'accused', 'leaving', 'die', 'reservation', 'Dakota'],
#  ['Koldowski', 'director', 'centre', 'Association', 'PATA'],
#  ['Library', 'appears', 'group', 'independent'],
#  ['ALICO', 'sold', 'Inc'],
#  ['CEO', 'President', 'Spahn', 'International'],
#  ['Bibi',
#   'held',
#   'Taseer',
#   'said',
#   'forwarded',
#   'petition',
#   'presenting',
#   'Zardari',
#   'President'],
#  ['Church', 'name', 'suggested', 'Mailer'],
#  ['lieutenant', 'Goude'],
#  ['he', 'left', 'said', 'Informed', 'looked', 'she'],
#  ['Gresik', 'stake', 'paid', 'option', 'increase', '2001'],
#  ['County', 'sending', 'bus', 'plane', 'flew', 'he'],
#  ['Peugeot', 'Renault', 'said', 'responsibility', 'pay', 'workers', 'New'],
#  ['she'],
#  ['Sycamore', 'specializes', 'providing', 'using', 'technology', 'Java'],
#  ['College', 'team', 'teenager', 'shows', 'became', 'Rashid'],
#  ['Letterman',
#   'Show',
#   'appearance',
#   'denying',
#   'time',
#   'running',
#   'Association'],
#  ['one', 'move', 'seems', 'said', 'Lomax'],
#  ['Rashid', 'views', 'his'],
#  ['Rashid', 'journalist', 'author'],
#  ['Craig', 'statements', 'approaching', 'evidence', 'his'],
#  ['Sacramento', 'toddler', 'mother', 'arrested', 'murder', 'her'],
#  ['She',
#   'testified',
#   'forced',
#   'sign',
#   'affidavits',
#   'prepared',
#   'Price',
#   'FBI'],
#  ['Denaro', 'trying', ',', 'capital', 'Sicilian'],
#  ['one', 'wants', 'League'],
#  ['Energy'],
#  ['Gross', 'accused', 'espionage'],
#  ['Gresik', 'added', '150'],
#  ['Donald', 'Lead', 'Web', 'Creator', 'Sipe', 'Fisher'],
#  ['http://www.investigativeproject.org/docs/misc/25.pdf',
#   'Committee',
#   'Palestine',
#   'included',
#   'HLF',
#   'Association'],
#  ['attack',
#   'work-related',
#   'called',
#   'said',
#   'treated',
#   'case',
#   'family',
#   'her'],
#  ['his', 'congressman', 'Poe'],
#  ['ADF', 'police', 'AFP', 'go', 'club', 'RSL'],
#  ['Ouloto', 'claimed', 'aimed', 'Goude'],
#  ['Saturday', 'Friday', 'sales', 'rose', 'ShopperTrak'],
#  ['Heloise', 'met', 'recently'],
#  ['Hodgson', 'associate', 'Library'],
#  ['2007', 'call', 'cited', 'lawyers', 'called', 'executive', 'Countrywide'],
#  ['Corp.', 'Co.', 'Inc.'],
#  ['Enterprises', 'officer', 'director', 'Festival'],
#  ['Bibi', 'committed', 'gathered', 'crowd', 'forced', 'her'],
#  ['10-minute', 'video', 'ends', 'word', 'fate', 'Gonzalez'],
#  ['League', 'likely', 'Americans'],
#  ['Nuclear'],
#  ['Sycamore', 'HS', 'dates', '3/15', 'End', 'tournament', 'Season'],
#  ['two', 'wives', 'Parad', 'held', 'said', 'Vagni'],
#  ['He', 'woke', 'night', 'Wednesday'],
#  ['Heloise', 'exclaims', 'shaking', 'look', 'her'],
#  ['Hagemo', 'decided', 'tell', 'break', 'her'],
#  ['Association',
#   'head',
#   'serving',
#   'harassed',
#   'allegations',
#   'come',
#   'reports',
#   'The'],
#  ['Lange', 'had', 'chairman'],
#  ['Countrywide',
#   'operations',
#   'value',
#   'underestimating',
#   'believe',
#   'said',
#   'chairman',
#   'Lewis'],
#  ['years', 'sentenced', 'convicted', 'trial', 'rejected', 'used', 'Kercher'],
#  ['Peltier', 'implicated', 'turned', 'Aquash'],
#  ['two', 'groups', 'leaders', 'denied', 'having', 'anything', 'do', 'him'],
#  ['Her', 'brother-in-law', 'Wen'],
#  ['Gonzalez', 'attorney'],
#  ['the', 'Mailer'],
#  ['Association', 'NRA'],
#  ['Bibi',
#   'drew',
#   'dispute',
#   'June',
#   'refused',
#   'refused',
#   'demands',
#   'convert',
#   'Islam'],
#  ['Qi', 'director', 'Administration'],
#  ['Association',
#   'gave',
#   'salary',
#   'pay',
#   'made',
#   'working',
#   'said',
#   'Tuesday'],
#  ['she', 'Compound', 'June'],
#  ['Miettinen', 'hired', 'Blue'],
#  ['genocide', 'brink', 'said', 'presenting', 'credentials', 'his'],
#  ['Graham', 'took', 'Looking'],
#  ['Shield', 'provided', 'ADF'],
#  ['Change', 'Zeitgeist'],
#  ['Lomax', 'president', 'Fund'],
#  ['Gonzalez', 'kidnapping', 'represent', 'similarities', 'propaganda', 'the'],
#  ['Cloud', 'Graham', 'told', 'take', 'Aquash'],
#  ['Chiafari', '53'],
#  ['ERP', 'technology', 'using', 'Oracle', 'SAP'],
#  ['He', 'said', 'remember', 'Looking'],
#  ['Qiang', 'provided', 'told', 'umbrella', 'mafia', 'Chongqing'],
#  ['Administration', 'reviews', 'consumption', 'China'],
#  ['Vagni', 'snatched', 'Committee'],
#  ['Sycamore', 'HS', 'dates', '3/15', '5/3'],
#  ['Association', 'speech', 'unsparing', 'Monday'],
#  ['6,550', 'rupiah', 'gained', 'advanced', 'Gresik'],
#  ['Rukwago', 'commander', 'ADF'],
#  ['Manila', 'reunited', 'he'],
#  ['Israel', 'has', ',', 'Pizza', 'Church', 'Ramon'],
#  ['Kunstler', 'acquitted', 'trial', 'charges', 'brought', 'arrest', 'her'],
#  ['Countrywide', 'funded', 'one', 'five'],
#  ['Gonzalez', 'beaten', 'feet', 'his'],
#  ['His', 'friends', 'described', 'man', 'had', 'eye', 'his'],
#  ['of', 'Bollyn'],
#  ['Corp.'],
#  ['Mailer', 'died', 'home', 'Brooklyn', 'NY'],
#  ['Denaro', 'bosses', 'competing', 'arrest', 'Provenzano'],
#  ['Alessi', 'said', 'asked', 'he'],
#  ['Cerniglia', 'owner', '39-year-old'],
#  ['Coast',
#   'militias',
#   'leader',
#   'imposed',
#   'sanctions',
#   'lifting',
#   'set',
#   ',',
#   'Goude'],
#  ['900', 'words', 'Klein', 'Lomax'],
#  ['Minow', 'co-founder', 'Library'],
#  ['her', 'put', 'reader'],
#  ['and', 'Minister', 'Xuren'],
#  ['he', 'fathered', 'child', 'born', '1991'],
#  ['murphy', 'Pizza', 'Church', 'Ramon'],
#  ['40', 'Silsby', 'asked', 'consider', 'she'],
#  ['Dworin', 'said', 'is', 'concern', 'cause', 'Jews'],
#  ['ADF', 'template', 'using', 'All', 'enable', 'bit', 'POS'],
#  ['Qiang', 'director', 'department', 'Chongqing'],
#  ['Gresik', 'gained', '5,900'],
#  ['recently', 'deceased', 'brother', 'relations', 'asked', 'put', 'her'],
#  ['Goude', 'changed', 'style', 'his'],
#  ['Gresik', 'added', '5,900'],
#  ['summers', 'pace', 'adding', 'said', 'Riehle', 'president', 'Association'],
#  ['She', 'picking', 'sent', 'she'],
#  ['ton-based', 'Information', 'Folkers', 'told', 'AFP'],
#  ['Caiping', 'testimony', 'drew', 'week'],
#  ['Gonzalez', 'said', 'kidnapped', 'brother', 'her'],
#  ['China',
#   'Russia',
#   'developing',
#   'cooperation',
#   'framework',
#   'Organization',
#   'OANA'],
#  ['ALICO', 'Company', 'selling', 'Inc'],
#  ['Denaro', 'accused', 'seeking', 'reconstruct', 'leadership', 'Nostra'],
#  ['him', 'worst', 'day'],
#  ['Fisher', 'writes', 'News'],
#  ['Countrywide', 'Simon'],
#  ['one', 'butcher', 'is', 'knows', 'does', 'she'],
#  ['She', 'insisted', 'help', 'continue', 'studies', 'her'],
#  ['Customs', 'agents', 'Immigration', 'seized', 'plant', 'Koch'],
#  ['Inn', 'dorm', 'lived', 'Heloise'],
#  ['Sycamore', 'coming', 'brothers', 'done', 'want', 'wrote', 'she'],
#  ['Qiang', 'case', 'biggest', 'series', 'city', 'Chongqing'],
#  ['Chongqing', 'officers', 'Daiqiang', 'Tao'],
#  ['Bibi', 'sentenced', 'hang', 'province', 'Punjab'],
#  ['Spooner', 'family', 'Sherrod', 'invited', 'wish', 'story', 'American'],
#  ['Silsby', '40'],
#  ['her', 'children', 'orphanage', 'run', 'charity', 'Children'],
#  ['Ladyzhenskiy', 'pronounced', 'collapsed', 'he'],
#  ['Nemours', 'biologist'],
#  ['states', 'speaking', 'heard', 'him'],
#  ['Travel'],
#  ['Library', 'firm', 'independent'],
#  ['him', 'return', 'waiting', 'said', 'Dworin'],
#  ['of', 'department', 'Corporation'],
#  ['United', 'Bamba', 'gave', 'received', 'he'],
#  ['Chertoff', 'cousin', '25-year-old'],
#  ['caller', 'asked', 'crazy', 'him'],
#  ['Gross', 'American', 'Potomac'],
#  ['Baldino', 'said', '2002'],
#  ['NYU', 'professor', 'resigned', 'position', 'his'],
#  ['Andreas',
#   'Jean',
#   'release',
#   'secure',
#   'worked',
#   'those',
#   'express',
#   'like',
#   'added',
#   'he'],
#  ['Israel', 'Cost', '$', 'Bollyn'],
#  ['her'],
#  ['He', 'arrested', 'accused', 'Castro', 'President'],
#  ['Department', 'Services', 'Congress', 'NCAI'],
#  ['Goude', 'told', 'AFP'],
#  ['he', 'talks', 'shows', 'bedroom', 'his'],
#  ['he', 'forced', 'visit', 'confront', 'fear', 'his'],
#  ['9-11', 'Mysteries', 'Change'],
#  ['internet', 'shouted', 'LIHOP'],
#  ['Dylan', 'wise', 'see', 'bottom-feeder', 'interest', 'telling', 'he'],
#  ['ShopperTrak', 'released', 'figures', 'rose', 'day', 'the'],
#  ['Dworin', 'president', 'Shalom', 'Havana'],
#  ['Pakistani', 'Rashid'],
#  ['Cloud', 'Graham', 'told', '1975'],
#  ['Countrywide', 'posted', 'quarter'],
#  ['he', 'fed', 'captors', 'treated', 'him'],
#  ['Russia', 'developing', 'cooperation', 'framework', 'Organization'],
#  ['Assouw', 'safari', 'Trudy', 'Patrick', 'Enzo'],
#  ['Alessi', 'said', 'Catholic', 'lost', 'illusions', 'her'],
#  ['Mailer', 'wife', 'model', 'painter'],
#  ['Foods', 'Fairfield', 'Ohio'],
#  ['Dunlap', 'mother', 'said', 'spent', 'Daniels'],
#  ['Tim', 'assume', 'leadership', 'team', 'based', 'China', 'Fisher'],
#  ['Romney', 'Contributions', 'made', 'director', 'Association'],
#  ['his'],
#  ['LC', 'film', 'said', 'tell', 'release', 'Hollywood'],
#  ['Caiping', 'labeled', 'sentenced', 'years'],
#  ['Dream', 'rally', 'Reclaim', 'plans', 'Network', 'National'],
#  ['lawmaker', 'Fisher'],
#  ['Her', 'attorney', 'asked', 'assertion', 'deceived', 'she'],
#  ['and', 'Xiaoxiong', 'Director', 'Minister', 'Deming', 'Biao'],
#  ['Wednesday', 'said', 'envoy', 'Bamba'],
#  ['China',
#   'India',
#   'countries',
#   'wealth',
#   'globalization',
#   'said',
#   'Allen',
#   'partner',
#   'TPI'],
#  ['Gross', 'passes', 'days', 'his'],
#  ['and', 'makers', 'three'],
#  ['Chiafari', 'Chimp', 'drove', 'him'],
#  ['His', 'girlfriend', 'lives', 'travels', 'he'],
#  ['ALICO', 'portfolio', 'fraction', 'one', 'Products', 'shop', 'London'],
#  ['he', 'owned', 'home', 'his'],
#  ['National', 'Morial'],
#  ['Mujahid', 'name', 'Ramon'],
#  ['USAID', 'program', 'part', 'Cuba', 'made', 'release', 'his'],
#  ['Fisher',
#   'producer',
#   'appointed',
#   'producer',
#   'nominated',
#   'producer',
#   'Games',
#   '2006'],
#  ['A', 'opened', 'NDA'],
#  ['UK', 'programme', 'cost', 'thought', 'higher', 'Authority'],
#  ['Logan', 'made', 'he'],
#  ['brown', 'jacket', 'accentuated', 'loss', 'his'],
#  ['Alessi', 'considers', 'one', 'experiences', 'Rome'],
#  ['her'],
#  ['Library', 'study', 'showed', 'rose', '2005'],
#  ['CBS',
#   'Rosen',
#   'remarks',
#   'resigns',
#   'forced',
#   'resign',
#   'comments',
#   'made',
#   'he'],
#  ['Lahore', 'city', 'hundreds', 'threatened', 'released', 'Bibi'],
#  ['two', 'wondered', 'look', 'she'],
#  ['Church', 'Ramon'],
#  ['his',
#   'breath',
#   'catch',
#   'sure',
#   'make',
#   'Let',
#   'said',
#   'television',
#   'Dutch'],
#  ['Dylan', 'saying', 'sorry', 'he'],
#  ['African', 'audiences', 'shows', 'one', 'said', 'he'],
#  ['National', 'survey', 'found', 'said', 'hot', 'cuisine', 'Latin'],
#  ['Loans',
#   'continues',
#   'goal',
#   'revolutionize',
#   'business-concepts',
#   'service',
#   '8212'],
#  ['he', 'Chertoff'],
#  ['Belarus', 'town', 'came', 'said', 'Dworin'],
#  ['Coast', 'stand-off', 'brought', ',', 'General', 'Goude'],
#  ['40', 'kilometers', 'miles', 'west', 'bought', 'he'],
#  ['Jan.', 'kidnapping', 'Vagni'],
#  ['Mamane', 'said', 'translator', 'French'],
#  ['Analysis', 'presents', 'elaborates', 'range', 'tools', 'used', 'PSIA'],
#  ['activist', 'group', 'leaders', 'thought', 'informant', 'she'],
#  ['10', 'times', 'dangerous', 'he'],
#  ['911', 'numbers', 'stack', 'numbers', 'his'],
#  ['Trapani', 'says', 'amazed', 'she'],
#  ['five',
#   'members',
#   'represented',
#   'committee',
#   'said',
#   'worked',
#   'Citigroup',
#   'Financial'],
#  ['Libyan', 'doctor', 'treating', 'him'],
#  ['Mellas', 'visit', 'daughter', 'her'],
#  ['Force', 'cut', 'year'],
#  ['Alessi', 'said', 'alluding', 'report', 'Newsday'],
#  ['New', 'YouTube', 'AIA', 'Richard'],
#  ['Spooner', 'said', 'far', 'concerned', 'she'],
#  ['Aziz', 'leader', 'mosque', 'the'],
#  ['Development'],
#  ['Fazlullah', 'mission', 'same', 'said', 'Aziz'],
#  ['her', 'husband', 'Shelby'],
#  ['Asia', 'Afghanistan', 'homeland', 'his'],
#  ['recently', 'underwent', 'evaluation', 'determine', 'candidate', 'she'],
#  ['32-year-old', 'Tao'],
#  ['League', 'outlined', 'State', 'America', '2007'],
#  ['ALICO', 'looking', 'developer', 'one'],
#  ['League', 'bought', 'School'],
#  ['Bruno', 'wishes', 'carrying', 'make', 'disappear', 'Samudio'],
#  ['Hernandez', 'spy', 'wife', 'allowed', 'visit', 'husband', 'her'],
#  ['spokesman', 'said', 'was', 'demand', 'Aziz'],
#  ['Knox', '22'],
#  ['Aziz', 'emerged', 'say', 'agreed', 'shooting'],
#  ['Miettinen', 'named', 'Tuesday'],
#  ['Library', 'firm', 'Portland', 'Maine'],
#  ['China', 'Development'],
#  ['Hsiou-mei', 'Tao'],
#  ['He', 'practices', 'believes', 'it', 'heart', 'his'],
#  ['event', 'won', 'Kusakabe', 'States'],
#  ['Vagni',
#   'release',
#   'negotiated',
#   'Sahidulla',
#   'alerted',
#   'proceed',
#   'midnight',
#   'found',
#   'said',
#   'spokesman'],
#  ['he'],
#  ['Hosseini',
#   'Culture',
#   'Minister',
#   'said',
#   'plays',
#   'Organization',
#   'Agency',
#   'OANA'],
#  ['Thursday', 'appealed', 'release', 'safe', 'Vagni'],
#  ['he', 'told', 'mitzvah', 'his'],
#  ['Bureau', 'director', 'arrested', 'he'],
#  ['Gonzalez', 'refused', 'comment', 'credibility', 'words', 'spoke', 'he'],
#  ['He', 'Gone', 'Realizing', 'That', 'People', 'Keeps', 'Fingers', 'His'],
#  ['Planers', 'Judy', 'Ibis'],
#  ['him', 'talking', 'he'],
#  ['Rowe', 'stating', 'online', 'SLC'],
#  ['Alessi', 'said', 'alluding', 'report', 'met', 'lobbyist', 'National'],
#  ['association', 'head', 'Sweeney'],
#  ['Development', 'lowered', 'adjusted', 'starting', 'Thursday'],
#  ['him', 'rid', 'get', 'have', 'told', 'going', 'he'],
#  ['Urban', 'Morial', 'said', 'expects', 'he'],
#  ['Kunstler', 'said', 'ironic', 'took', 'years'],
#  ['16', 'men', 'stable', 'kept', 'provide', 'her'],
#  ['Bibi',
#   'convicted',
#   'province',
#   'governor',
#   'XVI',
#   'clemency',
#   'calls',
#   'followed',
#   'becoming',
#   'woman',
#   'condemned',
#   'hanging'],
#  ['Silsby', 'months', 'deemed', 'was', 'fly', 'Florida'],
#  ['Fisher', 'Think', 'Way', 'Novato'],
#  ['New', 'court', 'panel', 'ruled', 'go', 'claims', 'Jones'],
#  ['Alessi',
#   'works',
#   'Roberto',
#   'said',
#   'agreed',
#   '36',
#   'want',
#   'waste',
#   'time',
#   'figuring',
#   'one',
#   'he'],
#  ['85', 'Simmons', 'said', 'see', 'Daniels'],
#  ['Kunstler', '33'],
#  ['Aug.', 'stage', 'musicians', 'sponsored', 'CCA', 'NTSO'],
#  ['Guobao', 'head', 'Administration'],
#  ['Inc.', 'officer', 'executive', 'options', 'abuse', 'one'],
#  ['Friday',
#   'night',
#   'airing',
#   'Show',
#   'appearance',
#   'denying',
#   'time',
#   'running',
#   'Association'],
#  ['cologne', 'touch', 'dress', 'wrote', 'wounded', 'Sodini', 'kept', 'he'],
#  ['four', 'Slams', 'two', 'have', 'said', 'Graham'],
#  ['Moore', 'died', 'knows', 'arrested', 'mother', 'toddler', 'Sacramento'],
#  ['Bruno', 'warrant', 'issued', 'told', 'killed', 'Samudio'],
#  ['Jawad', 'Pizza', 'Church', 'Ramon'],
#  ['Mozilo', 'accused', 'stock', 'Countrywide'],
#  ['his', 'certainty', 'cleared', 'he'],
#  ['States', 'view', 'release', 'Gross'],
#  ['ALICO', 'FAS'],
#  ['Columbus', 'conference', 'called', 'take', 'action', 'Fund', 'ADF'],
#  ['Cerniglia', 'body', 'found', 'floating', 'River'],
#  ['Osaka', 'Airport', 'Centre', 'Collection'],
#  ['his'],
#  ['she', 'says', 'end', 'began', 'colleagues', 'order', 'Scientology'],
#  ['contractor', 'Gross'],
#  ['Coalition', 'Troops', 'Center', 'of'],
#  ['48-year-old', 'gunman', 'Sodini'],
#  ['hundred', 'musicians', 'said', 'Hei', 'official', 'NTSO'],
#  ['one', 'him'],
#  ['Gonzalez', 'says', 'protected', 'acted', 'liaison'],
#  ['She', 'said', 'following', 'she'],
#  ['Chertoff'],
#  ['his', 'daughter', 'looked', 'confident', 'wants', 'she'],
#  ['League', 'director', 'Moore', 'said', 'go', 'as', 'expected', 'he'],
#  ['Pizza', 'Church', 'Ramon'],
#  ['Management', 'formed', 'e5'],
#  ['Pauliina', 'bring', 'player', 'coach'],
#  ['PeopleTools', ',', 'Framework', 'ADF'],
#  ['assembly', 'Organisation'],
#  ['Friday',
#   'arraigned',
#   'charges',
#   'assault',
#   'resulting',
#   'death',
#   'murder',
#   'Moore'],
#  ['AAUW', 'HRC'],
#  ['Wen', 'abused', 'offering', 'bribes', 'or', 'served', 'he'],
#  ['Rosen', 'reports', 'close', 'now'],
#  ['his', 'reaction', 'day'],
#  ['Bamba', 'ambassador', 'said', 'worried', 'future'],
#  ['Federation', 'launched', 'Thursday'],
#  ['Silsby', 'leader', 'told', 'headquarters', 'capital', 'held', 'judge'],
#  ['LIHOP', 'theory', 'edges', 'Skirts', 'Goldberg', '9/11'],
#  ['Dworin', 'head', 'community', 'Havana'],
#  ['Gonzalez', 'kidnapped', 'office', 'his'],
#  ['RCSC', 'Society', 'China'],
#  ['AIG', 'said', 'move', 'ALICO'],
#  ['he', 'drive', 'Road'],
#  ['ADF'],
#  ['Punjab', 'province', 'governor', 'Taseer', 'held', 'Bibi'],
#  ['Service', 'obituary', 'Lange'],
#  ['Moore', 'death', 'homicide'],
#  ['2001', 'received', 'Library'],
#  ['He', 'claims', 'fell', 'retreated', 'he'],
#  ['Idaho', 'Meridian', 'Church', 'attend', 'Silsby'],
#  ['BEIJING', 'said', 'Administration', 'NEA'],
#  ['Fisher', 'student', 'found', 'beaten', 'times', 'five'],
#  ['Graham', 'accused', 'Aquash'],
#  ['Gonzalez',
#   'prompted',
#   'saying',
#   'ordered',
#   'killings',
#   'Juarez',
#   'claimed',
#   'lives',
#   '6,500'],
#  ['Clark', 'Cloud'],
#  ['she', 'killed', 'said', 'investigating', 'suspects', 'three'],
#  ['he', 'remember', 'hearing', 'shots', 'four'],
#  ['Graham', 'case', 'evidence', 'hearsay', 'attack'],
#  ['Caiping', 'ringleader', 'charged', ',', 'imprisonment', 'illegal'],
#  ['his', 'position', 'NYU'],
#  ['his', 'Richards'],
#  ['Church',
#   'Palczynsky',
#   'said',
#   'disconcerting',
#   'taken',
#   'steps',
#   'make',
#   'sure',
#   'secure',
#   'church',
#   'his'],
#  ['the', 'head', 'Administration'],
#  ['Jennings', 'says', 'says', 'believe', 'meaning', 'guys', 'Loose'],
#  ['Vagni', 'freed', 'province', 'Sulu'],
#  ['He', 'took', 'want', 'he'],
#  ['Jiesong', 'head', 'Division'],
#  ['Mujahid', 'Firnando', 'Ramon'],
#  ['Piedra', 'mentioned', 'said', 'deposition', 'his'],
#  ['Jones', 'said', 'fighting', 'she'],
#  ['his'],
#  ['1', 'operation', 'claims', 'Change'],
#  ['her', 'father', 'support', 'plans', 'now'],
#  ['chertoff', 'talked', 'talked', 'check', 'wasnt', 'bombing', 'OKC'],
#  ['his', 'siblings', 'siphoning', 'Plc', 'TPI'],
#  ['she'],
#  ['Taiwan', 'present'],
#  ['Press', 'Jones', 'Duke'],
#  ['Bamba', 'gave', 'received', 'he'],
#  ['Press',
#   'crescent',
#   'cross',
#   'Issues',
#   '<',
#   'http://currentissues.tv',
#   'House',
#   'http://InformationClearingHouse.com'],
#  ['one', 'told', 'beaten', 'Gonzalez'],
#  ['Bryant', 'Denaro'],
#  ['PRESS', 'cover', 'ect.the', 'fix', 'lamestream'],
#  ['Agencies', 'OANA'],
#  ['ADF', 'Support'],
#  ['FARDC', 'offensive', 'ADF'],
#  ['Democrats', 'signing', 'supporting', 'Pledge', 'delivered', 'Pelosi'],
#  ['Chertoff'],
#  ['student', 'Knox', 'told', 'hopes', 'she'],
#  ['two', 'pistols', 'carried', 'clips', 'semiautomatic', 'pocket', 'his'],
#  ['Graham', 'charged', 'relation', 'kidnapping'],
#  ['Aquash', 'alive', 'said', 'killed', 'Looking'],
#  ['NDA'],
#  ['14,400', 'added', 'rose', 'Gresik'],
#  ['Sicily', 'city', 'base', 'Denaro'],
#  ['he', 'had', 'equipment', 'angered', 'government', 'Cuban'],
#  ['Nationwide', 'ad', 'drew', 'Association'],
#  ['Mailer', 'died', 'home', 'her'],
#  ['Giuliani', 'declined', 'appear', 'events', 'Officials', 'League'],
#  ['Kunstler',
#   'Disturbing',
#   'explore',
#   'life',
#   'father',
#   'lawyer',
#   'fought',
#   'King'],
#  ['Weiss', 'director', 'Association'],
#  ['May', 'secured', 'he'],
#  ['Gage',
#   'found',
#   'Truth',
#   'lecture',
#   'demolition',
#   'Towers',
#   'Building',
#   '7'],
#  ['he'],
#  ['he', 'flew', 'speak', 'Graham'],
#  ['Gross', 'accused', 'pressed', 'detained', 'Dec.'],
#  ['He', 'said', 'stopped', 'reservation', 'took', 'Graham'],
#  ['Inc.', 'lost', '20', 'employees', '85'],
#  ['Bamba', 'said', 'presenting', 'credentials', 'his'],
#  ['Rosen', 'gives', 'regard', 'movement', 'al-Sadr'],
#  ['Coroner', 'officials', 'identified', 'Moore'],
#  ['Bibi', 'sentenced', 'hang', 'Mohammed'],
#  ['Cloud', 'stopped', 'home', 'reservation', 'Aquash'],
#  ['Ecoffey', 'introduced', 'told', 'Graham'],
#  ['China'],
#  ['Guobao', 'director', 'Administration'],
#  ['Mercedes-Benz', 'drove', 'kept', 'provide', 'her'],
#  ['her', 'look', 'changed', 'years'],
#  ['Goude', 'sanctions', 'acts', 'violence'],
#  ['Journalist', 'Rosen'],
#  ['Duncan', 'Morial', 'National'],
#  [',', 'accounted', 'ShopperTrak'],
#  ['Lomax', 'president'],
#  ['Lomax', 'told', 'Press'],
#  ['he'],
#  ['he', 'didnt', 'do', 'thats', 'sorted', 'let', 'go', 'him'],
#  ['Amit', 'filed', 'charged', 'practice', 'Piedra'],
#  ['National', 'Guobao'],
#  ['Countrywide', 'operations', 'Valley', 'County'],
#  ['Orchestra', 'perform', 'first', 'concerts', '11'],
#  ['Piedra', 'contributions', 'voluntary', 'had', 'business', 'his'],
#  ['his', 'behalf', 'involved', 'became', 'covered', 'city', 'Stamford'],
#  ['producer', 'handed', 'bars', 'listed', 'Silsby', 'nanny', 'her'],
#  ['Center', 'of'],
#  ['Financial'],
#  ['Baldino', 'founded'],
#  ['he', 'worried', 'consulting', 'ahead', 'meeting', 'week'],
#  ['three', 'children', 'survives', 'Bailey', 'Lange'],
#  ['Herold', 'asked', 'friend', 'her'],
#  ['he', 'believed', 'treated', 'Bibi'],
#  ['TPI', 'said', 'value', 'reached', 'down', '18', 'quarter-on-quarter'],
#  ['her', 'brother', 'kidnapped', 'said', ',', "''", 'leader'],
#  ['Ouattara', 'Bamba'],
#  ['Enterprises', 'Group'],
#  ['one', 'million', 'manufacturers', 'Alessi'],
#  ['News'],
#  ['63-year-old', 'Vagni'],
#  ['one', 'helped', 'adding', 'insisted', 'telling', 'him'],
#  ['Lomax', 'said', 'thought', 'crazy', 'take', 'children', 'her'],
#  ['infant', 'identified', 'Moore'],
#  ['Cerniglia', 'saw', 'said', 'seemed', 'he'],
#  ['mediator', 'Aziz'],
#  ['Denaro', 'mobster', 'handful', 'people', 'vying', 'replace', 'Provenzano'],
#  ['Gonzalez',
#   'says',
#   'protected',
#   'Linea',
#   'gang',
#   'tied',
#   'cartel',
#   'Juarez'],
#  ['Georgia',
#   'group',
#   'director',
#   'formed',
#   'received',
#   'request',
#   'help',
#   'couple',
#   'Spooner'],
#  ['II', 'hired', 'Boyd', 'working', 'League'],
#  ['TPI', 'embezzlement', 'Yesterday', '|'],
#  ['April', 'March', 'participated', 'rejected', 'he'],
#  ['Minister', 'Goude'],
#  ['Amanda',
#   'character',
#   'attacks',
#   'had',
#   'overshadowed',
#   'lack',
#   'evidence',
#   'case',
#   'her'],
#  ['IRA', 'Association'],
#  ['Ladyzhenskiy', 'Russia'],
#  ['Association', 'predicts', 'reach', '$', '2007'],
#  ['NRA', 'survey', 'identifies', '2008'],
#  ['Orchestra', 'Suan-yung'],
#  ['League', 'sentences', 'issued', 'categories', 'Courts'],
#  ['Mycoplasma', 'Monitoring', 'performing', 'Facility', 'ADF'],
#  ['Cloud', 'Graham'],
#  ['he', 'use', 'Chertoff'],
#  ['his', 'diary', 'Web'],
#  ['LIHOP', 'scenario', 'involve', 'people', '9/11'],
#  ['Countrywide', 'presents', 'platform', 'said', 'Lewis'],
#  ['Graham', '94'],
#  ['39-year-old', 'Cerniglia'],
#  ['Tribeca'],
#  ['MCA', 'received', 'received', 'Society', 'China'],
#  ['Lang', 'Verticals', 'TPI'],
#  ['recently', 'developed', 'tools', 'Poverty', 'Analysis'],
#  ['China'],
#  ['governor', 'held', 'Bibi'],
#  ['manufacturer', 'Gresik'],
#  ['His', 'mistake', 'using', 'Chertoff'],
#  ['Sayyaf', 'held', 'entering', 'negotiations', 'release', 'his'],
#  ['and', 'Change', 'Protocol'],
#  ['now', 'heard', 'story', 'Chiafari'],
#  ['Villopoto', 'Alessi'],
#  ['Mailer', 'married', 'managed', 'career', 'his'],
#  ['Gage', 'Jones', 'Scholars', 'Truth', '9/11'],
#  ['him', 'be', 'raise', 'profile', 'his'],
#  ['he'],
#  ['Cooper', 'brother', 'warned', 'returning', 'create', 'Central'],
#  ['Graham', 'Cloud'],
#  ['Espitia', 'Baeza', 'met', 'described', 'Gonzalez'],
#  ['years', 'remaining', 'objective', 'his'],
#  ['Chen', 'said', 'referring', 'trials', 'took', '1999'],
#  ['Enterprises', 'officer', 'director', 'Sundance'],
#  ['Lieutenant', 'Ramon'],
#  ['he', 'relative', 'see', 'talked', 'talked', 'check', 'wasnt', 'bombing'],
#  ['Press',
#   'years',
#   'featured',
#   'publication',
#   'of',
#   'nation',
#   'leading',
#   'Denier',
#   'Carto'],
#  ['Video', 'Chertoff'],
#  ['Fisher', 'hire', 'move', 'Ricci'],
#  ['Knox', 'had', 'parents', 'her'],
#  ['Rosen', 'One', 'published', 'recently'],
#  ['Ltd.', 'company', 'provides', 'solutions', 'BPO'],
#  ['Org', 'get', 'her'],
#  ['Chongqing', 'court', 'convicted', 'Caiping'],
#  ['Tarpley', 'Jones', 'participants', 'Ranke'],
#  ['She', 'moved', 'work', 'Congress'],
#  ['Culture', 'of'],
#  ['Countrywide', 'subjects', 'one'],
#  ['Dworin', 'president', 'Shalom', 'organization', 'Jewish'],
#  ['Gonzalez', 'handcuffed', 'men', 'pointing', 'him'],
#  ['Dutch', 'ministry', 'identified', 'Ruben'],
#  ['Sodini', 'updated', 'diary', 'his'],
#  ['1423', 'Ave.', 'Pueblito', 'offers', 'cuisine', 'walk', 'Collection'],
#  ['Bibi', 'Christian'],
#  ['her', 'see', 'heroism', 'recognize', 'thought', 'explained', 'Lomax'],
#  ['Committee', 'part', 'head', 'UASR'],
#  ['She', 'testified', 'forced', 'she'],
#  ['Knox',
#   'parents',
#   'visited',
#   'ruled',
#   'remain',
#   'proclamation',
#   'death',
#   'flatmate',
#   'British'],
#  ['Rosen', 'came', 'said', 'more', 'saying', 'control', 'militias', 'shia'],
#  ['Jr.', 'acknowledged', 'made', '$', 'expected', 'one'],
#  ['Jones', 'Times', 'left', 'told', 'gang-raped', '2005'],
#  ['TPI', 'purchased', 'October'],
#  ['Haibin', 'Hao', 'Tao'],
#  ['president', 'Dworin', 'knows', 'does', 'she'],
#  ['Judge', 'Saint-Vil', 'had', 'ordered', 'Silsby'],
#  ["O'Grady", 'who', 'is', 'close', 'person', 'dug', 'Association', 'NRA'],
#  ['Morales', 'Silverman', 'Church'],
#  ['she', 'spent', 'Sollecito'],
#  ['Vagni', 'seized', 'Committee', 'Notter', 'Lacaba'],
#  ['Change', 'productive', 'riddled', 'Forum'],
#  ['her', 'freedom', 'happy', 'told', 'left', 'courthouse', 'held', 'Monday'],
#  ['ALICO', 'held', 'Bank', 'York'],
#  ['McFarlane', 'puts', 'director', 'Crisis'],
#  ['Jan.', 'met', 'carry', 'tried', 'he'],
#  ['Buy', 'laptops', 'discounts', 'attracted', 'ShopperTrak'],
#  ['One', 'Capital', 'sent', 'letter', 'demanding', 'give', 'he'],
#  ['his', 'address', 'delivered', 'League'],
#  ['he'],
#  ['February', 'went', 'asked', 'help', 'lure', 'him'],
#  ['Kunstler', '12', '10', 'sister', 'co-filmmaker'],
#  ['province', 'governor', 'Taseer', 'held', 'Bibi'],
#  ['Silsby', 'detainees', 'went', 'said', 'Saint-Vil', 'Judge'],
#  ['Denaro', 'said', 'Maroni'],
#  ['year', 'wrote', 'Rosen'],
#  ['Sodini', 'Carnegie'],
#  ['KBR',
#   'silent',
#   'according',
#   'News',
#   'circulated',
#   'saying',
#   'disputes',
#   'portions',
#   'version',
#   'Jones'],
#  ['Halliburton',
#   'Take',
#   'http://www.opednews.com/maxwrite/link.php?id=53740',
#   'Jones'],
#  ['680,000',
#   'meters',
#   'deficit',
#   'mend',
#   'helped',
#   'said',
#   'Jin',
#   'director',
#   'department',
#   'Development'],
#  ['Fisher', 'Blog', 'Response', 'EJB', 'Analysis', 'Spring'],
#  ['Co', 'BlackRock', 'investors', 'group', 'attempting', 'put', 'Group'],
#  ['Sodini', 'went', 'August'],
#  ['his', 'mother', 'Sally'],
#  ['NDRC', 'Commission', 'Development', 'announced', 'Tuesday'],
#  ['month', 'reported', 'Association'],
#  ['spokesman',
#   'said',
#   'go',
#   'appeals',
#   'made',
#   'appellants',
#   'Xiaoya',
#   'officers',
#   'Daiqiang',
#   'Tao'],
#  ['Minow', 'cofounder', 'Library'],
#  ['Fidel', 'said', 'know', 'explained', 'Dworin'],
#  ['his', 'wife', 'brothers', 'Guy'],
#  ['Xie', 'sister-in-law', 'Qiang', 'second', 'arrested', 'he'],
#  ['his'],
#  ['she', 'executed', 'snip', 'shears', 'mother', 'her'],
#  ['Piedra', 'showed', 'models', 'fix', 'he'],
#  ['Her', 'attackers', 'Halliburton', 'firefighters', 'KBR'],
#  ['Knox', 'Mellas'],
#  ['he', 'received', 'Ki-moon', 'UN'],
#  ['NAACP', 'Jealous', 'Morial', 'National'],
#  ['Kunstler', 'said', 'believed', 'she'],
#  ['Nations', 'expect', 'heart', 'said', 'he'],
#  ['Giuliani', 'name', 'Ramon'],
#  ['Drazan', 'Connolly', 'Morris', 'Heloise'],
#  ['ambassador', 'Bamba'],
#  ['Steal', 'Bollyn'],
#  ['Mamane', 'Claudine', 'given', 'bag', 'tickets', 'show', 'Chicago'],
#  ['his', 'wife', 'taunting', 'started', 'shouting', 'mother', 'her'],
#  ['Hodgson', 'Library'],
#  ['court', 'upheld', 'Arlo'],
#  ['OANA', 'President', 'said', 'speech', 'Thursday'],
#  ['he'],
#  ['He',
#   'attended',
#   'University',
#   'University',
#   'received',
#   'hired',
#   'professor'],
#  ['Library', 'associate', 'Hodgson', 'criticized', 'Bank'],
#  ['Silsby', 'told', 'interested', 'she'],
#  ['Center', 'resident', 'Simmons', 'said', 'see', 'Daniels'],
#  ['NDRC', "'s"],
#  ['he', 'knew', 'expert', 'has', 'turned', 'though', 'type', 'Cassandra'],
#  ['his', 'diary', 'complained', 'he'],
#  ['Customs', 'agents', 'Immigration', 'seized', 'plant', 'Koch'],
#  ['Caiping', '46'],
#  ['wrestler', 'Ladyzhenskiy', 'pronounced', 'collapsed', 'he'],
#  ['Lange', 'devoted', 'career', 'his'],
#  ['one', 'Flamengo', 'captain', 'suspected', 'involved', 'death', 'Samudio'],
#  ['Gage', 'speaker', 'BOULDER', 'present'],
#  ['he', 'wanted', 'her'],
#  ['American', 'Silsby'],
#  ['National', 'Caller', 'Joseph'],
#  ['HAYDEN', 'Author', 'Ending', 'of'],
#  ['her', 'community', 'knows', 'does', 'she'],
#  ['her'],
#  ['Mike', 'starting', 'questioning', 'watching', 'video', 'SLC'],
#  ['Jerusalem', 'ISRAEL-CRASH', 'kills', 'Ramon'],
#  ['he',
#   'speak',
#   'know',
#   'happening',
#   'kidnappers',
#   'alleged',
#   'government',
#   'Philippine'],
#  ['Qiang', 'director'],
#  ['National', 'Morial', 'mayor', 'city', 'Orleans'],
#  ['World', 'visit', 'ruined', 'appetite', 'his'],
#  ['Jan.', 'arrest', 'orphans', 'all', 'children', 'trying', 'she'],
#  ['Gresik', 'gained', '250'],
#  ['Denaro', 'fugitive', 'boss', 'who', 'some', 'considered', 'man', '2'],
#  ['Denaro', 'allowed', 'come', 'out', 'hideout', 'his'],
#  ['he', 'remember', 'Looking'],
#  ['9/11', 'wanted', 'outclassed', 'boys', 'Loose'],
#  ['kidnapping',
#   'posted',
#   'YouTube',
#   'showing',
#   'handcuffed',
#   'men',
#   'pointing',
#   'him'],
#  ['billion', '$', 'rose', 'ShopperTrak'],
#  ['Federation', 'raised', 'worth', 'yuan', 'dollars', 'million'],
#  ['Orchestra', 'Cello', 'Symphony-Concerto', 'Op.', '125'],
#  ['he', 'spoke', 'believes', 'close', 'Sharif'],
#  ['Sycamore', 'spokesman', 'said', 'yesterday'],
#  ['NTSO', 'CCA', 'sponsored', 'musicians', 'stage', 'pay', 'Williams'],
#  ['Koch',
#   'plant',
#   'seized',
#   'said',
#   'Moskowitz',
#   'agent',
#   'charge',
#   'enforcement',
#   'Ohio',
#   'Michigan'],
#  ['Hagemo', 'daughter', 'LaFreniere', 'Shelby'],
#  ['Wednesday',
#   'protest',
#   'took',
#   'front',
#   'railed',
#   'calling',
#   'release',
#   'Bibi'],
#  ['Congress'],
#  ['League', 'organization', 'address', 'Saturday'],
#  ['Jones', 'Conroe'],
#  ['Declaration', 'passed', 'summit', 'Assembly', 'Organization'],
#  ['ALICO', 'firm', 'operates', 'countries', '50'],
#  ['trafficking', 'ties', 'are', 'believe', 'said', 'she'],
#  ['New', 'examiner', 'ruled', 'death', 'Cerniglia'],
#  ['OANA'],
#  ['Rukwago', 'commander', 'ADF'],
#  ['his', 'mother', 'Lomax', 'story', 'shares', 'taking', 'Tuskegee'],
#  ['Aquash', 'member', 'tribe', 'Scotia'],
#  ['Lomax', 'said', 'thought', 'crazy', 'mother', 'his'],
#  ['he', 'moved', 'years'],
#  ['Pictou', 'one', 'daughters', 'Aquash'],
#  ['Collection', 'Center', 'Arts', 'Manhattan'],
#  ['Caiping', 'sentenced', 'charges', 'running', 'dens', 'dealing'],
#  ['of'],
#  ['His', 'troops', 'cornered', 'government', 'Ouattara'],
#  ['Dworin', 'president', 'Patronage'],
#  ['Tao', 'Shengjiong', 'Fangzhuo'],
#  ['US', 'government', 'identified', 'man', 'Gross'],
#  ['2006', 'placed', 'role', 'his'],
#  ['Cloud', 'Clark'],
#  ['AIA', 'Alico'],
#  ['March', 'participated', 'rejected', 'characterization', 'him'],
#  ['she', 'auditor'],
#  ['her', 'husband', 'using', 'Cuba'],
#  ['Pakistani', 'journalist', 'Rashid'],
#  ['his', 'bedside', 'Tripoli'],
#  ['Louisiana', 'Jindal', 'said', 'called', 'League'],
#  ['ShopperTrak', 'finds', 'that', 'weekend'],
#  ['Gonzalez', 'attorney'],
#  ['Skenendore', 'was', 'had', 'involvement', 'abduction', 'Aquash'],
#  ['Knox', 'Seattle'],
#  ['Hill', 'arrested', 'melee', 'left', 'Tao'],
#  ['she', 'feels', 'problem', 'talking', 'religion', 'her'],
#  ['He', 'saw', 'said', 'seemed', 'Cerniglia'],
#  ['ShopperTrak', 'figures', 'showed', 'rose', 'Friday'],
#  ['Bibi', 'sentenced', 'Nov.'],
#  ['ShopperTrak', 'said', 'dropped', 'week'],
#  ['Deming', 'head', 'Zhibang', 'Administration'],
#  ['Democrats',
#   'activist',
#   'Hirsch',
#   'tells',
#   'met',
#   'discussed',
#   'book',
#   'Bugliosi'],
#  ['Graham', 'Bliss', 'Vickers'],
#  ['Goude', 'known', 'insisted', 'he'],
#  ['AFP', 'asked', 'thought', 'he'],
#  ['She', 'enjoys', 'flicks', 'era'],
#  ['Hagemo', 'believes', 'warranted', 'destroyed', 'case', 'her'],
#  ['62-year-old', 'Vagni'],
#  ['Sodini', 'graduated', 'worked', 'analyst'],
#  ['He', 'has', 'issue', 'Journal'],
#  ['his', 'Trudy', 'Patrick', 'Enzo'],
#  ['Gay', 'president', 'Association'],
#  ['ALICO', 'Known', 'Co.'],
#  ['TPI', 'said', 'increasing', 'downturn', 'current'],
#  ['his',
#   'restaurant',
#   'featured',
#   'episode',
#   'thrilling',
#   'Nightmares',
#   'Ramsay'],
#  ['Bamba', 'ambassador', 'said', 'worried', 'he'],
#  ['he', 'held', 'year'],
#  ['TPI', 'Index', 'showed', 'contracts', '141'],
#  ['Ladyzhenskiy', 'headed', 'fund', 'city', 'Novosibirsk'],
#  ['Assouw', 'remember', 'reported', 'Telegraaf', 'Dutch'],
#  ['Chongqing', 'Qiang'],
#  ['pole', 'posted', 'picture', 'nullifies', 'point', 'his'],
#  ['PATA', 'ended', 'Saturday'],
#  ['Association', 'offered', 'Awards', 'reports', 'reaching', 'Bali'],
#  ['Professor', 'Tao'],
#  ['He', 'appointed', 'professor'],
#  ['Cloud', 'Graham', 'Aquash'],
#  ['chief', 'Qiang'],
#  ['Caiping', 'known', 'godmother', 'underworld', 'Chinese'],
#  ['She', 'said', 'saw', 'flash', 'him'],
#  ['Fabris', 'France'],
#  ['Pueblito', 'offers', 'cuisine', 'walk', 'Collection'],
#  ['Aziz', 'May', 'arrest', 'informed', 'connection', 'abduction', 'murder'],
#  ['He', 'had', 'fired', 'gun', 'his'],
#  ['Morial', 'mayor', 'president', 'League'],
#  ['Herold', 'Stamford'],
#  ['Minister', 'Goude'],
#  ['Bhatti', 'called', 'ensure', 'safety', 'Bibi'],
#  ['Iraq', 'Barker', 'held', 'kept', 'her'],
#  ['Africa', 'safari', 'Trudy', 'his'],
#  ['Law', 'companies', 'NDRC'],
#  ['manager', 'Gage', 'Avery', 'Ranke'],
#  ['his'],
#  ['Forces', 'ADF'],
#  ['Daniels', 'death', 'deemed', 'said', 'Ballard'],
#  ['ALICO', 'unit', 'AIA', 'Prudential'],
#  ['Longyuan', 'Shengjiong', 'Tao'],
#  ['week', 'became', 'fracas', 'came', 'Spooners'],
#  ['years', 'sentenced', 'charges', 'requested', 'defense', 'his'],
#  ['YouTube', 'showing', 'handcuffed', 'Gonzalez'],
#  ['her', 'locks', 'done', 'she'],
#  ['Organization', 'President', 'elected', 'assembly', 'taking', 'Wednesday'],
#  ['Russia', 'developing', 'cooperation', 'framework', 'Organization', 'OANA'],
#  ['Federation', 'launched', 'collaboration', 'institutions', '200'],
#  ['Oct.', 'kidnapped', 'Gonzalez'],
#  ['Commission', 'NDRC'],
#  ['Orchestra', 'Festival', 'NTSO'],
#  ['PATA', 'study', 'says', 'projected', 'numbers', 'Pacific'],
#  ['Vagni', 'release', 'mentioned', 'said', 'Gonzalez'],
#  ['MIHOP',
#   'attacks',
#   'government',
#   'evidence',
#   'had',
#   'foreknowledge',
#   'attack',
#   'ignored',
#   'LIHOP'],
#  ...]

# %% [markdown]
# ### Additional part

# %%
for i,r in enumerate(res):
    if r[0] in entities_tokenized[i][0]:
        r[0] = entities[i][0]
        r[-1] = entities[i][-1]
    else:
        print(i)

# %% [markdown]
# ### Save

# %%
import pickle

# %%
pickle.dump(res,open('./stanford_tacred_test_sdp_results.pkl','wb'))
